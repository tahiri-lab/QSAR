# %% [markdown]
# # Preparing the input file for the Small Dataset Curator ()
# We need a csv file with:
# > First Row: Header names \
# > First column: Chemical serial number (index) \
# > Subsequent columns: Descriptors values \
# > Last column:  Response values (Log_MP_RATIO) \

# %%
import pandas as pd

# %%
#Import data to pandas dataframe and set the first column as index
df = pd.read_excel ('milk_plasma_all_data_mrg_020821.xlsx')
df.set_index('index', inplace=True)
#number of rows, number of columns
df.shape
# Out:
# (183, 496)

# %%
#   * Drop the columns : 'smiles','conc','name','CLASS','MP_RATIO','Log_MP_RATIO', 'neutral','TEST','CHARGED','group','set''
#   * Insert the column Log_MP_RATIO in the last position as needed

new_df=df.drop(columns=['smiles','conc','name','CLASS','MP_RATIO','Log_MP_RATIO','neutral','TEST','CHARGED','group','set']).assign(Log_MP_RATIO=df['Log_MP_RATIO'])

new_df
# Out:
#        ENV_CHEM                                           FP:MACCS  $DIVPRIO  \
# index
# 1             1  92 110 113 117 131 133 135 139 143 151 152 154...         1
# 2             1  25 28 38 43 65 72 75 77 78 79 80 82 83 84 85 8...        73
# 3             1  19 38 52 62 65 77 78 79 80 83 85 87 94 96 100 ...        66
# 4             1  49 84 104 111 115 151 155 156 158 160 161 162 ...         9
# 5             1  8 11 19 36 47 49 54 66 74 79 81 83 84 85 88 92...        16
# ...         ...                                                ...       ...
# 179           1  49 53 54 82 84 89 90 92 95 97 100 104 110 111 ...        79
# 180           0  87 103 106 107 112 125 134 144 145 150 162 163...        61
# 181           0     21 50 76 87 99 103 107 125 134 145 162 163 165        14
# 182           0         87 103 106 107 112 125 134 145 162 163 165       115
# 183           0  66 76 87 96 99 101 103 105 107 112 134 150 163...        94
#
#             apol        ASA        ASA+       ASA-      ASA_H       ASA_P  \
# index
# 1      22.785137  341.43088  196.220180  145.21069  239.01727  102.413610
# 2      29.320723  431.48679  317.577730  113.90907  183.97377  247.513000
# 3      45.168308  512.07532  248.789260  263.28607  438.28427   73.791069
# 4      26.275103  349.46716  242.228820  107.23836  264.31046   85.156723
# 5      49.570274  561.79968  267.192260  262.83469  309.97708  251.822590
# ...          ...        ...         ...        ...        ...         ...
# 179    54.715824  628.47516  413.561190  214.91400  414.99454  213.480650
# 180    41.541138  490.29086  142.239910  348.05093  352.38516  137.905700
# 181    38.694344  498.58255  141.864210  356.71835  494.35355    4.229017
# 182    41.541138  508.05460  134.185330  373.86926  366.44958  141.605030
# 183    40.553967  474.31766   40.688782  433.62888  141.29962  333.018040
#
#        a_acc  ...  vsurf_Wp8     Weight  weinerPath  weinerPol  zagreb  \
# index         ...
# 1          2  ...       0.00  151.16499         166         11      50
# 2          5  ...       1.25  225.20799         453         22      80
# 3          3  ...       0.00  308.77200         926         40     122
# 4          0  ...       0.00  136.21800         126          9      44
# 5          3  ...       0.00  348.40298        1365         39     132
# ...      ...  ...        ...        ...         ...        ...     ...
# 179        3  ...       0.00  329.41998        1607         33     116
# 180        0  ...       0.00  354.49100         654         29      98
# 181        0  ...       0.00  318.03000         603         26      90
# 182        0  ...       0.00  354.49100         678         28      98
# 183        0  ...       0.00  444.22699         527         49     120
#
#        $PRED_neutral_model_7  $PRED_ionized_model_516  \
# index
# 1                  -0.246018                -0.198971
# 2                   0.274696                 0.252062
# 3                  -0.474589                -0.314985
# 4                   0.411452                 0.465482
# 5                  -0.879331                -0.344795
# ...                      ...                      ...
# 179                -0.467125                 0.162852
# 180                 0.353390                -0.868373
# 181                 0.391826                -0.630014
# 182                 0.537776                -0.910309
# 183                 0.565090                 0.090766
#
#        $PRED_charged_and_3d_model1  $PREDCOMP  Log_MP_RATIO
# index
# 1                        -0.338185  -0.246018     -0.119186
# 2                         0.017201   0.274696      0.423246
# 3                        -0.465988  -0.474589     -0.443698
# 4                         0.167944   0.465482      0.711807
# 5                        -0.708340  -0.344795     -0.530178
# ...                            ...        ...           ...
# 179                       0.130214   0.162852      0.176091
# 180                       0.323759   0.353390      0.472628
# 181                       0.152654   0.391826      0.667194
# 182                       0.383260   0.537776      0.850593
# 183                       0.759818   0.565090      0.847938
#
# [183 rows x 486 columns]

# %%
#list of all the column names  containing '$' in the first position
cols = [c for c in df.columns if c[0] == '$']

print(cols)
# Out:
# ['$DIVPRIO', '$PRED_neutral_model_7', '$PRED_ionized_model_516', '$PRED_charged_and_3d_model1', '$PREDCOMP']

# %%
#   * Drop the columns starting with $

new_df=new_df.drop(cols, axis=1)
new_df
# Out:
#        ENV_CHEM                                           FP:MACCS       apol  \
# index
# 1             1  92 110 113 117 131 133 135 139 143 151 152 154...  22.785137
# 2             1  25 28 38 43 65 72 75 77 78 79 80 82 83 84 85 8...  29.320723
# 3             1  19 38 52 62 65 77 78 79 80 83 85 87 94 96 100 ...  45.168308
# 4             1  49 84 104 111 115 151 155 156 158 160 161 162 ...  26.275103
# 5             1  8 11 19 36 47 49 54 66 74 79 81 83 84 85 88 92...  49.570274
# ...         ...                                                ...        ...
# 179           1  49 53 54 82 84 89 90 92 95 97 100 104 110 111 ...  54.715824
# 180           0  87 103 106 107 112 125 134 144 145 150 162 163...  41.541138
# 181           0     21 50 76 87 99 103 107 125 134 145 162 163 165  38.694344
# 182           0         87 103 106 107 112 125 134 145 162 163 165  41.541138
# 183           0  66 76 87 96 99 101 103 105 107 112 134 150 163...  40.553967
#
#              ASA        ASA+       ASA-      ASA_H       ASA_P  a_acc  a_acid  \
# index
# 1      341.43088  196.220180  145.21069  239.01727  102.413610      2       0
# 2      431.48679  317.577730  113.90907  183.97377  247.513000      5       0
# 3      512.07532  248.789260  263.28607  438.28427   73.791069      3       0
# 4      349.46716  242.228820  107.23836  264.31046   85.156723      0       0
# 5      561.79968  267.192260  262.83469  309.97708  251.822590      3       2
# ...          ...         ...        ...        ...         ...    ...     ...
# 179    628.47516  413.561190  214.91400  414.99454  213.480650      3       0
# 180    490.29086  142.239910  348.05093  352.38516  137.905700      0       0
# 181    498.58255  141.864210  356.71835  494.35355    4.229017      0       0
# 182    508.05460  134.185330  373.86926  366.44958  141.605030      0       0
# 183    474.31766   40.688782  433.62888  141.29962  333.018040      0       0
#
#        ...  vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8     Weight  \
# index  ...
# 1      ...     22.375      9.625      3.000      0.000       0.00  151.16499
# 2      ...     54.250     25.750     11.125      4.625       1.25  225.20799
# 3      ...      0.500      0.000      0.000      0.000       0.00  308.77200
# 4      ...     38.250     12.625      1.250      0.000       0.00  136.21800
# 5      ...     36.250     14.750      3.875      0.000       0.00  348.40298
# ...    ...        ...        ...        ...        ...        ...        ...
# 179    ...     62.625     21.375      4.375      0.375       0.00  329.41998
# 180    ...      0.000      0.000      0.000      0.000       0.00  354.49100
# 181    ...      0.000      0.000      0.000      0.000       0.00  318.03000
# 182    ...      0.000      0.000      0.000      0.000       0.00  354.49100
# 183    ...      0.250      0.000      0.000      0.000       0.00  444.22699
#
#        weinerPath  weinerPol  zagreb  Log_MP_RATIO
# index
# 1             166         11      50     -0.119186
# 2             453         22      80      0.423246
# 3             926         40     122     -0.443698
# 4             126          9      44      0.711807
# 5            1365         39     132     -0.530178
# ...           ...        ...     ...           ...
# 179          1607         33     116      0.176091
# 180           654         29      98      0.472628
# 181           603         26      90      0.667194
# 182           678         28      98      0.850593
# 183           527         49     120      0.847938
#
# [183 rows x 481 columns]

# %%
#Exporting pandas dataFrame to CSV
new_df.to_csv('milk_plasma_data.csv', encoding='utf-8')
