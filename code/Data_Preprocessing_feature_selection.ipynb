# %% [markdown]
# ## Data_Preprocessing_feature_selection
#
#
#
# > 1. Drop all non numeric data
# > 2. Drop feature containing '$' in the first position
# > 3. Drop all constant features
# > 4. dataFrame standardization
#     - save the dataframe to csv : standardized_df.csv
# > 5. Data Visualization
# > 6. Principal Component Analysis (PCA)
#      - on the scaled dataframe (df3) - save the dataframe to csv : df_pca.csv
# > 7. SelectKbest
#     -  on the scaled dataframe (df3) - save to csv : df_SelectKBest.csv
# >
# > 8. drop highly correlated features (> 0.95)
# > 9. Find outliers
# > 10. correlation with output
# > 11. Forward Selection
# > 12. Random Forest Regression Feature Importance (first 30)
# > 13. Backward Feature Elimination

# %%
#!/usr/bin/python3
# coding=utf-8

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold, SelectKBest, f_regression, RFECV, RFE 
from sklearn.model_selection import KFold, cross_val_score, cross_validate, cross_val_predict, GridSearchCV
from sklearn import svm
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge, LinearRegression, Lasso, ElasticNet, ElasticNetCV, LassoCV, LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.model_selection import train_test_split
#import pandas_profiling

from sklearn.metrics import mean_squared_error, r2_score, median_absolute_error, make_scorer
from random import randint

from IPython.display import display, Markdown
from platform import python_version

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
display(Markdown('### my python_version = 3.9.12 , Pandas_version = 1.2.4'))

print('python_version \t :', python_version())
print('Pandas_version \t :', pd. __version__ )
# Out:
# ### my python_version = 3.9.12 , Pandas_version = 1.2.4
# python_version 	 : 3.9.12
# Pandas_version 	 : 1.4.2

# %%
#Import data to pandas dataframe and set the first column as index
df = pd.read_excel ('data/milk_plasma_all_data_mrg_020821.xlsx')
df.set_index('index', inplace=True)
df.describe()
# Out:
#              conc    ENV_CHEM    MP_RATIO  Log_MP_RATIO    $DIVPRIO  \
# count  183.000000  183.000000  183.000000    183.000000  183.000000
# mean    94.457517    0.606557    2.471367      0.064355   95.841530
# std     11.244688    0.489854    2.807868      0.646852   58.355127
# min     44.544422    0.000000    0.005500     -2.259637    1.000000
# 25%     96.876785    0.000000    0.570000     -0.244192   46.500000
# 50%     99.761139    1.000000    1.249159      0.096618   92.000000
# 75%    100.000000    1.000000    3.643238      0.561488  137.500000
# max    100.000000    1.000000   20.466232      1.311038  184.000000
#
#              apol          ASA        ASA+        ASA-       ASA_H  ...  \
# count  183.000000   183.000000  183.000000  183.000000  183.000000  ...
# mean    43.101909   515.701000  242.645919  270.672053  403.884078  ...
# std     14.711291   108.701072  148.373315  124.829085  134.994054  ...
# min      8.322758   197.574580    0.000000   64.410759    0.000000  ...
# 25%     35.353966   467.002060  103.082525  170.508665  313.639420  ...
# 50%     39.893585   502.726960  246.916580  237.202330  437.151890  ...
# 75%     49.712860   559.477875  360.791610  374.248900  500.089340  ...
# max    126.062750  1094.164700  794.894100  625.281980  725.847960  ...
#
#         weinerPol      zagreb  $PRED_neutral_model_7  $PRED_ionized_model_516  \
# count  183.000000  183.000000             183.000000               183.000000
# mean    33.726776  105.693989               0.149404                -0.300480
# std     15.233411   37.591125               0.634315                 0.429151
# min      0.000000    6.000000              -2.568591                -1.423822
# 25%     25.000000   86.000000              -0.148957                -0.537066
# 50%     31.000000  100.000000               0.319691                -0.375190
# 75%     39.000000  122.000000               0.560284                 0.029467
# max    113.000000  320.000000               1.986463                 0.773092
#
#        $PRED_charged_and_3d_model1   $PREDCOMP     neutral        TEST  \
# count                   183.000000  183.000000  183.000000  183.000000
# mean                      0.053206    0.084174    0.606557    0.196721
# std                       0.506946    0.534768    0.489854    0.398610
# min                      -1.253899   -1.423822    0.000000    0.000000
# 25%                      -0.233913   -0.247966    0.000000    0.000000
# 50%                       0.147322    0.122110    1.000000    0.000000
# 75%                       0.454164    0.508073    1.000000    0.000000
# max                       0.983590    1.035515    1.000000    1.000000
#
#           CHARGED       group
# count  183.000000  183.000000
# mean     0.393443    0.590164
# std      0.489854    0.630116
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    1.000000
# max      1.000000    2.000000
#
# [8 rows x 491 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 183
# Columns: 496 entries, smiles to set
# dtypes: float64(272), int64(219), object(5)
# memory usage: 710.6+ KB

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['smiles', 'conc', 'name', 'CLASS', 'ENV_CHEM', 'MP_RATIO',
#        'Log_MP_RATIO', 'FP:MACCS', '$DIVPRIO', 'apol',
#        ...
#        'zagreb', '$PRED_neutral_model_7', '$PRED_ionized_model_516',
#        '$PRED_charged_and_3d_model1', '$PREDCOMP', 'neutral', 'TEST',
#        'CHARGED', 'group', 'set'],
#       dtype='object', length=496)

# %%
df.head(3)
# Out:
#                                         smiles       conc           name  \
# index
# 1                           O=C(Nc1ccc(O)cc1)C  99.679085  Acetaminophen
# 2                 O(CCO)Cn1c2N=C(N)NC(=O)c2nc1  86.215294      Acyclovir
# 3      Clc1cc2C(c3ccccc3)=NCc3n(c(C)nn3)-c2cc1  97.833694     Alprazolam
#
#       CLASS  ENV_CHEM  MP_RATIO  Log_MP_RATIO  \
# index
# 1      DRUG         1      0.76     -0.119186
# 2      DRUG         1      2.65      0.423246
# 3      DRUG         1      0.36     -0.443698
#
#                                                 FP:MACCS  $DIVPRIO       apol  \
# index
# 1      92 110 113 117 131 133 135 139 143 151 152 154...         1  22.785137
# 2      25 28 38 43 65 72 75 77 78 79 80 82 83 84 85 8...        73  29.320723
# 3      19 38 52 62 65 77 78 79 80 83 85 87 94 96 100 ...        66  45.168308
#
#        ...  zagreb  $PRED_neutral_model_7  $PRED_ionized_model_516  \
# index  ...
# 1      ...      50              -0.246018                -0.198971
# 2      ...      80               0.274696                 0.252062
# 3      ...     122              -0.474589                -0.314985
#
#        $PRED_charged_and_3d_model1  $PREDCOMP  neutral  TEST  CHARGED  group  \
# index
# 1                        -0.338185  -0.246018        1     0        0      0
# 2                         0.017201   0.274696        1     0        0      0
# 3                        -0.465988  -0.474589        1     0        0      0
#
#             set
# index
# 1      TRAINING
# 2      TRAINING
# 3      TRAINING
#
# [3 rows x 496 columns]

# %%
#find all rows with NaN in entire DataFrame (df)
nan_values = df[df.isna().any(axis=1)]
null_values = df[df.isnull().any(axis=1)]
#number of NAN and null values
len(nan_values), len(null_values)
# Out:
# (0, 0)

# %%
# drop the column 'MP_RATIO' (we need only one output/y variable) and place the 'Log_MP_RATIO' as the last column in the dataframe

df=df.drop(columns=['MP_RATIO','Log_MP_RATIO']).assign(Log_MP_RATIO=df['Log_MP_RATIO'])

df
# Out:
#                                                   smiles        conc  \
# index
# 1                                     O=C(Nc1ccc(O)cc1)C   99.679085
# 2                           O(CCO)Cn1c2N=C(N)NC(=O)c2nc1   86.215294
# 3                Clc1cc2C(c3ccccc3)=NCc3n(c(C)nn3)-c2cc1   97.833694
# 4                                    [N+H3]C(Cc1ccccc1)C   99.669838
# 5      O=C(N[C@@H]1C(=O)N2[C@@H](C(=O)[O-])C(C)(C)S[C...   79.510864
# ...                                                  ...         ...
# 179         O=C(N)c1c(O)ccc(C(O)C[N+H2]C(CCc2ccccc2)C)c1   55.552212
# 180               ClC(Cl)(Cl)C(c1c(Cl)cccc1)c1ccc(Cl)cc1  100.000000
# 181                  ClC(Cl)=C(c1ccc(Cl)cc1)c1ccc(Cl)cc1  100.000000
# 182               ClC(Cl)(Cl)C(c1ccc(Cl)cc1)c1ccc(Cl)cc1  100.000000
# 183    Cl[C@H]1C(Cl)[C@@H](Cl)[C@@H]2[C@@]3(Cl)C(Cl)(...  100.000000
#
#                 name CLASS  ENV_CHEM  \
# index
# 1      Acetaminophen  DRUG         1
# 2          Acyclovir  DRUG         1
# 3         Alprazolam  DRUG         1
# 4        Amphetamine  DRUG         1
# 5         Ampicillin  DRUG         1
# ...              ...   ...       ...
# 179       labetalol   DRUG         1
# 180           op-DDT   ENV         0
# 181           pp-DDE   ENV         0
# 182           pp-DDT   ENV         0
# 183           t-NONA   ENV         0
#
#                                                 FP:MACCS  $DIVPRIO       apol  \
# index
# 1      92 110 113 117 131 133 135 139 143 151 152 154...         1  22.785137
# 2      25 28 38 43 65 72 75 77 78 79 80 82 83 84 85 8...        73  29.320723
# 3      19 38 52 62 65 77 78 79 80 83 85 87 94 96 100 ...        66  45.168308
# 4      49 84 104 111 115 151 155 156 158 160 161 162 ...         9  26.275103
# 5      8 11 19 36 47 49 54 66 74 79 81 83 84 85 88 92...        16  49.570274
# ...                                                  ...       ...        ...
# 179    49 53 54 82 84 89 90 92 95 97 100 104 110 111 ...        79  54.715824
# 180    87 103 106 107 112 125 134 144 145 150 162 163...        61  41.541138
# 181       21 50 76 87 99 103 107 125 134 145 162 163 165        14  38.694344
# 182           87 103 106 107 112 125 134 145 162 163 165       115  41.541138
# 183    66 76 87 96 99 101 103 105 107 112 134 150 163...        94  40.553967
#
#              ASA        ASA+  ...  $PRED_neutral_model_7  \
# index                         ...
# 1      341.43088  196.220180  ...              -0.246018
# 2      431.48679  317.577730  ...               0.274696
# 3      512.07532  248.789260  ...              -0.474589
# 4      349.46716  242.228820  ...               0.411452
# 5      561.79968  267.192260  ...              -0.879331
# ...          ...         ...  ...                    ...
# 179    628.47516  413.561190  ...              -0.467125
# 180    490.29086  142.239910  ...               0.353390
# 181    498.58255  141.864210  ...               0.391826
# 182    508.05460  134.185330  ...               0.537776
# 183    474.31766   40.688782  ...               0.565090
#
#        $PRED_ionized_model_516  $PRED_charged_and_3d_model1  $PREDCOMP  \
# index
# 1                    -0.198971                    -0.338185  -0.246018
# 2                     0.252062                     0.017201   0.274696
# 3                    -0.314985                    -0.465988  -0.474589
# 4                     0.465482                     0.167944   0.465482
# 5                    -0.344795                    -0.708340  -0.344795
# ...                        ...                          ...        ...
# 179                   0.162852                     0.130214   0.162852
# 180                  -0.868373                     0.323759   0.353390
# 181                  -0.630014                     0.152654   0.391826
# 182                  -0.910309                     0.383260   0.537776
# 183                   0.090766                     0.759818   0.565090
#
#        neutral  TEST  CHARGED  group       set  Log_MP_RATIO
# index
# 1            1     0        0      0  TRAINING     -0.119186
# 2            1     0        0      0  TRAINING      0.423246
# 3            1     0        0      0  TRAINING     -0.443698
# 4            0     0        1      1  TRAINING      0.711807
# 5            0     1        1      2  TRAINING     -0.530178
# ...        ...   ...      ...    ...       ...           ...
# 179          0     0        1      1  TRAINING      0.176091
# 180          1     0        0      0  TRAINING      0.472628
# 181          1     0        0      0  TRAINING      0.667194
# 182          1     0        0      0  TRAINING      0.850593
# 183          1     0        0      0  TRAINING      0.847938
#
# [183 rows x 495 columns]

# %% [markdown]
# ## 1. Drop all non numeric data

# %%
#Identify  non numeric columns
NonNumericCols = (df.select_dtypes(exclude='number')).columns
NonNumericCols
# Out:
# Index(['smiles', 'name', 'CLASS', 'FP:MACCS', 'set'], dtype='object')

# %%
#we need to store the 'set' column to split the data later 
df_set = df['set']
df_output = df['Log_MP_RATIO']
df_set
# Out:
# index
# 1      TRAINING
# 2      TRAINING
# 3      TRAINING
# 4      TRAINING
# 5      TRAINING
#          ...
# 179    TRAINING
# 180    TRAINING
# 181    TRAINING
# 182    TRAINING
# 183    TRAINING
# Name: set, Length: 183, dtype: object

# %%
# Drop non numeric columns
df=df.drop(columns=NonNumericCols)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 183
# Columns: 490 entries, conc to Log_MP_RATIO
# dtypes: float64(271), int64(219)
# memory usage: 702.0 KB

# %%
len(df.Log_MP_RATIO.value_counts())
# Out:
# 166

# %% [markdown]
# ##  2.  Drop feature containing \'$' in the first position
#     save DtaFrame to df1

# %%
#list of all the column names  containing '$' in the first position
cols_dollar_signe = [c for c in df.columns if c[0] == '$']

print(str(len(cols_dollar_signe)),'columns with $ signe : \n',cols_dollar_signe)
# Out:
# 5 columns with $ signe :
#  ['$DIVPRIO', '$PRED_neutral_model_7', '$PRED_ionized_model_516', '$PRED_charged_and_3d_model1', '$PREDCOMP']

# %%
df_cols_dollar_signe = df[cols_dollar_signe].join(df_output)
df_cols_dollar_signe
# Out:
#        $DIVPRIO  $PRED_neutral_model_7  $PRED_ionized_model_516  \
# index
# 1             1              -0.246018                -0.198971
# 2            73               0.274696                 0.252062
# 3            66              -0.474589                -0.314985
# 4             9               0.411452                 0.465482
# 5            16              -0.879331                -0.344795
# ...         ...                    ...                      ...
# 179          79              -0.467125                 0.162852
# 180          61               0.353390                -0.868373
# 181          14               0.391826                -0.630014
# 182         115               0.537776                -0.910309
# 183          94               0.565090                 0.090766
#
#        $PRED_charged_and_3d_model1  $PREDCOMP  Log_MP_RATIO
# index
# 1                        -0.338185  -0.246018     -0.119186
# 2                         0.017201   0.274696      0.423246
# 3                        -0.465988  -0.474589     -0.443698
# 4                         0.167944   0.465482      0.711807
# 5                        -0.708340  -0.344795     -0.530178
# ...                            ...        ...           ...
# 179                       0.130214   0.162852      0.176091
# 180                       0.323759   0.353390      0.472628
# 181                       0.152654   0.391826      0.667194
# 182                       0.383260   0.537776      0.850593
# 183                       0.759818   0.565090      0.847938
#
# [183 rows x 6 columns]

# %%
df_cols_dollar_signeToCsv = df_cols_dollar_signe.join(df_set)
df_cols_dollar_signeToCsv.to_csv('df_cols_dollar_signe.csv', encoding='utf-8')

# %%
#Drop the columns starting with $

df1=df.drop(cols_dollar_signe, axis=1)
df1
# Out:
#              conc  ENV_CHEM       apol        ASA        ASA+       ASA-  \
# index
# 1       99.679085         1  22.785137  341.43088  196.220180  145.21069
# 2       86.215294         1  29.320723  431.48679  317.577730  113.90907
# 3       97.833694         1  45.168308  512.07532  248.789260  263.28607
# 4       99.669838         1  26.275103  349.46716  242.228820  107.23836
# 5       79.510864         1  49.570274  561.79968  267.192260  262.83469
# ...           ...       ...        ...        ...         ...        ...
# 179     55.552212         1  54.715824  628.47516  413.561190  214.91400
# 180    100.000000         0  41.541138  490.29086  142.239910  348.05093
# 181    100.000000         0  38.694344  498.58255  141.864210  356.71835
# 182    100.000000         0  41.541138  508.05460  134.185330  373.86926
# 183    100.000000         0  40.553967  474.31766   40.688782  433.62888
#
#            ASA_H       ASA_P  a_acc  a_acid  ...  vsurf_Wp8     Weight  \
# index                                        ...
# 1      239.01727  102.413610      2       0  ...       0.00  151.16499
# 2      183.97377  247.513000      5       0  ...       1.25  225.20799
# 3      438.28427   73.791069      3       0  ...       0.00  308.77200
# 4      264.31046   85.156723      0       0  ...       0.00  136.21800
# 5      309.97708  251.822590      3       2  ...       0.00  348.40298
# ...          ...         ...    ...     ...  ...        ...        ...
# 179    414.99454  213.480650      3       0  ...       0.00  329.41998
# 180    352.38516  137.905700      0       0  ...       0.00  354.49100
# 181    494.35355    4.229017      0       0  ...       0.00  318.03000
# 182    366.44958  141.605030      0       0  ...       0.00  354.49100
# 183    141.29962  333.018040      0       0  ...       0.00  444.22699
#
#        weinerPath  weinerPol  zagreb  neutral  TEST  CHARGED  group  \
# index
# 1             166         11      50        1     0        0      0
# 2             453         22      80        1     0        0      0
# 3             926         40     122        1     0        0      0
# 4             126          9      44        0     0        1      1
# 5            1365         39     132        0     1        1      2
# ...           ...        ...     ...      ...   ...      ...    ...
# 179          1607         33     116        0     0        1      1
# 180           654         29      98        1     0        0      0
# 181           603         26      90        1     0        0      0
# 182           678         28      98        1     0        0      0
# 183           527         49     120        1     0        0      0
#
#        Log_MP_RATIO
# index
# 1         -0.119186
# 2          0.423246
# 3         -0.443698
# 4          0.711807
# 5         -0.530178
# ...             ...
# 179        0.176091
# 180        0.472628
# 181        0.667194
# 182        0.850593
# 183        0.847938
#
# [183 rows x 485 columns]

# %%
# #save df1 to csv
# dfToCsv = df1.join(df_set)
# dfToCsv.to_csv('df1_clean.csv', encoding='utf-8')

# %% [markdown]
# ## List of important descriptors from Table 5 in Materials and Methods .

# %%
# Molecular QSAR Descriptors Important for Predicting Milk:Serum Partitioning.

important_descriptors = ['DASA', 'h_logS','ASA-', 'ASA_H', 'Weight', 'a_acc', 'b_1rotN', 'h_logP', 'CASA-', 'FCASA+','h_ema', 'h_mr', 'GCUT_PEOE_1', 'GCUT_SLOGP_2' ,'KierFlex', 'vsurf_DD13', 'density', 'SMR_VSA2', 'SMR_VSA7', 'MACCS(-50)','vsurf_D4', 'GCUT_SMR_2', 'b_rotR']
print(len(important_descriptors), 'Molecular QSAR Descriptors Important for Predicting Milk:Serum Partitioning \n \n' , important_descriptors)
# Out:
# 23 Molecular QSAR Descriptors Important for Predicting Milk:Serum Partitioning
#
#  ['DASA', 'h_logS', 'ASA-', 'ASA_H', 'Weight', 'a_acc', 'b_1rotN', 'h_logP', 'CASA-', 'FCASA+', 'h_ema', 'h_mr', 'GCUT_PEOE_1', 'GCUT_SLOGP_2', 'KierFlex', 'vsurf_DD13', 'density', 'SMR_VSA2', 'SMR_VSA7', 'MACCS(-50)', 'vsurf_D4', 'GCUT_SMR_2', 'b_rotR']

# %%
# check if all important_descriptors are present in df
i = 0 
missing = []
for descrtor in important_descriptors:
    if descrtor not in df1.columns:
        i+=1
        missing.append(descrtor)
print(i, missing, 'missing from df')
# Out:
# 0 [] missing from df

# %%
X_important_descriptors = df[important_descriptors]
df_important_descriptors = X_important_descriptors.join(df_output)

df_important_descriptors
# Out:
#              DASA    h_logS       ASA-      ASA_H     Weight  a_acc  b_1rotN  \
# index
# 1       51.009487 -1.473223  145.21069  239.01727  151.16499      2        1
# 2      203.668660 -0.556664  113.90907  183.97377  225.20799      5        4
# 3       14.496816 -5.238906  263.28607  438.28427  308.77200      3        1
# 4      134.990460  0.935879  107.23836  264.31046  136.21800      0        2
# 5        4.357579 -3.348349  262.83469  309.97708  348.40298      3        4
# ...           ...       ...        ...        ...        ...    ...      ...
# 179    198.647170 -1.234429  214.91400  414.99454  329.41998      3        8
# 180    205.811040 -6.720540  348.05093  352.38516  354.49100      0        2
# 181    214.854140 -6.688584  356.71835  494.35355  318.03000      0        2
# 182    239.683940 -6.693564  373.86926  366.44958  354.49100      0        2
# 183    392.940060 -6.881867  433.62888  141.29962  444.22699      0        0
#
#          h_logP       CASA-    FCASA+  ...  KierFlex  vsurf_DD13   density  \
# index                                  ...
# 1      1.088146   352.57156  1.395945  ...  1.503828    6.576473  0.742036
# 2     -1.669814   491.74542  3.177347  ...  2.109547    0.500000  0.853826
# 3      3.701848   745.62616  1.376399  ...  2.358810    0.866025  0.772703
# 4     -3.046292   214.79842  2.081492  ...  1.853780    0.707107  0.617172
# 5      0.415558  1837.47730  2.848848  ...  3.599823    0.500000  0.821163
# ...         ...         ...       ...  ...       ...         ...       ...
# 179   -1.446789  1158.60140  4.206185  ...  4.946094    0.500000  0.704018
# 180    7.081489   943.91418  0.786497  ...  6.354181    0.500000  0.951700
# 181    7.184247   674.55438  0.537771  ...  5.160360    6.500000  0.907039
# 182    7.047357  1013.93350  0.716018  ...  6.354181    0.866025  0.951700
# 183    6.608015  1071.06320  0.211886  ...  8.114878    0.500000  1.254165
#
#         SMR_VSA2    SMR_VSA7  MACCS(-50)  vsurf_D4  GCUT_SMR_2    b_rotR  \
# index
# 1       0.000000   33.326015           0   162.125    0.206710  0.181818
# 2      18.010750    0.000000           0   129.875    0.174109  0.235294
# 3       0.000000   72.474655           0   337.000    0.205528  0.040000
# 4      32.897186   33.326015           0   201.375    0.169076  0.200000
# 5      18.010750   98.871574           0   220.375    0.194394  0.192308
# ...          ...         ...         ...       ...         ...       ...
# 179     0.000000   33.326015           0   331.125    0.193051  0.320000
# 180     0.000000  195.743230           0   378.250    0.425300  0.150000
# 181     3.185575  156.594570           1   390.000    0.408469  0.105263
# 182     0.000000  195.743230           0   399.000    0.425300  0.150000
# 183     8.821592  352.337800           0   369.875    0.510980  0.000000
#
#        Log_MP_RATIO
# index
# 1         -0.119186
# 2          0.423246
# 3         -0.443698
# 4          0.711807
# 5         -0.530178
# ...             ...
# 179        0.176091
# 180        0.472628
# 181        0.667194
# 182        0.850593
# 183        0.847938
#
# [183 rows x 24 columns]

# %%
#save df_important_descriptors to csv
dfToCsv = df_important_descriptors.join(df_set)
dfToCsv.to_csv('df_important_descriptors.csv', encoding='utf-8')

# %%
def save_df(filename, df, df_set):
    dfToCsv = df.join(df_set)
    dfToCsv.to_csv('{filename}.csv', encoding='utf-8')

# %% [markdown]
# ## 3. Drop all constant features
#     save DataFrame to df2

# %%
#Get all columns with constant value (variance = zero) in df1
df_var = df1.var(axis=0)
nb_var_zero=0
listParamsVarZero=[]
for index, value in df_var.items():
    if value == 0:
        nb_var_zero+= 1                # nomble de descripteur constant
        listParamsVarZero.append(index) #liste des descripteurs constant
print('Number of descriptor with constant value = '+ str(nb_var_zero)+'\n')
print(listParamsVarZero)
# Out:
# Number of descriptor with constant value = 30
#
# ['a_nB', 'a_nI', 'a_nP', 'E_stb', 'MACCS(--1)', 'MACCS(--2)', 'MACCS(--3)', 'MACCS(--4)', 'MACCS(--5)', 'MACCS(--6)', 'MACCS(--7)', 'MACCS(--9)', 'MACCS(-10)', 'MACCS(-12)', 'MACCS(-14)', 'MACCS(-15)', 'MACCS(-18)', 'MACCS(-20)', 'MACCS(-27)', 'MACCS(-29)', 'MACCS(-30)', 'MACCS(-31)', 'MACCS(-35)', 'MACCS(-39)', 'MACCS(-40)', 'MACCS(-44)', 'MACCS(-48)', 'MACCS(-68)', 'MACCS(166)', 'nmol']

# %%
#drop constant descriptor
df2=df1.drop(columns=listParamsVarZero)
df2.shape
# Out:
# (183, 455)

# %%
df2
# Out:
#              conc  ENV_CHEM       apol        ASA        ASA+       ASA-  \
# index
# 1       99.679085         1  22.785137  341.43088  196.220180  145.21069
# 2       86.215294         1  29.320723  431.48679  317.577730  113.90907
# 3       97.833694         1  45.168308  512.07532  248.789260  263.28607
# 4       99.669838         1  26.275103  349.46716  242.228820  107.23836
# 5       79.510864         1  49.570274  561.79968  267.192260  262.83469
# ...           ...       ...        ...        ...         ...        ...
# 179     55.552212         1  54.715824  628.47516  413.561190  214.91400
# 180    100.000000         0  41.541138  490.29086  142.239910  348.05093
# 181    100.000000         0  38.694344  498.58255  141.864210  356.71835
# 182    100.000000         0  41.541138  508.05460  134.185330  373.86926
# 183    100.000000         0  40.553967  474.31766   40.688782  433.62888
#
#            ASA_H       ASA_P  a_acc  a_acid  ...  vsurf_Wp8     Weight  \
# index                                        ...
# 1      239.01727  102.413610      2       0  ...       0.00  151.16499
# 2      183.97377  247.513000      5       0  ...       1.25  225.20799
# 3      438.28427   73.791069      3       0  ...       0.00  308.77200
# 4      264.31046   85.156723      0       0  ...       0.00  136.21800
# 5      309.97708  251.822590      3       2  ...       0.00  348.40298
# ...          ...         ...    ...     ...  ...        ...        ...
# 179    414.99454  213.480650      3       0  ...       0.00  329.41998
# 180    352.38516  137.905700      0       0  ...       0.00  354.49100
# 181    494.35355    4.229017      0       0  ...       0.00  318.03000
# 182    366.44958  141.605030      0       0  ...       0.00  354.49100
# 183    141.29962  333.018040      0       0  ...       0.00  444.22699
#
#        weinerPath  weinerPol  zagreb  neutral  TEST  CHARGED  group  \
# index
# 1             166         11      50        1     0        0      0
# 2             453         22      80        1     0        0      0
# 3             926         40     122        1     0        0      0
# 4             126          9      44        0     0        1      1
# 5            1365         39     132        0     1        1      2
# ...           ...        ...     ...      ...   ...      ...    ...
# 179          1607         33     116        0     0        1      1
# 180           654         29      98        1     0        0      0
# 181           603         26      90        1     0        0      0
# 182           678         28      98        1     0        0      0
# 183           527         49     120        1     0        0      0
#
#        Log_MP_RATIO
# index
# 1         -0.119186
# 2          0.423246
# 3         -0.443698
# 4          0.711807
# 5         -0.530178
# ...             ...
# 179        0.176091
# 180        0.472628
# 181        0.667194
# 182        0.850593
# 183        0.847938
#
# [183 rows x 455 columns]

# %%
# save df2 
save_df('df2', df2, df_set)

# %% [markdown]
# ## 9. Find highly correlated features (> 0.95)
#
#     * One of the assumptions of linear regression is that the independent variables need to be uncorrelated with each other
#     * save the dataframe to df4 and csv : drop_correlated_features.csv

# %%
# function to create correlation matrix plot using Pearson Correlation
def corr_matrix_plot(df):
    f, ax = plt.subplots(figsize=(12, 10))
    corr = df.corr()
    sns.heatmap(corr, mask=np.zeros_like(corr),
                cmap=sns.diverging_palette(220, 10, as_cmap=True),
                square=True, ax=ax)
    

corr_matrix_plot(df2)

# %%
# https://github.com/adityav95/variable_reduction_correlation/blob/master/variable_reduction_by_correlation.ipynb
# Cross-correlation (dropping by mean correlation with all features)


""" The function retuns a list of features to be dropped from the input features.

INPUTS:
1. df_input: n input features (pandas dataframe)
2. corr_coeff: Coefficient threshold (absolute value, no negatives) for a pair of variables above
   which one of the two will be dropped
3. plot: If set to 1 a plot will be displayed showing a heatmap of the cross-correlation between variables 
4. savefile: If set to 1, all relevant files will be saved

PLEASE NOTE:
- The dataframe df_input (should contain only the n input features i.e. no ID and targets) 

SUMMARY OF LOGIC:
1. The n input variables are taken and a n X n matrix of correlation is created (these are absolute values
   i.e. a correlation of -0.8 is treated as 0.8)
2. Variable pairs with correlation higher than the corr_coeff threshold are picked and one of 
   the two variables will be dropped
3. Which of the two will be dropped is based on the one having lower mean absolute correlation with 
   all other variables 

SAVED FILES:
If savefile is set to 1. Saved under current directory under cross_corr_target under folder with a 
   UTC timestamp.
1. A PDF heatmap representing the cross correlation between all the input features
2. A CSV of the matrix containing the values used for the heatmap
3. A CSV of the list of variables to be dropped
"""
def cross_corr_mean(df_input, corr_coeff=0.95, plot=0, savefile=0):
    # Pre-processing
    if savefile == 1:
        from datetime import datetime
        time = str(datetime.utcnow())
        import os
        path = str(os.getcwd()) + "/cross_corr_mean/" + str(time[0:19].replace(':',"-")) + "/"
        os.makedirs(path)

    # Generating correlation matrix of input features
    corr_matrix = df_input.corr(method = 'pearson') # For more info on the methods please refer to https://www.kaggle.com/kiyoung1027/correlation-pearson-spearman-and-kendall

    # Plotting cross correlation matrix
    if plot == 1:
        import matplotlib.pyplot as plt
        import seaborn as sns
        plt.figure(figsize=(10,8))
        sns.heatmap(corr_matrix.round(2), cmap=plt.cm.Blues)
        fig = plt.gcf()
        plt.show()
        if savefile == 1:
            fig.savefig(path + "cross_corr_heatmap.pdf")

    # Generating correlation with the target
    corr_mean = abs(corr_matrix).mean()

    # Saving files
    if savefile ==1:
        corr_matrix.to_csv(path + "cross_corr.csv")
        corr_mean.to_csv(path + "corr_abs_mean.csv")

    # Preparing data
    features_drop_list = [] # This will contain the list of features to be dropped
    features_index_drop_list = [] # This will contain the index of features to be dropped as per df_input
    corr_matrix = abs(corr_matrix)

    # Selecting features to be dropped (Using two for loops that runs on one triangle of the corr_matrix to avoid checking the correlation of a variable with itself)
    for i in range(corr_matrix.shape[0]):
        for j in range(i+1,corr_matrix.shape[0]):

            # The following if statement checks if each correlation value is higher than threshold (or equal) and also ensures the two columns have NOT been dropped already.  
            if corr_matrix.iloc[i,j]>=corr_coeff and i not in features_index_drop_list and j not in features_index_drop_list:

                # The following if statement checks which of the 2 variables with high correlation has a lower correlation with target and then drops it. If equal we can drop any and it drops the first one (This is arbitrary)
                if corr_mean[corr_matrix.columns[i]] >= corr_mean[corr_matrix.columns[j]]:
                    features_drop_list.append(corr_matrix.columns[i])	# Name of variable that needs to be dropped appended to list
                    features_index_drop_list.append(i)	# Index of variable that needs to be dropped appended to list. This is used to not check for the same variables repeatedly
                else:
                    features_drop_list.append(corr_matrix.columns[j])
                    features_index_drop_list.append(j)

    # Saving final list
    if savefile ==1:
        pd.Series(features_drop_list).to_csv(path + "features_drop_list.csv")

    return features_drop_list

# %%
df_input = df2.drop(columns=['Log_MP_RATIO'])
dropList=cross_corr_mean(df_input)
print(len(dropList), dropList)
# Out:
# 123 ['apol', 'ASA', 'FCASA+', 'Q_VSA_POS', 'Q_VSA_HYD', 'a_acc', 'vsa_acid', 'a_aro', 'a_IC', 'bpol', 'a_count', 'a_heavy', 'a_nBr', 'chi0v_C', 'chi0_C', 'a_nCl', 'a_nF', 'a_nN', 'a_nO', 'a_nS', 'BCUT_PEOE_0', 'BCUT_PEOE_3', 'BCUT_SLOGP_0', 'b_rotN', 'b_rotR', 'b_single', 'CASA+', 'b_heavy', 'chi1', 'Kier1', 'chi0', 'chi1v', 'SMR', 'vol', 'vsurf_V', 'chi1v_C', 'diameter', 'E_nb', 'FASA-', 'Q_VSA_FNEG', 'Q_VSA_FPOS', 'FASA_H', 'Q_VSA_FHYD', 'Q_VSA_FPOL', 'h_pavgQ', 'GCUT_PEOE_3', 'GCUT_SMR_3', 'vsurf_HB5', 'h_logD', 'h_logP', 'logS', 'h_log_dbo', 'h_mr', 'h_pstates', 'MACCS(-32)', 'PEOE_VSA-3', 'neutral', 'MACCS(-49)', 'MACCS(-51)', 'MACCS(-55)', 'MACCS(-56)', 'MACCS(-60)', 'MACCS(-61)', 'MACCS(-67)', 'MACCS(-88)', 'MACCS(-87)', 'MACCS(107)', 'MACCS(148)', 'MACCS(153)', 'MACCS(146)', 'MACCS(161)', 'MACCS(160)', 'MACCS(164)', 'MACCS(165)', 'vdw_area', 'vdw_vol', 'VSA', 'vsurf_S', 'rings', 'PC+', 'PC-', 'Q_PC-', 'PEOE_VSA_FHYD', 'PEOE_VSA_FNEG', 'vsa_hyd', 'PEOE_VSA_NEG', 'TPSA', 'petitjeanSC', 'pmi', 'pmi3', 'Q_RPC+', 'Q_RPC-', 'VAdjEq', 'VDistMa', 'vsurf_W4', 'vsa_pol', 'vsurf_CW4', 'vsurf_CW5', 'vsurf_D2', 'vsurf_D1', 'vsurf_D4', 'vsurf_D5', 'vsurf_D6', 'vsurf_D7', 'vsurf_EDmin2', 'vsurf_EDmin3', 'vsurf_EWmin2', 'vsurf_EWmin3', 'vsurf_HB2', 'vsurf_HB4', 'vsurf_W3', 'vsurf_HB6', 'vsurf_HB7', 'vsurf_W7', 'vsurf_HB8', 'vsurf_HL1', 'vsurf_ID2', 'vsurf_ID1', 'vsurf_ID4', 'vsurf_ID5', 'vsurf_W5', 'vsurf_Wp4', 'zagreb']

# %%
#Corr_list_to_drop fuction returns a correlation matrix list between features, to drop
def Corr_list_to_drop(X, corr_poucent):
    corr_matrix = X.corr().abs()  #Calculate the absolute value element-wise
    high_corr_var=np.where(corr_matrix>=corr_poucent)
    high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
    #Selecting the Upper trigular matrix
    upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))
    
    #select the columns having absolute correlation 
    to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > corr_poucent)]
    return to_drop

# %%
# list of features having 95% corrolation
X_df2 = df2.drop(columns=['Log_MP_RATIO'])
to_drop = Corr_list_to_drop(X_df2,0.95)
print(len(to_drop), to_drop)
# Out:
# 130 ['a_donacc', 'a_IC', 'a_nC', 'BCUT_SMR_0', 'BCUT_SMR_3', 'bpol', 'b_ar', 'b_count', 'b_heavy', 'b_rotN', 'b_rotR', 'b_single', 'CASA+', 'chi0', 'chi0v_C', 'chi0_C', 'chi1', 'chi1v', 'chi1_C', 'E_nb', 'FASA-', 'FASA_P', 'FCASA+', 'GCUT_SLOGP_0', 'GCUT_SMR_0', 'GCUT_SMR_3', 'h_logP', 'h_logS', 'h_mr', 'h_pavgQ', 'h_pstrain', 'Kier1', 'logS', 'MACCS(-33)', 'MACCS(-42)', 'MACCS(-46)', 'MACCS(-51)', 'MACCS(-55)', 'MACCS(-58)', 'MACCS(-60)', 'MACCS(-61)', 'MACCS(-63)', 'MACCS(-67)', 'MACCS(-73)', 'MACCS(-81)', 'MACCS(-88)', 'MACCS(103)', 'MACCS(107)', 'MACCS(134)', 'MACCS(142)', 'MACCS(146)', 'MACCS(148)', 'MACCS(153)', 'MACCS(159)', 'MACCS(160)', 'MACCS(161)', 'MACCS(164)', 'mr', 'opr_brigid', 'PEOE_PC-', 'PEOE_VSA-3', 'PEOE_VSA_FPOL', 'PEOE_VSA_FPOS', 'PEOE_VSA_POS', 'petitjeanSC', 'pmi2', 'pmi3', 'Q_PC+', 'Q_PC-', 'Q_VSA_FHYD', 'Q_VSA_FNEG', 'Q_VSA_FPOL', 'Q_VSA_FPOS', 'Q_VSA_HYD', 'Q_VSA_NEG', 'Q_VSA_POS', 'radius', 'rings', 'RPC+', 'RPC-', 'SlogP', 'SMR', 'SMR_VSA6', 'TPSA', 'VAdjMa', 'VDistMa', 'vdw_area', 'vdw_vol', 'vol', 'VSA', 'vsa_acid', 'vsa_hyd', 'vsa_pol', 'vsurf_CW5', 'vsurf_CW6', 'vsurf_D2', 'vsurf_D3', 'vsurf_D4', 'vsurf_D5', 'vsurf_D6', 'vsurf_D7', 'vsurf_D8', 'vsurf_EDmin2', 'vsurf_EDmin3', 'vsurf_EWmin2', 'vsurf_EWmin3', 'vsurf_HB2', 'vsurf_HB3', 'vsurf_HB4', 'vsurf_HB5', 'vsurf_HB6', 'vsurf_HB7', 'vsurf_HB8', 'vsurf_HL2', 'vsurf_ID2', 'vsurf_ID3', 'vsurf_ID4', 'vsurf_ID5', 'vsurf_S', 'vsurf_V', 'vsurf_W3', 'vsurf_W4', 'vsurf_W5', 'vsurf_W6', 'vsurf_W7', 'vsurf_W8', 'vsurf_Wp5', 'zagreb', 'neutral', 'CHARGED']

# %%
# function to return a list of commun elements between 2 lists
def communElem(list1, list2):  
    communElem = []
    print(len(list1), ' elements in the first list')
    print(len(list2), ' elements in the first list')
    for elem in list1:
        if elem in list2:
            communElem.append(elem)
    return communElem
      
print(len(communElem(dropList,to_drop)), communElem(dropList,to_drop))
# Out:
# 123  elements in the first list
# 130  elements in the first list
# 123  elements in the first list
# 130  elements in the first list
# 82 ['FCASA+', 'Q_VSA_POS', 'Q_VSA_HYD', 'vsa_acid', 'a_IC', 'bpol', 'chi0v_C', 'chi0_C', 'b_rotN', 'b_rotR', 'b_single', 'CASA+', 'b_heavy', 'chi1', 'Kier1', 'chi0', 'chi1v', 'SMR', 'vol', 'vsurf_V', 'E_nb', 'FASA-', 'Q_VSA_FNEG', 'Q_VSA_FPOS', 'Q_VSA_FHYD', 'Q_VSA_FPOL', 'h_pavgQ', 'GCUT_SMR_3', 'vsurf_HB5', 'h_logP', 'logS', 'h_mr', 'PEOE_VSA-3', 'neutral', 'MACCS(-51)', 'MACCS(-55)', 'MACCS(-60)', 'MACCS(-61)', 'MACCS(-67)', 'MACCS(-88)', 'MACCS(107)', 'MACCS(148)', 'MACCS(153)', 'MACCS(146)', 'MACCS(161)', 'MACCS(160)', 'MACCS(164)', 'vdw_area', 'vdw_vol', 'VSA', 'vsurf_S', 'rings', 'Q_PC-', 'vsa_hyd', 'TPSA', 'petitjeanSC', 'pmi3', 'VDistMa', 'vsurf_W4', 'vsa_pol', 'vsurf_CW5', 'vsurf_D2', 'vsurf_D4', 'vsurf_D5', 'vsurf_D6', 'vsurf_D7', 'vsurf_EDmin2', 'vsurf_EDmin3', 'vsurf_EWmin2', 'vsurf_EWmin3', 'vsurf_HB2', 'vsurf_HB4', 'vsurf_W3', 'vsurf_HB6', 'vsurf_HB7', 'vsurf_W7', 'vsurf_HB8', 'vsurf_ID2', 'vsurf_ID4', 'vsurf_ID5', 'vsurf_W5', 'zagreb']

# %%
print(len(communElem(dropList,to_drop)), communElem(dropList,to_drop))
# Out:
# 123  elements in the first list
# 130  elements in the first list
# 123  elements in the first list
# 130  elements in the first list
# 82 ['FCASA+', 'Q_VSA_POS', 'Q_VSA_HYD', 'vsa_acid', 'a_IC', 'bpol', 'chi0v_C', 'chi0_C', 'b_rotN', 'b_rotR', 'b_single', 'CASA+', 'b_heavy', 'chi1', 'Kier1', 'chi0', 'chi1v', 'SMR', 'vol', 'vsurf_V', 'E_nb', 'FASA-', 'Q_VSA_FNEG', 'Q_VSA_FPOS', 'Q_VSA_FHYD', 'Q_VSA_FPOL', 'h_pavgQ', 'GCUT_SMR_3', 'vsurf_HB5', 'h_logP', 'logS', 'h_mr', 'PEOE_VSA-3', 'neutral', 'MACCS(-51)', 'MACCS(-55)', 'MACCS(-60)', 'MACCS(-61)', 'MACCS(-67)', 'MACCS(-88)', 'MACCS(107)', 'MACCS(148)', 'MACCS(153)', 'MACCS(146)', 'MACCS(161)', 'MACCS(160)', 'MACCS(164)', 'vdw_area', 'vdw_vol', 'VSA', 'vsurf_S', 'rings', 'Q_PC-', 'vsa_hyd', 'TPSA', 'petitjeanSC', 'pmi3', 'VDistMa', 'vsurf_W4', 'vsa_pol', 'vsurf_CW5', 'vsurf_D2', 'vsurf_D4', 'vsurf_D5', 'vsurf_D6', 'vsurf_D7', 'vsurf_EDmin2', 'vsurf_EDmin3', 'vsurf_EWmin2', 'vsurf_EWmin3', 'vsurf_HB2', 'vsurf_HB4', 'vsurf_W3', 'vsurf_HB6', 'vsurf_HB7', 'vsurf_W7', 'vsurf_HB8', 'vsurf_ID2', 'vsurf_ID4', 'vsurf_ID5', 'vsurf_W5', 'zagreb']

# %%
 #https://likegeeks.com/python-correlation-matrix/
#Sorting the correlation matrix
    #1. convert the given matrix into a one-dimensional Series of values.
correlation_mat = df2.corr().abs()

print('____________________________')
corr_pairs = correlation_mat.unstack()

print(corr_pairs.shape)

    #2. sort the values using the sort_values() 
sorted_pairs = corr_pairs.sort_values(kind="quicksort")
print('____________________________')
print(sorted_pairs)
# Out:
# ____________________________
# (207025,)
# ____________________________
# BCUT_SMR_1    vsurf_CW3       0.000001
# vsurf_CW3     BCUT_SMR_1      0.000001
# KierFlex      MACCS(160)      0.000009
# MACCS(160)    KierFlex        0.000009
# MACCS(-52)    MACCS(150)      0.000017
#                                 ...
# PEOE_VSA_NEG  PEOE_VSA_NEG    1.000000
# neutral       MACCS(-49)      1.000000
#               CHARGED         1.000000
# MACCS(-49)    neutral         1.000000
# CHARGED       neutral         1.000000
# Length: 207025, dtype: float64

# %%
#Corr_list_relevant_features fuction returns a correlation matrix list between features and output, to keep
def Corr_list_with_output(df, target=0.5):
    cor = df.corr()      # Using Pearson Correlation
    cor_target = abs(cor['Log_MP_RATIO'])
    #Selecting highly correlated features
    features = cor_target[cor_target>target]
    return features

# %%
relevant_features = Corr_list_with_output(df2).sort_values(kind="quicksort")

print(len(relevant_features) ,'Number of descriptors correlated with y to keep','\n', relevant_features)
# Out:
# 38 Number of descriptors correlated with y to keep
#  vsurf_W4          0.500097
# a_acid            0.500293
# E_sol             0.502328
# vsurf_ID1         0.503618
# vsurf_ID2         0.504370
# h_ema             0.505217
# vsurf_HB5         0.505374
# vsurf_CW4         0.507663
# vsa_acid          0.510706
# vsurf_HB6         0.510886
# vsurf_W5          0.511460
# vsurf_W6          0.513319
# PEOE_VSA_FHYD     0.516797
# PEOE_VSA_FPOL     0.516797
# GCUT_SMR_2        0.520091
# vsurf_CW5         0.522737
# MACCS(134)        0.525753
# MACCS(-87)        0.526146
# TPSA              0.531526
# PEOE_VSA_POL      0.535125
# vsa_pol           0.537606
# vsurf_CW6         0.538361
# GCUT_SLOGP_1      0.538647
# b_double          0.543089
# DASA              0.547024
# MACCS(107)        0.552171
# SlogP             0.560981
# PEOE_VSA_PNEG     0.572234
# PEOE_VSA_FPNEG    0.577693
# ENV_CHEM          0.582632
# vsa_acc           0.584741
# vsurf_EWmin2      0.586677
# vsurf_EWmin3      0.588231
# vsurf_EWmin1      0.590682
# SMR_VSA0          0.596317
# MACCS(154)        0.597222
# GCUT_SLOGP_2      0.600831
# Log_MP_RATIO      1.000000
# Name: Log_MP_RATIO, dtype: float64

# %%
df_relevant_features=df1[relevant_features.index]
df_relevant_features
# Out:
#        vsurf_W4  a_acid       E_sol  vsurf_ID1  vsurf_ID2      h_ema  \
# index
# 1        60.125       0  -17.289808   0.534114   0.592329   2.807268
# 2       207.125       0  -28.662804   0.419048   0.472217   9.401648
# 3        89.000       0  -19.286819   1.108302   0.949276   6.998776
# 4        17.875       0  -74.318977   0.957445   0.731199   0.000000
# 5       224.375       2 -111.944730   1.564881   1.545264  12.811975
# ...         ...     ...         ...        ...        ...        ...
# 179     133.250       0  -73.292038   1.636585   1.479004   3.944437
# 180       0.000       0   -5.243302   0.245388   0.213638   1.397877
# 181       0.000       0   -2.048312   0.165911   0.147808   0.884502
# 182       0.000       0   -4.709925   0.302262   0.224857   1.408016
# 183       0.125       0   -7.521484   0.060463   0.029051   2.719147
#
#        vsurf_HB5  vsurf_CW4   vsa_acid  vsurf_HB6  ...  PEOE_VSA_FPNEG  \
# index                                              ...
# 1         10.000   0.530227   0.000000     -0.375  ...        0.129231
# 2         69.125   1.170379   0.000000     33.125  ...        0.161277
# 3         40.875   0.398057   0.000000     14.000  ...        0.019991
# 4        -12.375   0.187871   0.000000     -1.250  ...        0.006582
# 5         81.125   0.980341  27.133842     36.125  ...        0.186829
# ...          ...        ...        ...        ...  ...             ...
# 179       37.000   0.540022   0.000000     20.625  ...        0.100604
# 180        0.000   0.000000   0.000000      0.000  ...        0.000000
# 181        0.000   0.000000   0.000000      0.000  ...        0.000000
# 182        0.000   0.000000   0.000000      0.000  ...        0.000000
# 183        0.000   0.000005   0.000000      0.000  ...        0.000000
#
#        ENV_CHEM    vsa_acc  vsurf_EWmin2  vsurf_EWmin3  vsurf_EWmin1  \
# index
# 1             1  13.566921     -4.501601     -4.495557     -4.591724
# 2             1  27.435829     -7.737467     -7.734310     -7.756833
# 3             1  24.524654     -5.387553     -5.232655     -5.495107
# 4             1   0.000000     -3.024735     -2.995125     -3.044288
# 5             1  54.267685     -7.296841     -7.204403     -7.492854
# ...         ...        ...           ...           ...           ...
# 179           1  13.566921     -6.865585     -6.721995     -7.182785
# 180           0   0.000000     -1.898758     -1.893961     -1.908710
# 181           0   0.000000     -1.663281     -1.649255     -1.703724
# 182           0   0.000000     -1.848760     -1.743012     -1.990883
# 183           0   0.000000     -1.860372     -1.810575     -2.011065
#
#          SMR_VSA0  MACCS(154)  GCUT_SLOGP_2  Log_MP_RATIO
# index
# 1       23.862217           1      0.123895     -0.119186
# 2       34.862103           1      0.047797      0.423246
# 3        0.000000           0      0.155151     -0.443698
# 4        0.000000           0      0.142107      0.711807
# 5      114.269990           3      0.109960     -0.530178
# ...           ...         ...           ...           ...
# 179     23.862217           1      0.145267      0.176091
# 180      0.000000           0      0.481420      0.472628
# 181      0.000000           0      0.409728      0.667194
# 182      0.000000           0      0.482633      0.850593
# 183      0.000000           0      0.570088      0.847938
#
# [183 rows x 38 columns]

# %%
# df_relevant_features corrolation plot
corr_matrix_plot(df_relevant_features)

# %%
# list of features corrolated with output corrolated with each other to drop
df_input_corrWithOutput = df_relevant_features.drop(columns=['Log_MP_RATIO'])
dropList_corrWithOutput=cross_corr_mean(df_input_corrWithOutput)
print(len(dropList_corrWithOutput), dropList_corrWithOutput)
# Out:
# 13 ['vsurf_W4', 'vsa_acid', 'vsurf_ID2', 'vsurf_HB5', 'vsurf_CW5', 'vsurf_W5', 'vsurf_W6', 'PEOE_VSA_FHYD', 'MACCS(107)', 'PEOE_VSA_POL', 'vsa_pol', 'vsurf_EWmin3', 'vsurf_EWmin2']

# %%
# # List of less corrolated features <0.1
# cor = df.corr()      # Using Pearson Correlation
# cor_target = abs(cor['Log_MP_RATIO'])
#     #Selecting highly correlated features
# zero_cor_features = cor_target[cor_target<0.1]
    


# print(len(zero_cor_features) ,'Number of descriptors not correlated with y ','\n', zero_cor_features)

# %%
#Drop highly correlated feature

df2 = df2.drop(columns=dropList)
df2
# Out:
#              conc  ENV_CHEM        ASA+       ASA-      ASA_H       ASA_P  \
# index
# 1       99.679085         1  196.220180  145.21069  239.01727  102.413610
# 2       86.215294         1  317.577730  113.90907  183.97377  247.513000
# 3       97.833694         1  248.789260  263.28607  438.28427   73.791069
# 4       99.669838         1  242.228820  107.23836  264.31046   85.156723
# 5       79.510864         1  267.192260  262.83469  309.97708  251.822590
# ...           ...       ...         ...        ...        ...         ...
# 179     55.552212         1  413.561190  214.91400  414.99454  213.480650
# 180    100.000000         0  142.239910  348.05093  352.38516  137.905700
# 181    100.000000         0  141.864210  356.71835  494.35355    4.229017
# 182    100.000000         0  134.185330  373.86926  366.44958  141.605030
# 183    100.000000         0   40.688782  433.62888  141.29962  333.018040
#
#        a_acid  a_base  a_don  a_donacc  ...  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  \
# index                                   ...
# 1           0       0      2         4  ...      3.000      0.000       0.00
# 2           0       0      3         8  ...     11.125      4.625       1.25
# 3           0       0      0         3  ...      0.000      0.000       0.00
# 4           0       1      0         0  ...      1.250      0.000       0.00
# 5           2       0      2         5  ...      3.875      0.000       0.00
# ...       ...     ...    ...       ...  ...        ...        ...        ...
# 179         0       1      3         6  ...      4.375      0.375       0.00
# 180         0       0      0         0  ...      0.000      0.000       0.00
# 181         0       0      0         0  ...      0.000      0.000       0.00
# 182         0       0      0         0  ...      0.000      0.000       0.00
# 183         0       0      0         0  ...      0.000      0.000       0.00
#
#           Weight  weinerPath  weinerPol  TEST  CHARGED  group  Log_MP_RATIO
# index
# 1      151.16499         166         11     0        0      0     -0.119186
# 2      225.20799         453         22     0        0      0      0.423246
# 3      308.77200         926         40     0        0      0     -0.443698
# 4      136.21800         126          9     0        1      1      0.711807
# 5      348.40298        1365         39     1        1      2     -0.530178
# ...          ...         ...        ...   ...      ...    ...           ...
# 179    329.41998        1607         33     0        1      1      0.176091
# 180    354.49100         654         29     0        0      0      0.472628
# 181    318.03000         603         26     0        0      0      0.667194
# 182    354.49100         678         28     0        0      0      0.850593
# 183    444.22699         527         49     0        0      0      0.847938
#
# [183 rows x 332 columns]

# %% [markdown]
# ## 4. DataFrame standardization
#     save the dataframe to df3 and standardized_df.csv

# %%
#standardize df2 and store in df3
scaler = StandardScaler()
X_df2 = df2.drop(columns=['Log_MP_RATIO'])
#store X_df2 colums name and index
df2_Col=X_df2.columns

scaled_X_df2 = scaler.fit_transform(X_df2)

df3 = pd.concat([pd.DataFrame(scaled_X_df2, columns = df2_Col, index=df2.index), df['Log_MP_RATIO']], axis=1)

# %%
df3
# Out:
#            conc  ENV_CHEM      ASA+      ASA-     ASA_H     ASA_P    a_acid  \
# index
# 1      0.465633  0.805387 -0.313757 -1.007823 -1.224640 -0.084355 -0.392017
# 2     -0.734999  0.805387  0.506408 -1.259266 -1.633506  1.217306 -0.392017
# 3      0.301070  0.805387  0.041518 -0.059331  0.255527 -0.341123 -0.392017
# 4      0.464808  0.805387 -0.002819 -1.312852 -1.036761 -0.239164 -0.392017
# 5     -1.332866  0.805387  0.165890 -0.062957 -0.697547  1.255967  2.081746
# ...         ...       ...       ...       ...       ...       ...       ...
# 179   -3.469375  0.805387  1.155088 -0.447901  0.082529  0.912008 -0.392017
# 180    0.494250 -1.241639 -0.678569  0.621579 -0.382537  0.234038 -0.392017
# 181    0.494250 -1.241639 -0.681108  0.691204  0.672012 -0.965153 -0.392017
# 182    0.494250 -1.241639 -0.733003  0.828976 -0.278066  0.267224 -0.392017
# 183    0.494250 -1.241639 -1.364876  1.309021 -1.950492  1.984357 -0.392017
#
#          a_base     a_don  a_donacc  ...  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  \
# index                                ...
# 1     -0.628828  1.346150  0.605165  ...   0.780186  -0.226971  -0.074125
# 2     -0.628828  2.331532  1.972389  ...   4.658291  11.873983  13.490738
# 3     -0.628828 -0.624614  0.263359  ...  -0.651730  -0.226971  -0.074125
# 4      1.114741 -0.624614 -0.762059  ...  -0.055099  -0.226971  -0.074125
# 5     -0.628828  1.346150  0.946971  ...   1.197828  -0.226971  -0.074125
# ...         ...       ...       ...  ...        ...        ...        ...
# 179    1.114741  2.331532  1.288777  ...   1.436480   0.754187  -0.074125
# 180   -0.628828 -0.624614 -0.762059  ...  -0.651730  -0.226971  -0.074125
# 181   -0.628828 -0.624614 -0.762059  ...  -0.651730  -0.226971  -0.074125
# 182   -0.628828 -0.624614 -0.762059  ...  -0.651730  -0.226971  -0.074125
# 183   -0.628828 -0.624614 -0.762059  ...  -0.651730  -0.226971  -0.074125
#
#          Weight  weinerPath  weinerPol      TEST   CHARGED     group  \
# index
# 1     -1.510011   -0.615007  -1.495996 -0.494872 -0.805387 -0.939166
# 2     -0.928176   -0.415341  -0.771918 -0.494872 -0.805387 -0.939166
# 3     -0.271524   -0.086275   0.412937 -0.494872 -0.805387 -0.939166
# 4     -1.627466   -0.642835  -1.627647 -0.494872  1.241639  0.652199
# 5      0.039899    0.219138   0.347111  2.020726  1.241639  2.243563
# ...         ...         ...        ...       ...       ...       ...
# 179   -0.109270    0.387498  -0.047840 -0.494872  1.241639  0.652199
# 180    0.087739   -0.275505  -0.311141 -0.494872 -0.805387 -0.939166
# 181   -0.198774   -0.310986  -0.508617 -0.494872 -0.805387 -0.939166
# 182    0.087739   -0.258808  -0.376967 -0.494872 -0.805387 -0.939166
# 183    0.792891   -0.363859   1.005364 -0.494872 -0.805387 -0.939166
#
#        Log_MP_RATIO
# index
# 1         -0.119186
# 2          0.423246
# 3         -0.443698
# 4          0.711807
# 5         -0.530178
# ...             ...
# 179        0.176091
# 180        0.472628
# 181        0.667194
# 182        0.850593
# 183        0.847938
#
# [183 rows x 332 columns]

# %%
#save df3 to csv
dfToCsv = df3.join(df_set)
dfToCsv.to_csv('standardized_df.csv', encoding='utf-8')

# %% [markdown]
# ## 5. Data Visualization

# %%
def Data_Visualization(df):
    fig, axes = plt.subplots(2,2) 
    fig.set_size_inches(14,10)

    axes[0,0].hist(df['Log_MP_RATIO'], bins=30)
    axes[0,1].scatter(df.index, df['Log_MP_RATIO'])
    axes[1,0].boxplot(df['Log_MP_RATIO'], notch=True, patch_artist=True,
                     flierprops={'marker': 'o', 'markersize': 5, 'markerfacecolor': 'red'})
    sns.kdeplot(df['Log_MP_RATIO'], shade=True, thresh=0, ax=axes[1,1])
    plt.show()

# %%
Data_Visualization(df3) # df3 scaled data

# %% [markdown]
# ## 6. Principal Component Analysis (PCA)
#     on the scaled dataframe (df3)
#     save to df_pca.csv

# %%
scaled_X_df2
# Out:
# array([[ 0.46563257,  0.80538727, -0.3137566 , ..., -0.49487166,
#         -0.80538727, -0.93916594],
#        [-0.73499915,  0.80538727,  0.50640768, ..., -0.49487166,
#         -0.80538727, -0.93916594],
#        [ 0.30107008,  0.80538727,  0.04151822, ..., -0.49487166,
#         -0.80538727, -0.93916594],
#        ...,
#        [ 0.49425013, -1.2416387 , -0.68110767, ..., -0.49487166,
#         -0.80538727, -0.93916594],
#        [ 0.49425013, -1.2416387 , -0.73300343, ..., -0.49487166,
#         -0.80538727, -0.93916594],
#        [ 0.49425013, -1.2416387 , -1.36487619, ..., -0.49487166,
#         -0.80538727, -0.93916594]])

# %%
# we want the explained variance to be between 95–99%. In Scikit-learn
#//95% of variance
from sklearn.decomposition import PCA

nComponents = 0.95
pca = PCA(n_components=nComponents).fit(scaled_X_df2)

# %%
x_pca = pca.transform(scaled_X_df2)
print(scaled_X_df2.shape)
print(x_pca.shape)
# Out:
# (183, 331)
# (183, 52)

# %%
columns = ['pca_%i' % i for i in range(1, (x_pca.shape[1]+1))]
df_pca = pd.DataFrame(x_pca, columns=columns, index=df2.index)
df_pca.head()
# Out:
#            pca_1      pca_2     pca_3     pca_4     pca_5     pca_6     pca_7  \
# index
# 1      -1.932489  -9.369895 -0.429328 -2.896163 -0.860028 -4.625436  0.140549
# 2      11.875548 -11.720451  5.293248  4.672378  4.596623 -6.833438  9.608099
# 3      -0.107373  -2.805654  0.981750  6.574170 -3.389038  2.246912  4.505979
# 4      -2.143555  -8.906456 -7.642120 -3.128535  0.626197 -2.501226 -1.990190
# 5      10.607591  -2.846858  7.165251  0.471743 -2.842250 -1.233028 -7.223117
#
#           pca_8     pca_9    pca_10  ...    pca_43    pca_44    pca_45  \
# index                                ...
# 1     -0.264314 -0.793396  0.656604  ... -0.102804 -1.216918  0.794060
# 2     -4.221668  2.570879  1.955849  ... -0.240557 -0.288711 -0.662073
# 3      4.028233  1.238496 -2.717560  ... -0.500540 -0.784293 -0.715659
# 4     -1.837358  1.553272 -0.065783  ...  0.596870  0.950997 -0.721979
# 5     -1.122639  3.682269  1.908214  ... -0.311134  2.257420  1.131548
#
#          pca_46    pca_47    pca_48    pca_49    pca_50    pca_51    pca_52
# index
# 1      0.005334  1.308561  0.613513 -0.625668  0.545121 -0.311322 -0.306187
# 2     -0.768836  0.660976  0.659805  0.326068  0.271467  0.285403  0.673312
# 3     -0.539183  1.114615 -1.445342  0.888594 -0.749250  0.288211  0.046683
# 4     -0.307070  1.404008  1.062438  0.672862 -0.042480 -2.037658  1.644345
# 5     -0.942353  0.109952 -0.967532 -1.268523  0.145893  1.347483  0.852110
#
# [5 rows x 52 columns]

# %%
df_pca = df_pca.join(df_output)
df_pca
# Out:
#            pca_1      pca_2     pca_3     pca_4     pca_5     pca_6     pca_7  \
# index
# 1      -1.932489  -9.369895 -0.429328 -2.896163 -0.860028 -4.625436  0.140549
# 2      11.875548 -11.720451  5.293248  4.672378  4.596623 -6.833438  9.608099
# 3      -0.107373  -2.805654  0.981750  6.574170 -3.389038  2.246912  4.505979
# 4      -2.143555  -8.906456 -7.642120 -3.128535  0.626197 -2.501226 -1.990190
# 5      10.607591  -2.846858  7.165251  0.471743 -2.842250 -1.233028 -7.223117
# ...          ...        ...       ...       ...       ...       ...       ...
# 179     9.836850   1.233745 -4.832227  0.805906  5.214431 -6.622625 -2.161562
# 180    -7.864375   1.413901  0.783062 -1.131479 -0.095532  1.173689 -1.183842
# 181    -8.346712   1.281081  0.202058  0.763229 -1.335157 -0.734154 -1.519155
# 182    -7.618065   1.465796  0.717240 -0.698918  0.066164  0.835250 -1.436739
# 183    -7.442440   2.298769  4.956455 -7.652121 -2.369449  8.201770  1.205622
#
#           pca_8     pca_9    pca_10  ...    pca_44    pca_45    pca_46  \
# index                                ...
# 1     -0.264314 -0.793396  0.656604  ... -1.216918  0.794060  0.005334
# 2     -4.221668  2.570879  1.955849  ... -0.288711 -0.662073 -0.768836
# 3      4.028233  1.238496 -2.717560  ... -0.784293 -0.715659 -0.539183
# 4     -1.837358  1.553272 -0.065783  ...  0.950997 -0.721979 -0.307070
# 5     -1.122639  3.682269  1.908214  ...  2.257420  1.131548 -0.942353
# ...         ...       ...       ...  ...       ...       ...       ...
# 179    0.159669  2.953209  2.110482  ... -0.881483  1.832298 -0.744569
# 180    0.366329  1.381644 -0.227329  ...  0.216655 -0.422776  0.775516
# 181    0.805224  0.308047 -0.195388  ...  4.873409  2.850885  2.311225
# 182    0.760311  1.124718 -0.162053  ...  0.177163 -0.697808  0.866070
# 183   -3.811999  5.502749  1.805342  ... -0.247582  0.362767 -0.739904
#
#          pca_47    pca_48    pca_49    pca_50    pca_51    pca_52  \
# index
# 1      1.308561  0.613513 -0.625668  0.545121 -0.311322 -0.306187
# 2      0.660976  0.659805  0.326068  0.271467  0.285403  0.673312
# 3      1.114615 -1.445342  0.888594 -0.749250  0.288211  0.046683
# 4      1.404008  1.062438  0.672862 -0.042480 -2.037658  1.644345
# 5      0.109952 -0.967532 -1.268523  0.145893  1.347483  0.852110
# ...         ...       ...       ...       ...       ...       ...
# 179   -0.233842 -1.729909  0.534166  0.267195  0.083070  1.544554
# 180   -1.346407 -1.372402  0.085392  1.137203 -0.324752  0.152011
# 181    1.716661  2.111291  0.098579 -1.077232 -0.159306 -1.730749
# 182   -1.415321 -1.330465  0.417132  1.177152  0.025343 -0.183902
# 183   -1.154207 -0.420309 -0.169067  0.361243 -0.891467  0.311299
#
#        Log_MP_RATIO
# index
# 1         -0.119186
# 2          0.423246
# 3         -0.443698
# 4          0.711807
# 5         -0.530178
# ...             ...
# 179        0.176091
# 180        0.472628
# 181        0.667194
# 182        0.850593
# 183        0.847938
#
# [183 rows x 53 columns]

# %%
# the principal components explain a part of the variance. 


len(pca.explained_variance_ratio_)
# Out:
# 52

# %%
# From the Scikit-learn implementation, we can get the information about the explained variance 
# and plot the cumulative variance.

plt.rcParams["figure.figsize"] = (12,6)

fig, ax = plt.subplots()
xi = np.arange(1, (len(pca.explained_variance_ratio_)+1), step=1)
y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 11, step=1)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
# Importance de chaque variable dans le PCA :

loadings = pd.DataFrame(pca.components_, 
                       columns=X_df2.dropna(axis=1).columns)

def feature_importance(loadings):
    maxPC = 1.01 * np.max(np.max(np.abs(loadings)))
    f, axes = plt.subplots(10, 1, figsize=(15, 15), sharex=True)
    for i, ax in enumerate(axes):
        pc_loadings = loadings.loc[i, :]
        colors = ['C0' if l > 0 else 'C1' for l in pc_loadings]
        ax.axhline(color='#888888')
        pc_loadings.plot.bar(ax=ax, color=colors)
        ax.set_ylabel(f'PC{i+1}')
        ax.set_ylim(-maxPC, maxPC)
    plt.tight_layout()
    plt.show()
    
feature_importance(loadings)

# %%
#save df_pca to csv
df_pcaToCsv = df_pca.join(df_set)
df_pcaToCsv.to_csv('df_pca.csv', encoding='utf-8')

# %%
nComponents = 0.95


# https://stats.stackexchange.com/questions/384541/use-pca-to-discover-the-most-impactful-variables-on-the-original-data-set
from sklearn.decomposition import PCA
import math

pca = PCA(n_components=nComponents, svd_solver='full')
pca.fit(scaled_X_df2)

pca_site = pca.transform(scaled_X_df2)

pca.explained_variance_ratio_

# https://michael-fuchs-python.netlify.app/2020/07/27/pca-for-visualization/
# Interpreting Components:
index = ['pca_%i' % i for i in range(1, (x_pca.shape[1]+1))]
components = pd.DataFrame(pca.components_, columns = list(X_df2.columns), index=index)

components
# Out:
#             conc  ENV_CHEM      ASA+      ASA-     ASA_H     ASA_P    a_acid  \
# pca_1  -0.048029  0.089682  0.093776 -0.065190 -0.025815  0.084654  0.050600
# pca_2   0.022136 -0.045127  0.030474  0.078977  0.119944 -0.016350 -0.026353
# pca_3   0.006942 -0.063283 -0.085214  0.102217 -0.045249  0.060971  0.080903
# pca_4  -0.050098  0.016515  0.015820  0.022865  0.101940 -0.074015  0.020060
# pca_5  -0.002971 -0.037926 -0.026950  0.061984 -0.010645  0.042909 -0.052614
# pca_6   0.019865  0.003649 -0.012121  0.020546 -0.045762  0.061848 -0.012116
# pca_7  -0.060285 -0.005389  0.020855 -0.039875 -0.006421 -0.018518 -0.144748
# pca_8   0.063299  0.016005  0.000285 -0.001011  0.024001 -0.032863  0.028599
# pca_9  -0.003271  0.020863 -0.012533 -0.008414 -0.076223  0.069212 -0.048338
# pca_10 -0.034302 -0.038270 -0.038008  0.043653 -0.035235  0.043013  0.075056
# pca_11  0.053873  0.003287  0.020802 -0.023528  0.034489 -0.037184 -0.090350
# pca_12  0.005966  0.031970 -0.022997  0.041937 -0.006732  0.021587 -0.022963
# pca_13 -0.028951 -0.033221 -0.038304  0.022080 -0.042864  0.028568  0.026423
# pca_14 -0.012103  0.003193 -0.029058  0.035176 -0.031360  0.033400 -0.001872
# pca_15  0.077277  0.009988  0.026133 -0.007206 -0.005841  0.037620 -0.017792
# pca_16  0.072746  0.004740 -0.005518  0.004894 -0.007516  0.003568  0.031312
# pca_17  0.115100  0.016656  0.023323 -0.015815 -0.014299  0.026699  0.061217
# pca_18  0.035708  0.015612  0.008858 -0.025536  0.005013 -0.020987  0.107591
# pca_19 -0.059308  0.027854 -0.006059  0.020142  0.074357 -0.067510 -0.044920
# pca_20 -0.069670  0.007103 -0.012277  0.003187 -0.007418 -0.004954  0.112705
# pca_21 -0.100147 -0.055371  0.006485 -0.019576 -0.034999  0.027158 -0.015148
# pca_22  0.018859 -0.059074  0.006161 -0.008661  0.003032 -0.008462 -0.055230
# pca_23 -0.211357 -0.063722  0.022754 -0.001227 -0.006139  0.034190 -0.041040
# pca_24 -0.020744  0.040096  0.011837 -0.001262  0.021288 -0.014894  0.044136
# pca_25  0.034462 -0.023747 -0.020059  0.014555 -0.025497  0.021244 -0.017596
# pca_26  0.029249 -0.005562 -0.024886  0.011700  0.037047 -0.061749 -0.020224
# pca_27  0.013629  0.062040 -0.010737 -0.003442  0.019060 -0.042474 -0.032560
# pca_28 -0.043542 -0.000450  0.020947 -0.013254  0.019831 -0.009076 -0.029329
# pca_29 -0.051969 -0.048598  0.000706 -0.011078  0.016985 -0.025112  0.008532
# pca_30 -0.129962 -0.034207 -0.009111  0.003553  0.021966 -0.032065 -0.036549
# pca_31  0.040282  0.017849 -0.013527  0.002543 -0.008170 -0.006996  0.032583
# pca_32 -0.228693 -0.052996 -0.003613  0.002336 -0.011763  0.009130  0.012174
# pca_33 -0.069570  0.011207 -0.015243  0.010226  0.027319 -0.041944  0.067227
# pca_34  0.157331  0.021834  0.017327 -0.016629  0.010077 -0.008153  0.009941
# pca_35 -0.058117  0.004199 -0.015797  0.007926 -0.002536 -0.010508  0.053408
# pca_36  0.028374 -0.037704 -0.004854  0.011660 -0.013542  0.020931 -0.037840
# pca_37 -0.037701 -0.049521 -0.000745 -0.012384  0.009269 -0.021321 -0.011076
# pca_38 -0.038299  0.001855 -0.004562 -0.014268 -0.004708 -0.011737  0.046597
# pca_39 -0.131601 -0.014509  0.024397 -0.037763 -0.000601 -0.007867 -0.078461
# pca_40 -0.036152 -0.062832 -0.000130 -0.001574 -0.003113  0.003139  0.027605
# pca_41  0.016053 -0.038523 -0.008367  0.009051  0.002888 -0.003978 -0.058295
# pca_42  0.025174  0.053772 -0.003704  0.005217  0.013022 -0.015940 -0.084405
# pca_43 -0.008183  0.038133 -0.011709 -0.001181  0.004531 -0.021919 -0.015339
# pca_44 -0.006382  0.046821 -0.010314  0.016064  0.059716 -0.064801  0.030437
# pca_45 -0.076699  0.004706  0.003706 -0.007978 -0.016343  0.016257 -0.006436
# pca_46  0.169858 -0.027084 -0.036402  0.025916  0.021536 -0.041626  0.018820
# pca_47  0.001515  0.003001 -0.002796 -0.005173 -0.010046  0.009756  0.020592
# pca_48  0.142064 -0.016685  0.016799 -0.031722  0.023927 -0.043490  0.019297
# pca_49 -0.071979 -0.046407 -0.000834  0.002505  0.009560 -0.014399  0.029023
# pca_50 -0.087997  0.000683  0.007336  0.006596  0.005227  0.010829 -0.038208
# pca_51 -0.024502  0.011910 -0.018261  0.030561 -0.004068  0.021209 -0.003023
# pca_52 -0.044723 -0.025417 -0.014691  0.002169  0.006584 -0.020738 -0.051977
#
#           a_base     a_don  a_donacc  ...  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  \
# pca_1   0.044897  0.075346  0.091092  ...   0.066525   0.061013   0.026913
# pca_2   0.010151  0.008083  0.029573  ...  -0.041246  -0.044192  -0.032844
# pca_3  -0.126133  0.027486  0.028470  ...  -0.025232   0.000713   0.026715
# pca_4   0.032544 -0.051593 -0.045370  ...   0.034823   0.043788   0.030966
# pca_5   0.056375  0.026388 -0.010489  ...   0.124970   0.121908   0.063858
# pca_6   0.021625 -0.131146 -0.088428  ...  -0.065970  -0.055871  -0.069904
# pca_7  -0.018367  0.062329  0.078714  ...   0.015848   0.030505   0.064385
# pca_8  -0.074641 -0.011395  0.007662  ...  -0.040340  -0.032139  -0.036248
# pca_9   0.067685  0.075055  0.019710  ...   0.145837   0.140946   0.074472
# pca_10 -0.026074  0.024220 -0.029852  ...   0.015957   0.019901   0.014147
# pca_11 -0.033803  0.042523  0.027585  ...   0.004228   0.017772   0.003816
# pca_12 -0.016078  0.002311 -0.016093  ...   0.024716   0.017422   0.007609
# pca_13  0.059220 -0.011644 -0.017265  ...   0.005262  -0.014073  -0.022291
# pca_14  0.036095 -0.004930 -0.010254  ...  -0.049568  -0.103041  -0.121926
# pca_15 -0.034919 -0.013921  0.019842  ...  -0.039566  -0.021562   0.048308
# pca_16 -0.026510  0.058856  0.015721  ...   0.017209   0.059593   0.011667
# pca_17 -0.033246 -0.054143 -0.046315  ...   0.034165   0.034523   0.080742
# pca_18  0.049481 -0.095897 -0.048346  ...  -0.022631  -0.071202  -0.125706
# pca_19  0.018675 -0.011499 -0.009808  ...  -0.015387  -0.031052  -0.128802
# pca_20  0.085966 -0.030091 -0.047400  ...  -0.015572  -0.012081  -0.065405
# pca_21 -0.074257  0.033647  0.037436  ...  -0.023941   0.019246   0.040263
# pca_22 -0.028152 -0.024643  0.024774  ...   0.028177   0.029676   0.050663
# pca_23 -0.009281 -0.036041 -0.007715  ...   0.011604   0.019016  -0.012708
# pca_24 -0.038146 -0.064733 -0.004237  ...  -0.050259  -0.039384   0.172799
# pca_25  0.043952  0.026224 -0.007083  ...  -0.007877   0.006577   0.183973
# pca_26 -0.005321  0.023470 -0.018130  ...   0.003601   0.052803   0.167008
# pca_27 -0.002965  0.030353  0.050340  ...   0.003088   0.001024  -0.029490
# pca_28  0.065355 -0.075768 -0.045246  ...   0.025957   0.024652  -0.009289
# pca_29  0.032813 -0.014243 -0.023180  ...  -0.015365  -0.008447  -0.069432
# pca_30  0.035225  0.044194  0.039897  ...   0.018182   0.053045   0.008101
# pca_31  0.005973 -0.054055 -0.042210  ...  -0.008319  -0.022487  -0.010781
# pca_32  0.046909  0.007079  0.007410  ...  -0.079457  -0.059947  -0.102820
# pca_33  0.032017 -0.043685 -0.029758  ...  -0.056543  -0.036415   0.023673
# pca_34  0.014784  0.005465  0.011003  ...  -0.044092  -0.047362  -0.137504
# pca_35  0.052079 -0.034005 -0.020825  ...   0.000782  -0.020406   0.043469
# pca_36  0.006171 -0.030154 -0.024901  ...  -0.033132  -0.064539  -0.061572
# pca_37 -0.005401 -0.000429  0.013742  ...  -0.027187  -0.011108   0.093049
# pca_38 -0.039862  0.044141 -0.002913  ...   0.053663   0.030971  -0.028765
# pca_39 -0.102111  0.104304  0.070846  ...   0.040793   0.032097   0.003453
# pca_40 -0.022872  0.020596  0.016639  ...  -0.014742  -0.029128  -0.104935
# pca_41 -0.073720 -0.008360  0.028289  ...  -0.028907  -0.018686  -0.014578
# pca_42 -0.072869  0.051545  0.037066  ...   0.057070   0.023315  -0.098836
# pca_43  0.064530 -0.079326 -0.048787  ...  -0.037051  -0.046785  -0.044778
# pca_44 -0.102056  0.046319  0.026455  ...   0.064996   0.064223   0.034231
# pca_45  0.021871 -0.049820  0.013649  ...  -0.003448  -0.011431  -0.066657
# pca_46 -0.020596  0.016831  0.002973  ...  -0.050601  -0.045442  -0.095299
# pca_47  0.051789 -0.030602 -0.016862  ...  -0.003033   0.008026   0.011348
# pca_48 -0.023846 -0.009644 -0.017074  ...  -0.024170  -0.002375   0.147397
# pca_49  0.114273 -0.026073 -0.039513  ...  -0.089026  -0.088911  -0.015938
# pca_50  0.046599 -0.040994 -0.005011  ...   0.040200   0.041526  -0.006602
# pca_51  0.020910  0.030552 -0.001534  ...   0.051308   0.093911   0.073892
# pca_52 -0.081831  0.000007  0.022040  ...   0.015921  -0.018188   0.039084
#
#         vsurf_Wp8    Weight  weinerPath  weinerPol      TEST   CHARGED  \
# pca_1    0.011210 -0.002142    0.068515   0.046125 -0.020912  0.061637
# pca_2   -0.022809  0.131595    0.105891   0.117871  0.024214 -0.001278
# pca_3    0.013984  0.073123    0.024937   0.050097  0.007778 -0.079499
# pca_4    0.019318  0.016773   -0.025230  -0.030540  0.019564  0.016757
# pca_5    0.026850  0.058478   -0.000070  -0.012067 -0.003108  0.018518
# pca_6   -0.044291  0.028545   -0.028870   0.070910  0.014089  0.016316
# pca_7    0.069913 -0.007970    0.035513   0.034371 -0.041094 -0.116241
# pca_8   -0.035667 -0.004983    0.023674   0.063278 -0.062267 -0.049721
# pca_9    0.024340 -0.030181   -0.025919   0.045396  0.052797  0.032204
# pca_10   0.020776 -0.010294    0.015805  -0.004131  0.006991 -0.035792
# pca_11  -0.020157 -0.049906    0.001570  -0.053835  0.035094 -0.051887
# pca_12  -0.025695  0.115874   -0.040739  -0.031510 -0.196161 -0.039090
# pca_13  -0.002044 -0.000254   -0.017075  -0.002418 -0.037173  0.022547
# pca_14  -0.110324 -0.003266    0.021289   0.022177  0.040817  0.052405
# pca_15   0.080642 -0.009024   -0.002263  -0.031860 -0.033866  0.044443
# pca_16  -0.022185 -0.006742    0.024577  -0.067150  0.009597 -0.024246
# pca_17   0.024840 -0.064353   -0.020940   0.013959 -0.039072  0.004219
# pca_18  -0.130305 -0.000165    0.041442  -0.027065  0.060233  0.125332
# pca_19  -0.136561 -0.015697    0.052058  -0.019838  0.030564  0.037987
# pca_20  -0.068297  0.007352   -0.069946  -0.002817  0.075711  0.054324
# pca_21   0.008222 -0.026480    0.027179   0.003381  0.009213  0.009626
# pca_22   0.065008  0.002758    0.002816  -0.036049  0.128275 -0.061813
# pca_23  -0.037041 -0.029520    0.005073   0.008702 -0.143978 -0.040615
# pca_24   0.262452  0.004865   -0.019328  -0.041330  0.111183  0.016456
# pca_25   0.218164  0.018132    0.087972   0.020843 -0.038072 -0.020156
# pca_26   0.235978  0.041119   -0.077722   0.035201  0.031019  0.085731
# pca_27  -0.041844  0.012177   -0.068755  -0.010911  0.076210 -0.083473
# pca_28  -0.020287  0.018985   -0.009586   0.054984  0.057274 -0.029042
# pca_29  -0.058744  0.005777   -0.042243  -0.032968 -0.124178 -0.009046
# pca_30  -0.009158 -0.003610   -0.068140   0.000797 -0.003774 -0.011091
# pca_31   0.002794  0.014726   -0.028793  -0.021481 -0.131954  0.010890
# pca_32  -0.105817  0.014693   -0.023877  -0.019749  0.140015  0.040516
# pca_33   0.085764 -0.001028   -0.030715   0.014638  0.011294  0.071633
# pca_34  -0.084358  0.000617    0.003116  -0.005930  0.032283  0.000251
# pca_35   0.081010 -0.006509   -0.022378   0.034900 -0.155155  0.020006
# pca_36  -0.018210 -0.005804   -0.043575  -0.040518 -0.075388 -0.039202
# pca_37   0.088900  0.007772   -0.000127   0.020941 -0.106806  0.030100
# pca_38  -0.031114  0.020310   -0.011042  -0.035854  0.053168  0.084880
# pca_39  -0.053088 -0.009720   -0.049638   0.015907 -0.028241 -0.053552
# pca_40  -0.069369 -0.009449   -0.014126   0.010211 -0.074390 -0.021771
# pca_41   0.023413  0.000092    0.009223  -0.015703  0.046304  0.007675
# pca_42  -0.118254  0.020314    0.033480   0.005040 -0.059146  0.037177
# pca_43  -0.016674  0.003510   -0.017007   0.016612 -0.043792 -0.001271
# pca_44  -0.020692  0.004975    0.048110   0.029897 -0.015503  0.105435
# pca_45  -0.050545 -0.000034    0.007776  -0.004380 -0.160922 -0.059243
# pca_46  -0.061239 -0.009369   -0.050844  -0.007749 -0.099000 -0.071036
# pca_47   0.056302 -0.013013    0.050073  -0.012414 -0.000126 -0.098115
# pca_48   0.057107 -0.012584    0.018139   0.002197 -0.035742 -0.002832
# pca_49   0.028429 -0.015392    0.008112   0.015490 -0.100723 -0.005377
# pca_50   0.025114 -0.003927    0.039122  -0.005291 -0.234985 -0.030164
# pca_51   0.027049  0.011091    0.018259   0.014784  0.070706  0.040565
# pca_52   0.069297 -0.020491   -0.001116  -0.009972  0.031586 -0.113562
#
#            group
# pca_1   0.034688
# pca_2   0.014324
# pca_3  -0.056882
# pca_4   0.025403
# pca_5   0.012430
# pca_6   0.021597
# pca_7  -0.116362
# pca_8  -0.078043
# pca_9   0.058435
# pca_10 -0.023402
# pca_11 -0.018137
# pca_12 -0.154480
# pca_13 -0.005988
# pca_14  0.066560
# pca_15  0.013127
# pca_16 -0.012778
# pca_17 -0.021437
# pca_18  0.135537
# pca_19  0.048866
# pca_20  0.090126
# pca_21  0.013312
# pca_22  0.033093
# pca_23 -0.122655
# pca_24  0.083128
# pca_25 -0.039754
# pca_26  0.086271
# pca_27 -0.016682
# pca_28  0.013654
# pca_29 -0.085587
# pca_30 -0.011010
# pca_31 -0.075008
# pca_32  0.120071
# pca_33  0.062832
# pca_34  0.020617
# pca_35 -0.082598
# pca_36 -0.078167
# pca_37 -0.044165
# pca_38  0.099620
# pca_39 -0.059496
# pca_40 -0.063984
# pca_41  0.035258
# pca_42 -0.008514
# pca_43 -0.028691
# pca_44  0.072158
# pca_45 -0.147855
# pca_46 -0.117851
# pca_47 -0.076355
# pca_48 -0.024812
# pca_49 -0.067897
# pca_50 -0.172101
# pca_51  0.076264
# pca_52 -0.068302
#
# [52 rows x 331 columns]

# %%
#dataFrame = components.sum(axis = 1)
#print("\nSumming rows...\n",dataFrame)
################################
# Get a series containing maximum value of each column
# maxValuesObj = dfObj.max()
# print('Maximum value in each column : ')
# print(maxValuesObj)
#################################
# # Get a series containing maximum value of each row
# maxValuesPca = components.max(axis=1)
# print('Maximum value in each row : ')
# print(maxValuesPca)

# get the column name of max values in every row
maxValueIndexObj = components.idxmax(axis=1)
print("Max values of each pca :")
print(maxValueIndexObj)
# Out:
# Max values of each pca :
# pca_1            Q_PC+
# pca_2     PEOE_VSA_HYD
# pca_3           FCASA-
# pca_4        h_log_pbo
# pca_5       MACCS(-58)
# pca_6                E
# pca_7       MACCS(-77)
# pca_8       MACCS(-73)
# pca_9             glob
# pca_10      MACCS(129)
# pca_11      MACCS(102)
# pca_12      MACCS(-46)
# pca_13      MACCS(-57)
# pca_14      MACCS(-70)
# pca_15      MACCS(-83)
# pca_16      MACCS(114)
# pca_17       mutagenic
# pca_18      MACCS(-24)
# pca_19       vsurf_IW3
# pca_20        b_triple
# pca_21      MACCS(-78)
# pca_22      MACCS(-22)
# pca_23      SlogP_VSA4
# pca_24      MACCS(-28)
# pca_25       vsurf_Wp8
# pca_26       vsurf_Wp8
# pca_27      PEOE_VSA+2
# pca_28      vsurf_DW13
# pca_29      MACCS(-13)
# pca_30      vsurf_DD12
# pca_31      MACCS(114)
# pca_32       h_pstrain
# pca_33      MACCS(-23)
# pca_34      MACCS(-53)
# pca_35      MACCS(-26)
# pca_36      MACCS(-21)
# pca_37      MACCS(-66)
# pca_38      MACCS(-23)
# pca_39        E_strain
# pca_40      MACCS(-34)
# pca_41           E_oop
# pca_42      MACCS(-17)
# pca_43      MACCS(-34)
# pca_44      MACCS(-21)
# pca_45      MACCS(-21)
# pca_46      MACCS(-21)
# pca_47      MACCS(-19)
# pca_48      vsurf_DW12
# pca_49      MACCS(-17)
# pca_50      vsurf_DW13
# pca_51      MACCS(114)
# pca_52      MACCS(115)
# dtype: object

# %%
#https://stackoverflow.com/questions/41117560/how-to-sort-rows-values-and-replace-them-by-column-names-on-a-pandas-dataframe

components.apply(lambda row: row.sort_values(ascending=False).index, axis=1)
# Out:
# pca_1     Index(['Q_PC+', 'Q_VSA_PPOS', 'PEOE_VSA_POL', ...
# pca_2     Index(['PEOE_VSA_HYD', 'chi0v', 'a_hyd', 'mr',...
# pca_3     Index(['FCASA-', 'vsurf_HB1', 'density', 'vsur...
# pca_4     Index(['h_log_pbo', 'MACCS(162)', 'b_ar', 'MAC...
# pca_5     Index(['MACCS(-58)', 'MACCS(-33)', 'MACCS(-42)...
# pca_6     Index(['E', 'MACCS(122)', 'PEOE_VSA-2', 'MACCS...
# pca_7     Index(['MACCS(-77)', 'MACCS(-80)', 'MACCS(-38)...
# pca_8     Index(['MACCS(-73)', 'MACCS(-58)', 'MACCS(-33)...
# pca_9     Index(['glob', 'vsurf_Wp5', 'vsurf_Wp6', 'vsa_...
# pca_10    Index(['MACCS(129)', 'MACCS(128)', 'MACCS(118)...
# pca_11    Index(['MACCS(102)', 'MACCS(130)', 'MACCS(124)...
# pca_12    Index(['MACCS(-46)', 'PEOE_VSA-0', 'PEOE_RPC-'...
# pca_13    Index(['MACCS(-57)', 'E_ang', 'MACCS(-22)', 'm...
# pca_14    Index(['MACCS(-70)', 'MACCS(-63)', 'GCUT_PEOE_...
# pca_15    Index(['MACCS(-83)', 'MACCS(-96)', 'PEOE_VSA+2...
# pca_16    Index(['MACCS(114)', 'MACCS(-16)', 'vsurf_DD13...
# pca_17    Index(['mutagenic', 'MACCS(-63)', 'h_pKa', 'MA...
# pca_18    Index(['MACCS(-24)', 'PEOE_RPC-', 'vsurf_DD12'...
# pca_19    Index(['vsurf_IW3', 'vsurf_IW4', 'MACCS(-16)',...
# pca_20    Index(['b_triple', 'MACCS(-41)', 'MACCS(-43)',...
# pca_21    Index(['MACCS(-78)', 'MACCS(-13)', 'MACCS(119)...
# pca_22    Index(['MACCS(-22)', 'MACCS(-16)', 'MACCS(-99)...
# pca_23    Index(['SlogP_VSA4', 'h_pstrain', 'rsynth', 'M...
# pca_24    Index(['MACCS(-28)', 'vsurf_Wp8', 'MACCS(109)'...
# pca_25    Index(['vsurf_Wp8', 'vsurf_Wp7', 'MACCS(-43)',...
# pca_26    Index(['vsurf_Wp8', 'vsurf_Wp7', 'SMR_VSA4', '...
# pca_27    Index(['PEOE_VSA+2', 'vsurf_DW23', 'vsurf_DW13...
# pca_28    Index(['vsurf_DW13', 'npr2', 'vsurf_DW23', 'pe...
# pca_29    Index(['MACCS(-13)', 'MACCS(-65)', 'MACCS(-38)...
# pca_30    Index(['vsurf_DD12', 'MACCS(-91)', 'MACCS(101)...
# pca_31    Index(['MACCS(114)', 'SMR_VSA2', 'MACCS(-57)',...
# pca_32    Index(['h_pstrain', 'MACCS(-53)', 'TEST', 'vsu...
# pca_33    Index(['MACCS(-23)', 'MACCS(-34)', 'MACCS(-74)...
# pca_34    Index(['MACCS(-53)', 'MACCS(-23)', 'conc', 'E_...
# pca_35    Index(['MACCS(-26)', 'MACCS(-19)', 'MACCS(-21)...
# pca_36    Index(['MACCS(-21)', 'vsurf_DW13', 'MACCS(-74)...
# pca_37    Index(['MACCS(-66)', 'SlogP_VSA4', 'MACCS(-97)...
# pca_38    Index(['MACCS(-23)', 'MACCS(-21)', 'h_pstrain'...
# pca_39    Index(['E_strain', 'MACCS(-74)', 'MACCS(-23)',...
# pca_40    Index(['MACCS(-34)', 'MACCS(-19)', 'vsurf_DD12...
# pca_41    Index(['E_oop', 'MACCS(-59)', 'MACCS(-36)', 'v...
# pca_42    Index(['MACCS(-17)', 'MACCS(-34)', 'PEOE_VSA+5...
# pca_43    Index(['MACCS(-34)', 'petitjean', 'MACCS(106)'...
# pca_44    Index(['MACCS(-21)', 'petitjean', 'E_strain', ...
# pca_45    Index(['MACCS(-21)', 'SMR_VSA4', 'MACCS(-17)',...
# pca_46    Index(['MACCS(-21)', 'MACCS(-54)', 'conc', 'MA...
# pca_47    Index(['MACCS(-19)', 'MACCS(-28)', 'MACCS(135)...
# pca_48    Index(['vsurf_DW12', 'MACCS(-21)', 'MACCS(-34)...
# pca_49    Index(['MACCS(-17)', 'petitjean', 'MACCS(114)'...
# pca_50    Index(['vsurf_DW13', 'SMR_VSA4', 'MACCS(111)',...
# pca_51    Index(['MACCS(114)', 'E_strain', 'MACCS(-59)',...
# pca_52    Index(['MACCS(115)', 'MACCS(-41)', 'MACCS(-34)...
# dtype: object

# %%
# most important feature for each pca

pd.DataFrame(components.columns[np.argsort(-components.values, axis=1)], 
                               index=components.index)
# Out:
#                  0           1             2             3              4    \
# pca_1          Q_PC+  Q_VSA_PPOS  PEOE_VSA_POL      PEOE_PC+   PEOE_VSA_POS
# pca_2   PEOE_VSA_HYD       chi0v         a_hyd            mr         KierA2
# pca_3         FCASA-   vsurf_HB1       density     vsurf_CW2          h_ema
# pca_4      h_log_pbo  MACCS(162)          b_ar    MACCS(121)     MACCS(142)
# pca_5     MACCS(-58)  MACCS(-33)    MACCS(-42)    MACCS(106)     MACCS(-73)
# pca_6              E  MACCS(122)    PEOE_VSA-2    MACCS(112)     MACCS(-85)
# pca_7     MACCS(-77)  MACCS(-80)    MACCS(-38)    MACCS(137)     MACCS(121)
# pca_8     MACCS(-73)  MACCS(-58)    MACCS(-33)    MACCS(-69)     MACCS(125)
# pca_9           glob   vsurf_Wp5     vsurf_Wp6       vsa_don     MACCS(101)
# pca_10    MACCS(129)  MACCS(128)    MACCS(118)    MACCS(147)           npr2
# pca_11    MACCS(102)  MACCS(130)    MACCS(124)    MACCS(-70)     MACCS(-71)
# pca_12    MACCS(-46)  PEOE_VSA-0     PEOE_RPC-     vsurf_IW4      vsurf_IW5
# pca_13    MACCS(-57)       E_ang    MACCS(-22)     mutagenic     MACCS(113)
# pca_14    MACCS(-70)  MACCS(-63)   GCUT_PEOE_2    MACCS(-52)     MACCS(-94)
# pca_15    MACCS(-83)  MACCS(-96)    PEOE_VSA+2    MACCS(-65)     MACCS(-52)
# pca_16    MACCS(114)  MACCS(-16)    vsurf_DD13    MACCS(-22)     MACCS(135)
# pca_17     mutagenic  MACCS(-63)         h_pKa    MACCS(-71)     MACCS(-25)
# pca_18    MACCS(-24)   PEOE_RPC-    vsurf_DD12         group       vsa_base
# pca_19     vsurf_IW3   vsurf_IW4    MACCS(-16)      chiral_u     MACCS(-78)
# pca_20      b_triple  MACCS(-41)    MACCS(-43)      SMR_VSA2     MACCS(-17)
# pca_21    MACCS(-78)  MACCS(-13)    MACCS(119)    MACCS(-41)          E_ele
# pca_22    MACCS(-22)  MACCS(-16)    MACCS(-99)          npr2       chiral_u
# pca_23    SlogP_VSA4   h_pstrain        rsynth    MACCS(-16)       reactive
# pca_24    MACCS(-28)   vsurf_Wp8    MACCS(109)     vsurf_Wp7       std_dim3
# pca_25     vsurf_Wp8   vsurf_Wp7    MACCS(-43)         E_ele      vsurf_ID8
# pca_26     vsurf_Wp8   vsurf_Wp7      SMR_VSA4         E_ele     MACCS(-92)
# pca_27    PEOE_VSA+2  vsurf_DW23    vsurf_DW13    MACCS(144)         rsynth
# pca_28    vsurf_DW13        npr2    vsurf_DW23     petitjean     vsurf_DD13
# pca_29    MACCS(-13)  MACCS(-65)    MACCS(-38)    MACCS(-34)     PEOE_VSA+2
# pca_30    vsurf_DD12  MACCS(-91)    MACCS(101)     h_pstrain     MACCS(-94)
# pca_31    MACCS(114)    SMR_VSA2    MACCS(-57)  BCUT_SLOGP_3     MACCS(115)
# pca_32     h_pstrain  MACCS(-53)          TEST     vsurf_ID8          group
# pca_33    MACCS(-23)  MACCS(-34)    MACCS(-74)    MACCS(-50)     MACCS(-21)
# pca_34    MACCS(-53)  MACCS(-23)          conc         E_oop     vsurf_DW13
# pca_35    MACCS(-26)  MACCS(-19)    MACCS(-21)      vsa_base       E_strain
# pca_36    MACCS(-21)  vsurf_DW13    MACCS(-74)    vsurf_DD23      vsurf_ID3
# pca_37    MACCS(-66)  SlogP_VSA4    MACCS(-97)    MACCS(-11)     PEOE_VSA+1
# pca_38    MACCS(-23)  MACCS(-21)     h_pstrain    vsurf_DD23     MACCS(-54)
# pca_39      E_strain  MACCS(-74)    MACCS(-23)    MACCS(-59)      h_pstrain
# pca_40    MACCS(-34)  MACCS(-19)    vsurf_DD12      E_strain   vsurf_EDmin1
# pca_41         E_oop  MACCS(-59)    MACCS(-36)    vsurf_DW13     MACCS(111)
# pca_42    MACCS(-17)  MACCS(-34)    PEOE_VSA+5    SlogP_VSA4           npr1
# pca_43    MACCS(-34)   petitjean    MACCS(106)    MACCS(135)     MACCS(112)
# pca_44    MACCS(-21)   petitjean      E_strain    MACCS(-34)         rsynth
# pca_45    MACCS(-21)    SMR_VSA4    MACCS(-17)    MACCS(-92)       b_triple
# pca_46    MACCS(-21)  MACCS(-54)          conc    MACCS(-90)      petitjean
# pca_47    MACCS(-19)  MACCS(-28)    MACCS(135)    MACCS(-21)     MACCS(118)
# pca_48    vsurf_DW12  MACCS(-21)    MACCS(-34)     vsurf_Wp7           conc
# pca_49    MACCS(-17)   petitjean    MACCS(114)    MACCS(101)  opr_violation
# pca_50    vsurf_DW13    SMR_VSA4    MACCS(111)          glob     MACCS(-24)
# pca_51    MACCS(114)    E_strain    MACCS(-59)    MACCS(-34)      vsurf_IW1
# pca_52    MACCS(115)  MACCS(-41)    MACCS(-34)    MACCS(-95)     MACCS(108)
#
#                5             6              7              8            9    \
# pca_1         ASA+     Q_VSA_POL  PEOE_VSA_PNEG  PEOE_VSA_PPOS     a_donacc
# pca_2       KierA1       vsurf_R         Weight      vsurf_Wp1         pmi1
# pca_3   GCUT_SMR_0  GCUT_SLOGP_0          h_pKa          a_ICM        CASA-
# pca_4   MACCS(-79)    MACCS(125)     MACCS(-80)     MACCS(158)  BCUT_PEOE_2
# pca_5   MACCS(-69)       vsa_don       balabanJ      vsurf_Wp5   MACCS(102)
# pca_6   BCUT_SMR_3    MACCS(-75)     MACCS(-86)     MACCS(100)        E_ele
# pca_7   MACCS(120)    MACCS(-65)     MACCS(-57)          E_sol   MACCS(-75)
# pca_8    vsurf_ID7    SlogP_VSA7      vsurf_ID6     PEOE_VSA-4     SMR_VSA5
# pca_9   MACCS(-84)    PEOE_VSA-2     MACCS(151)     MACCS(-66)    vsurf_Wp3
# pca_10  MACCS(-91)    SlogP_VSA8     vsurf_DW12   BCUT_SLOGP_3   MACCS(138)
# pca_11  MACCS(-63)    MACCS(-50)     MACCS(-76)          h_pKb   MACCS(-59)
# pca_12    SMR_VSA2          pmi1         Weight     MACCS(-76)    vsurf_IW3
# pca_13  MACCS(152)    MACCS(-16)              E       SMR_VSA3   MACCS(101)
# pca_14  MACCS(119)    SlogP_VSA7       SMR_VSA2     PEOE_VSA+6   MACCS(-71)
# pca_15  MACCS(155)    MACCS(-41)       b_triple        b_1rotR      b_1rotN
# pca_16       E_ang      chiral_u     MACCS(141)     MACCS(-85)   MACCS(149)
# pca_17  MACCS(-70)    MACCS(133)     MACCS(-76)           conc     reactive
# pca_18        RPC-      E_strain        CHARGED     SlogP_VSA8   MACCS(115)
# pca_19   vsurf_IW5     vsurf_IW2     MACCS(-13)       SMR_VSA4   MACCS(119)
# pca_20  MACCS(-93)    MACCS(136)         a_acid      vsurf_CW2   MACCS(-91)
# pca_21  SlogP_VSA5    MACCS(-25)      h_pstrain       b_triple   MACCS(113)
# pca_22  MACCS(-76)         E_ang           TEST     MACCS(-45)   MACCS(-50)
# pca_23       E_ang      std_dim2     MACCS(-22)     vsurf_DD13     chiral_u
# pca_24  MACCS(-62)    MACCS(-43)           glob     MACCS(-13)         TEST
# pca_25  MACCS(123)    MACCS(109)     PEOE_VSA+3      PEOE_RPC+         RPC-
# pca_26           E    MACCS(110)     MACCS(-17)     MACCS(-74)   vsurf_DW23
# pca_27   vsurf_ID3    MACCS(-24)      vsurf_IW2          E_ele         npr1
# pca_28  MACCS(114)    MACCS(-11)     vsurf_DD23     MACCS(-62)   MACCS(-63)
# pca_29       E_oop    MACCS(--8)     MACCS(-74)     vsurf_DD13   PEOE_VSA+5
# pca_30  MACCS(-52)    MACCS(-24)          E_oop     MACCS(114)   MACCS(-45)
# pca_31  MACCS(-28)    MACCS(-91)     MACCS(120)     SlogP_VSA8   MACCS(-43)
# pca_32  MACCS(-91)    MACCS(-59)     MACCS(-16)     MACCS(-73)   MACCS(-99)
# pca_33  MACCS(-52)     PEOE_RPC-     vsurf_DW23     MACCS(-17)    PEOE_RPC+
# pca_34  MACCS(101)    vsurf_DD13     MACCS(-93)     SlogP_VSA5   MACCS(155)
# pca_35  MACCS(-99)    MACCS(-78)     vsurf_DD13     MACCS(111)   MACCS(-52)
# pca_36    reactive    MACCS(115)     MACCS(-97)     MACCS(-45)   vsurf_DW23
# pca_37  MACCS(114)        rsynth     MACCS(-94)      vsurf_Wp7   MACCS(-19)
# pca_38  MACCS(120)      E_strain     PEOE_VSA-0          E_ele        group
# pca_39  MACCS(118)    MACCS(-66)     vsurf_DD13          a_don   MACCS(139)
# pca_40  MACCS(-62)    MACCS(-43)          h_pKb     MACCS(109)   vsurf_DD13
# pca_41       a_ICM    PEOE_VSA-5     MACCS(-26)     MACCS(-25)    vsurf_IW4
# pca_42  MACCS(-36)    MACCS(-96)          E_tor          E_sol   MACCS(-84)
# pca_43  vsurf_DD23    MACCS(-66)     MACCS(-74)     MACCS(-62)    mutagenic
# pca_44        RPC-     h_pstrain     MACCS(-37)          h_pKa   PEOE_VSA-1
# pca_45  SlogP_VSA4     PEOE_RPC+     PEOE_VSA+2     MACCS(-53)   MACCS(110)
# pca_46  MACCS(125)    MACCS(145)     MACCS(-13)          a_ICM        h_pKa
# pca_47  MACCS(-90)    MACCS(-11)     MACCS(-63)       vsa_base   MACCS(128)
# pca_48   vsurf_ID7      balabanJ     MACCS(-75)          E_vdw    vsurf_IW4
# pca_49  MACCS(-19)    vsurf_DW12     MACCS(120)       E_strain   MACCS(-16)
# pca_50  MACCS(-41)    MACCS(-34)      vsurf_HL2       std_dim3   vsurf_DW12
# pca_51  vsurf_DW23      std_dim2     vsurf_DD23           RPC+        E_oop
# pca_52  vsurf_DD23      vsa_base      h_pstrain          E_oop   MACCS(101)
#
#         ...             321         322             323            324  \
# pca_1   ...      GCUT_SMR_2   logP(o/w)      BCUT_SMR_0    GCUT_PEOE_0
# pca_2   ...  PEOE_VSA_FPNEG   vsurf_IW1  PEOE_VSA_FPPOS  PEOE_VSA_FPOL
# pca_3   ...      MACCS(-86)     h_emd_C        SMR_VSA5          h_emd
# pca_4   ...     BCUT_PEOE_1      FASA_P      MACCS(139)         chiral
# pca_5   ...            npr1  MACCS(-50)      PEOE_VSA-5     MACCS(-96)
# pca_6   ...      MACCS(152)  MACCS(157)     BCUT_PEOE_2     MACCS(-54)
# pca_7   ...         b_1rotR     CHARGED           group     MACCS(-11)
# pca_8   ...  PEOE_VSA_FPPOS  MACCS(-24)      MACCS(119)     PEOE_VSA-2
# pca_9   ...      MACCS(-70)  MACCS(-37)      BCUT_SMR_1     MACCS(-46)
# pca_10  ...            pmi1  MACCS(130)      MACCS(126)     MACCS(-74)
# pca_11  ...       vsurf_CW8   vsurf_IW7       vsurf_IW1      vsurf_IW2
# pca_12  ...        balabanJ    SMR_VSA3    vsurf_EDmin1     MACCS(-62)
# pca_13  ...      vsurf_DW23        glob      MACCS(-17)     vsurf_DD13
# pca_14  ...       vsurf_Wp6  MACCS(-43)       vsurf_Wp8     MACCS(-93)
# pca_15  ...      MACCS(145)  MACCS(-50)      MACCS(163)          E_oop
# pca_16  ...      MACCS(-50)  MACCS(105)        E_strain     MACCS(-42)
# pca_17  ...      vsurf_DW13  vsurf_DD13      MACCS(110)     MACCS(-11)
# pca_18  ...    opr_leadlike   vsurf_Wp7       vsurf_IW7     MACCS(-99)
# pca_19  ...      MACCS(135)  vsurf_DD12      vsurf_DD23     PEOE_VSA-2
# pca_20  ...      MACCS(-34)      rsynth      MACCS(-84)     PEOE_VSA+5
# pca_21  ...      MACCS(105)  MACCS(-97)      PEOE_VSA+3     MACCS(136)
# pca_22  ...      MACCS(102)  MACCS(105)            b_ar     GCUT_SMR_1
# pca_23  ...      MACCS(104)  MACCS(144)      MACCS(-74)     MACCS(-94)
# pca_24  ...      MACCS(114)       h_pKb           E_ele     MACCS(-42)
# pca_25  ...       vsurf_IW8  MACCS(110)      MACCS(117)     BCUT_SMR_3
# pca_26  ...       vsurf_IW1    std_dim3            glob     MACCS(-52)
# pca_27  ...            rgyr      radius      MACCS(106)     SlogP_VSA7
# pca_28  ...      MACCS(-34)  MACCS(132)        b_triple     MACCS(-59)
# pca_29  ...       mutagenic  MACCS(-92)      MACCS(-82)           TEST
# pca_30  ...      MACCS(120)  MACCS(-74)      MACCS(-23)           conc
# pca_31  ...      MACCS(-99)       E_ang      MACCS(-26)     MACCS(139)
# pca_32  ...       vsurf_IW1  MACCS(141)      MACCS(-17)       b_triple
# pca_33  ...      PEOE_VSA+5        pmi2      MACCS(-24)     MACCS(-62)
# pca_34  ...     GCUT_PEOE_1  MACCS(-74)        reactive     MACCS(-97)
# pca_35  ...      MACCS(-17)  MACCS(163)      MACCS(-41)     MACCS(-97)
# pca_36  ...      MACCS(126)           E      MACCS(-26)     MACCS(-64)
# pca_37  ...      MACCS(-34)   vsurf_IW8    opr_leadlike     MACCS(-72)
# pca_38  ...      MACCS(155)  MACCS(-34)          rsynth     PEOE_VSA+5
# pca_39  ...      MACCS(-33)       a_ICM      MACCS(-90)           conc
# pca_40  ...      MACCS(-59)      rsynth      MACCS(-81)     PEOE_VSA+0
# pca_41  ...      MACCS(-21)  MACCS(116)      PEOE_VSA-6     MACCS(101)
# pca_42  ...       vsurf_Wp7  vsurf_DD12           E_vdw     MACCS(119)
# pca_43  ...      MACCS(-95)  vsurf_DW12           E_ele     MACCS(113)
# pca_44  ...        SMR_VSA4       a_ICM      MACCS(119)         a_base
# pca_45  ...          rsynth  MACCS(106)            RPC+     MACCS(-24)
# pca_46  ...      PEOE_VSA-2   vsurf_IW7            pmi2    BCUT_PEOE_2
# pca_47  ...      MACCS(-24)   petitjean      MACCS(136)       reactive
# pca_48  ...      MACCS(-53)   vsurf_ID3      MACCS(-90)     MACCS(109)
# pca_49  ...      MACCS(-13)  MACCS(-96)      MACCS(-64)     MACCS(136)
# pca_50  ...      MACCS(-66)  MACCS(114)      MACCS(-54)     MACCS(-64)
# pca_51  ...        vsurf_W8    reactive      PEOE_VSA-5         dipole
# pca_52  ...      MACCS(-62)   PEOE_RPC+         CHARGED     vsurf_DW12
#
#                  325           326           327           328           329  \
# pca_1   BCUT_SLOGP_2  GCUT_SLOGP_2  GCUT_SLOGP_1         SlogP  vsurf_EWmin1
# pca_2         h_logS  opr_leadlike          RPC-     PEOE_RPC+          RPC+
# pca_3     MACCS(-82)         FASA+          RPC-   GCUT_PEOE_1        a_base
# pca_4     MACCS(-66)    Q_VSA_PNEG      balabanJ  vsurf_EDmin1   Q_VSA_FPNEG
# pca_5     MACCS(-99)    MACCS(154)      b_double    MACCS(105)    opr_brigid
# pca_6     MACCS(139)    SlogP_VSA0    MACCS(131)   GCUT_PEOE_2         a_don
# pca_7     MACCS(-81)    MACCS(-47)         E_ele    MACCS(-36)        a_acid
# pca_8     GCUT_SMR_1   BCUT_PEOE_1    PEOE_VSA+5      SMR_VSA7    BCUT_SMR_1
# pca_9         KierA3    PEOE_VSA-0       b_1rotR    SlogP_VSA3    MACCS(-75)
# pca_10      std_dim2          npr1    MACCS(141)    MACCS(149)    MACCS(-93)
# pca_11     vsurf_IW6     vsurf_IW3     vsurf_IW8    MACCS(-25)     vsurf_IW4
# pca_12    MACCS(103)         group  opr_leadlike    PEOE_VSA-1          TEST
# pca_13    MACCS(-65)    SlogP_VSA8    MACCS(108)    MACCS(-26)      SMR_VSA5
# pca_14    MACCS(-36)    BCUT_SMR_1    MACCS(-59)     vsurf_Wp7    MACCS(-81)
# pca_15    MACCS(133)    MACCS(-98)    MACCS(-45)    MACCS(-13)    MACCS(-62)
# pca_16    MACCS(-24)      SMR_VSA1    MACCS(-78)    PEOE_VSA+6    MACCS(113)
# pca_17    PEOE_VSA-0    MACCS(143)    MACCS(-37)    MACCS(117)    MACCS(-46)
# pca_18    MACCS(-43)     vsurf_Wp8    MACCS(110)         E_sol    MACCS(-76)
# pca_19     vsurf_Wp7     vsurf_Wp8    MACCS(109)    vsurf_DD13    SlogP_VSA4
# pca_20    MACCS(-19)   GCUT_PEOE_1    MACCS(114)         E_sol    MACCS(-23)
# pca_21      SMR_VSA2      E_strain    MACCS(-65)  BCUT_SLOGP_1      vsa_base
# pca_22    MACCS(-53)    MACCS(-70)  BCUT_SLOGP_1          npr1      std_dim2
# pca_23          npr2    MACCS(-99)         group          TEST    MACCS(-52)
# pca_24    MACCS(116)      SMR_VSA1     PEOE_RPC-    MACCS(135)        rsynth
# pca_25    MACCS(-34)    MACCS(-13)    MACCS(-84)    MACCS(-37)    MACCS(-26)
# pca_26    MACCS(123)    MACCS(-76)    MACCS(-41)    MACCS(-45)    MACCS(-62)
# pca_27    MACCS(-13)          pmi2    MACCS(-96)         h_pKb  vsurf_EDmin1
# pca_28    MACCS(118)    MACCS(-64)    MACCS(-24)      E_strain    MACCS(-17)
# pca_29    MACCS(114)    MACCS(-89)    MACCS(117)     PEOE_RPC+    MACCS(-37)
# pca_30    MACCS(-38)        rsynth    MACCS(-13)    vsurf_DW23    MACCS(-59)
# pca_31      reactive          TEST    MACCS(-38)    MACCS(-71)      SMR_VSA4
# pca_32    MACCS(-24)    MACCS(-66)    vsurf_DD13         E_oop          conc
# pca_33    MACCS(-92)    MACCS(116)         a_ICM    MACCS(135)    MACCS(-93)
# pca_34    MACCS(-45)     vsurf_Wp7     h_pstrain    SlogP_VSA4    MACCS(-17)
# pca_35      chiral_u          TEST    MACCS(-23)    MACCS(-74)    vsurf_DW12
# pca_36          RPC-     PEOE_RPC+    MACCS(114)          npr2         E_oop
# pca_37         E_ele    MACCS(-95)    MACCS(-64)    vsurf_DD23    vsurf_DD12
# pca_38         h_pKb      chiral_u    vsurf_DW12    MACCS(-59)    MACCS(-64)
# pca_39    MACCS(-78)    MACCS(108)    MACCS(-34)    MACCS(116)    MACCS(-21)
# pca_40      reactive     vsurf_CW2          RPC+    MACCS(-64)    MACCS(-21)
# pca_41    MACCS(-97)          RPC+    MACCS(-73)    MACCS(-23)    MACCS(-64)
# pca_42     vsurf_Wp8         E_oop    MACCS(-23)    MACCS(-74)    MACCS(-64)
# pca_43      SMR_VSA3         h_pKb      SMR_VSA4    MACCS(-13)    vsurf_DD12
# pca_44    PEOE_VSA-2    PEOE_VSA+3    MACCS(-78)    MACCS(-24)    vsurf_DD23
# pca_45    MACCS(-97)         group    MACCS(-91)          TEST    vsurf_DW12
# pca_46         group     vsurf_IW8    MACCS(-34)    MACCS(108)      E_strain
# pca_47    SlogP_VSA4          npr2    MACCS(-23)    MACCS(-13)    MACCS(-34)
# pca_48      SMR_VSA4    MACCS(-38)    MACCS(145)    MACCS(115)     PEOE_RPC+
# pca_49    MACCS(145)    MACCS(-90)         E_ele    vsurf_DW13    MACCS(-41)
# pca_50    MACCS(-43)    vsurf_DD23    PEOE_VSA+5         group    MACCS(-17)
# pca_51   BCUT_PEOE_2    MACCS(-26)    MACCS(162)         E_vdw          npr2
# pca_52    MACCS(-22)    vsurf_DD12     vsurf_IW6    MACCS(-21)    MACCS(-74)
#
#                  330
# pca_1       PEOE_PC-
# pca_2      vsurf_CW1
# pca_3        FCharge
# pca_4     MACCS(112)
# pca_5      opr_nring
# pca_6     PEOE_VSA+4
# pca_7     MACCS(--8)
# pca_8   BCUT_SLOGP_1
# pca_9     MACCS(126)
# pca_10    SlogP_VSA5
# pca_11     vsurf_IW5
# pca_12    SlogP_VSA6
# pca_13      std_dim3
# pca_14    MACCS(-28)
# pca_15         E_vdw
# pca_16      vsa_base
# pca_17    vsurf_DD23
# pca_18    MACCS(-54)
# pca_19    MACCS(113)
# pca_20    MACCS(109)
# pca_21    PEOE_VSA+6
# pca_22    MACCS(-63)
# pca_23          conc
# pca_24     mutagenic
# pca_25    MACCS(113)
# pca_26    PEOE_VSA-2
# pca_27    MACCS(-37)
# pca_28      std_dim2
# pca_29    MACCS(110)
# pca_30    MACCS(-19)
# pca_31    vsurf_DD23
# pca_32      E_strain
# pca_33      E_strain
# pca_34    vsurf_DW12
# pca_35      b_triple
# pca_36    MACCS(-23)
# pca_37    vsurf_DD13
# pca_38    vsurf_DD12
# pca_39         E_oop
# pca_40         E_oop
# pca_41    MACCS(-34)
# pca_42      E_strain
# pca_43    MACCS(-21)
# pca_44    MACCS(-23)
# pca_45    MACCS(-43)
# pca_46        rsynth
# pca_47    MACCS(116)
# pca_48          RPC+
# pca_49    MACCS(-84)
# pca_50          TEST
# pca_51        rsynth
# pca_52    MACCS(-91)
#
# [52 rows x 331 columns]

# %%
def get_important_features(transformed_features, components_, columns):
    """
    This function will return the most "important" 
    features so we can determine which have the most
    effect on multi-dimensional scaling
    """
    num_columns = len(columns)

    # Scale the principal components by the max value in
    # the transformed set belonging to that component
    xvector = components_[0] * max(transformed_features[:,0])
    yvector = components_[1] * max(transformed_features[:,1])

    # Sort each column by it's length. These are your *original*
    # columns, not the principal components.
    important_features = { columns[i] : math.sqrt(xvector[i]**2 + yvector[i]**2) for i in range(num_columns) }
    important_features = sorted(zip(important_features.values(), important_features.keys()), reverse=True)
    print(len(important_features),"Features by importance:\n", important_features)
    return important_features

#print(pca.explained_variance_ratio_)

important_features = get_important_features(pca_site, pca.components_, X_df2.columns)
# Out:
# 331 Features by importance:
#  [(4.807353604614102, 'chi0v'), (4.805464499067002, 'PEOE_VSA_HYD'), (4.710034740400617, 'mr'), (4.653109086372897, 'a_hyd'), (4.427109601888707, 'KierA2'), (4.377440474471958, 'KierA1'), (4.285063562857592, 'vsurf_R'), (4.18461304214408, 'Weight'), (4.1456466460162, 'vsurf_D3'), (4.113097458406033, 'vsurf_Wp1'), (4.049891256284833, 'vsurf_CW1'), (4.047480702115112, 'a_nC'), (3.9877197938418307, 'weinerPol'), (3.929671229652503, 'pmi1'), (3.928274444375502, 'weinerPath'), (3.915130895567107, 'VAdjMa'), (3.8910955645261756, 'Q_VSA_NEG'), (3.8891496587266006, 'ASA_H'), (3.8471112677762433, 'b_count'), (3.8101114242198464, 'logP(o/w)'), (3.74873793073425, 'rgyr'), (3.7174252264942926, 'vsurf_W1'), (3.7118484961513887, 'Kier2'), (3.699894311998191, 'GCUT_SLOGP_3'), (3.685619231533307, 'SMR_VSA7'), (3.6768704233519007, 'opr_violation'), (3.6711151037955823, 'DASA'), (3.6593895428073515, 'SlogP'), (3.649305576566002, 'pmi2'), (3.6451650315540842, 'radius'), (3.6408240188600485, 'KierFlex'), (3.622750613708704, 'chi1_C'), (3.5751838394442035, 'SMR_VSA3'), (3.5544599386608255, 'DCASA'), (3.5028231394865035, 'PEOE_VSA_FPOL'), (3.493190437434493, 'KierA3'), (3.436456234007042, 'vsurf_G'), (3.426701192590296, 'vsurf_D8'), (3.395949912010774, 'VDistEq'), (3.3914297074655604, 'SlogP_VSA9'), (3.34236416606403, 'h_logS'), (3.3311528543068945, 'RPC+'), (3.3273514782918383, 'Q_PC+'), (3.3018459889096152, 'opr_brigid'), (3.2820017951177936, 'MACCS(140)'), (3.26891232322066, 'PEOE_VSA_POS'), (3.255250265122685, 'MACCS(152)'), (3.253415337084865, 'MACCS(157)'), (3.241169580297673, 'PEOE_PC+'), (3.229037073371386, 'Q_VSA_FPPOS'), (3.2033583979982305, 'GCUT_SLOGP_2'), (3.1973077826614715, 'MACCS(163)'), (3.1962662646589726, 'E_str'), (3.1884587927806716, 'MACCS(127)'), (3.18244192297074, 'opr_nrot'), (3.1817675821377556, 'GCUT_SLOGP_1'), (3.1748672613618893, 'chiral'), (3.17327159348618, 'PEOE_RPC+'), (3.164382400270617, 'ASA-'), (3.137531933499809, 'MACCS(150)'), (3.137408856981717, 'a_nH'), (3.121495068055249, 'PEOE_PC-'), (3.1205805454272175, 'BCUT_SLOGP_2'), (3.1146311218898375, 'PEOE_VSA_FPNEG'), (3.101468752035357, 'GCUT_SMR_2'), (3.0945026985556234, 'vsurf_EWmin1'), (3.0417068646049024, 'PEOE_VSA_POL'), (3.0401165047935734, 'Q_VSA_PPOS'), (3.038731321508587, 'E_vdw'), (3.03841846292492, 'std_dim1'), (3.0382715306536556, 'PEOE_VSA_FPPOS'), (3.0313205148533156, 'vsurf_CW3'), (3.0291650203720564, 'vsurf_Wp2'), (3.0125899360630117, 'ENV_CHEM'), (2.993799761495097, 'MACCS(159)'), (2.9869126776247232, 'PEOE_VSA_FPOS'), (2.9463830485402323, 'MACCS(143)'), (2.943368735733263, 'MACCS(-72)'), (2.93444517720402, 'ASA+'), (2.9279653577173117, 'vsurf_W2'), (2.8776667026158678, 'SlogP_VSA2'), (2.8719834814245564, 'Kier3'), (2.859649575273465, 'MACCS(158)'), (2.850935933201833, 'BCUT_SMR_2'), (2.8501767941408076, 'a_donacc'), (2.8422605910885994, 'MACCS(145)'), (2.8365638683068677, 'MACCS(141)'), (2.828023094595015, 'vsurf_CW6'), (2.823706280716695, 'RPC-'), (2.822571027958134, 'h_emd_C'), (2.8020357639767957, 'Q_VSA_POL'), (2.7951702064893182, 'vsurf_IW2'), (2.767138207356174, 'opr_leadlike'), (2.766474725148047, 'vsurf_IW1'), (2.7548912667072685, 'MACCS(149)'), (2.7471513963940604, 'PEOE_VSA-1'), (2.7469445487501063, 'MACCS(144)'), (2.7404519247695633, 'PEOE_VSA_PNEG'), (2.7382306309630025, 'FASA+'), (2.7325165613788114, 'PEOE_VSA+0'), (2.7261851825042087, 'PEOE_VSA_PPOS'), (2.7261217305557297, 'FASA_P'), (2.6911881036696736, 'vsurf_ID3'), (2.651152380344185, 'GCUT_PEOE_0'), (2.647114896892918, 'CASA-'), (2.646318637919491, 'vsa_acc'), (2.6341188140536658, 'vsurf_HB3'), (2.6156301407469553, 'opr_nring'), (2.605873760975823, 'MACCS(134)'), (2.6052654550794916, 'MACCS(-89)'), (2.60278962140512, 'SlogP_VSA0'), (2.5995007554783625, 'MACCS(156)'), (2.5904835329027764, 'h_ema'), (2.5851828244080943, 'MACCS(103)'), (2.56755740096276, 'MACCS(104)'), (2.5539064105317797, 'ASA_P'), (2.553493453157507, 'vsurf_W6'), (2.5424933116879855, 'vsurf_ID6'), (2.541986552969 ...

# %%
# from sklearn.decomposition import PCA
# import pandas as pd
# import numpy as np
# np.random.seed(0)

# # 10 samples with 5 features
# train_features = np.random.rand(10,5)

# model = PCA(n_components=2).fit(train_features)
# X_pc = model.transform(train_features)
# x_pca
# number of components
n_pcs= pca.components_.shape[0]

# get the index of the most important feature on EACH component
# LIST COMPREHENSION HERE
most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]

initial_feature_names = X_df2.columns.values
# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]
print(most_important_names)

# LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df = pd.DataFrame(dic.items())


df
# Out:
# ['Q_PC+', 'PEOE_VSA_HYD', 'FCharge', 'h_log_pbo', 'MACCS(-58)', 'E', 'MACCS(-77)', 'MACCS(-73)', 'glob', 'SlogP_VSA5', 'MACCS(102)', 'MACCS(-46)', 'MACCS(-57)', 'MACCS(-70)', 'MACCS(-83)', 'MACCS(114)', 'mutagenic', 'MACCS(-24)', 'MACCS(113)', 'b_triple', 'MACCS(-78)', 'MACCS(-22)', 'conc', 'MACCS(-28)', 'MACCS(113)', 'vsurf_Wp8', 'MACCS(-37)', 'vsurf_DW13', 'MACCS(-13)', 'MACCS(-19)', 'vsurf_DD23', 'h_pstrain', 'MACCS(-23)', 'MACCS(-53)', 'MACCS(-26)', 'MACCS(-21)', 'vsurf_DD13', 'MACCS(-23)', 'E_oop', 'MACCS(-34)', 'MACCS(-34)', 'MACCS(-17)', 'MACCS(-34)', 'MACCS(-21)', 'MACCS(-43)', 'rsynth', 'MACCS(116)', 'vsurf_DW12', 'MACCS(-17)', 'TEST', 'rsynth', 'MACCS(115)']
#        0             1
# 0    PC0         Q_PC+
# 1    PC1  PEOE_VSA_HYD
# 2    PC2       FCharge
# 3    PC3     h_log_pbo
# 4    PC4    MACCS(-58)
# 5    PC5             E
# 6    PC6    MACCS(-77)
# 7    PC7    MACCS(-73)
# 8    PC8          glob
# 9    PC9    SlogP_VSA5
# 10  PC10    MACCS(102)
# 11  PC11    MACCS(-46)
# 12  PC12    MACCS(-57)
# 13  PC13    MACCS(-70)
# 14  PC14    MACCS(-83)
# 15  PC15    MACCS(114)
# 16  PC16     mutagenic
# 17  PC17    MACCS(-24)
# 18  PC18    MACCS(113)
# 19  PC19      b_triple
# 20  PC20    MACCS(-78)
# 21  PC21    MACCS(-22)
# 22  PC22          conc
# 23  PC23    MACCS(-28)
# 24  PC24    MACCS(113)
# 25  PC25     vsurf_Wp8
# 26  PC26    MACCS(-37)
# 27  PC27    vsurf_DW13
# 28  PC28    MACCS(-13)
# 29  PC29    MACCS(-19)
# 30  PC30    vsurf_DD23
# 31  PC31     h_pstrain
# 32  PC32    MACCS(-23)
# 33  PC33    MACCS(-53)
# 34  PC34    MACCS(-26)
# 35  PC35    MACCS(-21)
# 36  PC36    vsurf_DD13
# 37  PC37    MACCS(-23)
# 38  PC38         E_oop
# 39  PC39    MACCS(-34)
# 40  PC40    MACCS(-34)
# 41  PC41    MACCS(-17)
# 42  PC42    MACCS(-34)
# 43  PC43    MACCS(-21)
# 44  PC44    MACCS(-43)
# 45  PC45        rsynth
# 46  PC46    MACCS(116)
# 47  PC47    vsurf_DW12
# 48  PC48    MACCS(-17)
# 49  PC49          TEST
# 50  PC50        rsynth
# 51  PC51    MACCS(115)

# %% [markdown]
# ## 7. SelectKBest
#     on the scaled dataframe (df3) - save to csv : df_SelectKBest.csv

# %%
df3
# Out:
#            conc  ENV_CHEM      ASA+      ASA-     ASA_H     ASA_P    a_acid  \
# index
# 1      0.465633  0.805387 -0.313757 -1.007823 -1.224640 -0.084355 -0.392017
# 2     -0.734999  0.805387  0.506408 -1.259266 -1.633506  1.217306 -0.392017
# 3      0.301070  0.805387  0.041518 -0.059331  0.255527 -0.341123 -0.392017
# 4      0.464808  0.805387 -0.002819 -1.312852 -1.036761 -0.239164 -0.392017
# 5     -1.332866  0.805387  0.165890 -0.062957 -0.697547  1.255967  2.081746
# ...         ...       ...       ...       ...       ...       ...       ...
# 179   -3.469375  0.805387  1.155088 -0.447901  0.082529  0.912008 -0.392017
# 180    0.494250 -1.241639 -0.678569  0.621579 -0.382537  0.234038 -0.392017
# 181    0.494250 -1.241639 -0.681108  0.691204  0.672012 -0.965153 -0.392017
# 182    0.494250 -1.241639 -0.733003  0.828976 -0.278066  0.267224 -0.392017
# 183    0.494250 -1.241639 -1.364876  1.309021 -1.950492  1.984357 -0.392017
#
#          a_base     a_don  a_donacc  ...  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  \
# index                                ...
# 1     -0.628828  1.346150  0.605165  ...   0.780186  -0.226971  -0.074125
# 2     -0.628828  2.331532  1.972389  ...   4.658291  11.873983  13.490738
# 3     -0.628828 -0.624614  0.263359  ...  -0.651730  -0.226971  -0.074125
# 4      1.114741 -0.624614 -0.762059  ...  -0.055099  -0.226971  -0.074125
# 5     -0.628828  1.346150  0.946971  ...   1.197828  -0.226971  -0.074125
# ...         ...       ...       ...  ...        ...        ...        ...
# 179    1.114741  2.331532  1.288777  ...   1.436480   0.754187  -0.074125
# 180   -0.628828 -0.624614 -0.762059  ...  -0.651730  -0.226971  -0.074125
# 181   -0.628828 -0.624614 -0.762059  ...  -0.651730  -0.226971  -0.074125
# 182   -0.628828 -0.624614 -0.762059  ...  -0.651730  -0.226971  -0.074125
# 183   -0.628828 -0.624614 -0.762059  ...  -0.651730  -0.226971  -0.074125
#
#          Weight  weinerPath  weinerPol      TEST   CHARGED     group  \
# index
# 1     -1.510011   -0.615007  -1.495996 -0.494872 -0.805387 -0.939166
# 2     -0.928176   -0.415341  -0.771918 -0.494872 -0.805387 -0.939166
# 3     -0.271524   -0.086275   0.412937 -0.494872 -0.805387 -0.939166
# 4     -1.627466   -0.642835  -1.627647 -0.494872  1.241639  0.652199
# 5      0.039899    0.219138   0.347111  2.020726  1.241639  2.243563
# ...         ...         ...        ...       ...       ...       ...
# 179   -0.109270    0.387498  -0.047840 -0.494872  1.241639  0.652199
# 180    0.087739   -0.275505  -0.311141 -0.494872 -0.805387 -0.939166
# 181   -0.198774   -0.310986  -0.508617 -0.494872 -0.805387 -0.939166
# 182    0.087739   -0.258808  -0.376967 -0.494872 -0.805387 -0.939166
# 183    0.792891   -0.363859   1.005364 -0.494872 -0.805387 -0.939166
#
#        Log_MP_RATIO
# index
# 1         -0.119186
# 2          0.423246
# 3         -0.443698
# 4          0.711807
# 5         -0.530178
# ...             ...
# 179        0.176091
# 180        0.472628
# 181        0.667194
# 182        0.850593
# 183        0.847938
#
# [183 rows x 332 columns]

# %%
# function to select the best k number of features with p_value <= 0.05 and f_score >= 5

def select_KBest(x, y, k, p_value_threshold = 0.05, score_threshold = 5):
    feature_selector = SelectKBest(f_regression, k = k)
    fit = feature_selector.fit(x,y)   

    p_values = pd.DataFrame(fit.pvalues_)
    scores = pd.DataFrame(fit.scores_)
    input_variable_names = pd.DataFrame(x.columns)
    support = pd.DataFrame(fit.get_support())
    summary_stats = pd.concat([input_variable_names, p_values, scores, support], axis = 1)
    summary_stats.columns = ["input_variable", "p_value", "f_score", 'support']
    summary_stats.sort_values(by = "p_value", inplace = True)

    
    selected_variables = summary_stats.loc[(summary_stats["f_score"] >= score_threshold) &
                                           (summary_stats["p_value"] <= p_value_threshold)]
    stat_significance = selected_variables
    selected_variables = selected_variables["input_variable"].tolist()
    
    new_features  = fit.get_feature_names_out(x.columns.values)   # # Extract the best features name
    x_new = x[new_features]                      # <- new x dataframe with k number of columns 
    x_selected_variables = x[selected_variables] # <- new x dataframe with selected features with to p_value <= 0.05 and f_score >= 5
       
    return stat_significance, x_new, x_selected_variables, new_features

# %%
x = df3.drop(columns=['Log_MP_RATIO'])
y = df3['Log_MP_RATIO']

# %%
x.shape
# Out:
# (183, 331)

# %%
stat_significance, x_new_kAll, x_selected_variables, new_features_kAll= select_KBest(x, y, 'all')
stat_significance, x_new_k1, x_selected_variables, new_features_k1 = select_KBest(x, y, 1)
stat_significance, x_new_k10, x_selected_variables, new_features_k10 = select_KBest(x, y, 10)
stat_significance, x_new_k50, x_selected_variables, new_features_k50 = select_KBest(x, y, 50)

# %%
stat_significance
# Out:
#     input_variable       p_value     f_score  support
# 58    GCUT_SLOGP_2  2.441057e-19  102.254317     True
# 194     MACCS(154)  4.520721e-19  100.350296     True
# 264       SMR_VSA0  5.269667e-19   99.878696     True
# 296   vsurf_EWmin1  1.354026e-18   96.993315     True
# 277        vsa_acc  3.590804e-18   94.043337     True
# ..             ...           ...         ...      ...
# 15     BCUT_PEOE_1  1.706165e-02    5.796604    False
# 259     SlogP_VSA5  1.784371e-02    5.715289    False
# 162     MACCS(119)  1.821338e-02    5.678136    False
# 121     MACCS(-75)  1.989229e-02    5.518743    False
# 157     MACCS(114)  2.331742e-02    5.233123    False
#
# [202 rows x 4 columns]

# %%
x_new_k10
# Out:
#        ENV_CHEM      DASA  GCUT_SLOGP_2  MACCS(154)  PEOE_VSA_FPNEG  \
# index
# 1      0.805387 -1.294161     -0.687403    0.349138        0.854906
# 2      0.805387 -0.109509     -1.027004    0.349138        1.287014
# 3      0.805387 -1.577503     -0.547918   -0.649179       -0.618081
# 4      0.805387 -0.642459     -0.606131   -0.649179       -0.798898
# 5      0.805387 -1.656184     -0.749591    2.345773        1.631557
# ...         ...       ...           ...         ...             ...
# 179    0.805387 -0.148477     -0.592030    0.349138        0.468895
# 180   -1.241639 -0.092884      0.908113   -0.649179       -0.887643
# 181   -1.241639 -0.022709      0.588175   -0.649179       -0.887643
# 182   -1.241639  0.169973      0.913525   -0.649179       -0.887643
# 183   -1.241639  1.359257      1.303808   -0.649179       -0.887643
#
#        PEOE_VSA_PNEG     SlogP  SMR_VSA0   vsa_acc  vsurf_EWmin1
# index
# 1           0.084470 -0.681544 -0.105379 -0.094626      0.075385
# 2           0.714590 -1.495059  0.154266  0.567452     -1.381186
# 3          -0.586052  0.116252 -0.668632  0.428477     -0.340348
# 4          -0.780435 -0.838528 -0.668632 -0.742288      0.787508
# 5           1.765548 -1.407670  2.028640  1.848359     -1.259704
# ...              ...       ...       ...       ...           ...
# 179         0.690991 -0.728189 -0.105379 -0.094626     -1.117011
# 180        -0.827381  0.962972 -0.668632 -0.742288      1.310097
# 181        -0.827381  0.806249 -0.668632 -0.742288      1.404430
# 182        -0.827381  0.962972 -0.668632 -0.742288      1.272281
# 183        -0.827381  0.772658 -0.668632 -0.742288      1.262993
#
# [183 rows x 10 columns]

# %%
df_selected_variables = x_selected_variables.join(df_output)
df_selected_variables
# Out:
#        GCUT_SLOGP_2  MACCS(154)  SMR_VSA0  vsurf_EWmin1   vsa_acc  ENV_CHEM  \
# index
# 1         -0.687403    0.349138 -0.105379      0.075385 -0.094626  0.805387
# 2         -1.027004    0.349138  0.154266     -1.381186  0.567452  0.805387
# 3         -0.547918   -0.649179 -0.668632     -0.340348  0.428477  0.805387
# 4         -0.606131   -0.649179 -0.668632      0.787508 -0.742288  0.805387
# 5         -0.749591    2.345773  2.028640     -1.259704  1.848359  0.805387
# ...             ...         ...       ...           ...       ...       ...
# 179       -0.592030    0.349138 -0.105379     -1.117011 -0.094626  0.805387
# 180        0.908113   -0.649179 -0.668632      1.310097 -0.742288 -1.241639
# 181        0.588175   -0.649179 -0.668632      1.404430 -0.742288 -1.241639
# 182        0.913525   -0.649179 -0.668632      1.272281 -0.742288 -1.241639
# 183        1.303808   -0.649179 -0.668632      1.262993 -0.742288 -1.241639
#
#        PEOE_VSA_FPNEG  PEOE_VSA_PNEG     SlogP      DASA  ...         E  \
# index                                                     ...
# 1            0.854906       0.084470 -0.681544 -1.294161  ... -1.395229
# 2            1.287014       0.714590 -1.495059 -0.109509  ... -2.024936
# 3           -0.618081      -0.586052  0.116252 -1.577503  ...  0.391573
# 4           -0.798898      -0.780435 -0.838528 -0.642459  ... -0.879702
# 5            1.631557       1.765548 -1.407670 -1.656184  ...  1.105015
# ...               ...            ...       ...       ...  ...       ...
# 179          0.468895       0.690991 -0.728189 -0.148477  ... -0.394697
# 180         -0.887643      -0.827381  0.962972 -0.092884  ... -0.133049
# 181         -0.887643      -0.827381  0.806249 -0.022709  ... -0.469584
# 182         -0.887643      -0.827381  0.962972  0.169973  ... -0.200926
# 183         -0.887643      -0.827381  0.772658  1.359257  ...  1.021417
#
#        MACCS(116)  MACCS(-24)  MACCS(-77)  BCUT_PEOE_1  SlogP_VSA5  \
# index
# 1       -0.513691   -0.129099   -0.345986    -0.305803   -0.655781
# 2       -0.513691   -0.129099    3.661318     0.391835   -0.134066
# 3       -0.513691   -0.129099    2.058396    -0.322409   -0.134066
# 4       -0.513691   -0.129099   -0.345986     0.414713   -0.069328
# 5       -0.513691   -0.129099   -0.345986     0.040814   -0.655781
# ...           ...         ...         ...          ...         ...
# 179      1.575318   -0.129099   -0.345986     0.071068   -0.069328
# 180     -0.513691   -0.129099   -0.345986    -0.560425   -0.655781
# 181     -0.513691   -0.129099   -0.345986    -0.553488   -0.537186
# 182     -0.513691   -0.129099   -0.345986    -0.560426   -0.655781
# 183     -0.513691   -0.129099   -0.345986    -0.386182   -0.438174
#
#        MACCS(119)  MACCS(-75)  MACCS(114)  Log_MP_RATIO
# index
# 1       -0.295493   -0.423337   -0.358379     -0.119186
# 2        1.784321    1.038373   -0.358379      0.423246
# 3        1.784321   -0.423337   -0.358379     -0.443698
# 4       -0.295493   -0.423337   -0.358379      0.711807
# 5       -0.295493   -0.423337   -0.358379     -0.530178
# ...           ...         ...         ...           ...
# 179     -0.295493   -0.423337   -0.358379      0.176091
# 180     -0.295493   -0.423337   -0.358379      0.472628
# 181     -0.295493   -0.423337   -0.358379      0.667194
# 182     -0.295493   -0.423337   -0.358379      0.850593
# 183     -0.295493   -0.423337   -0.358379      0.847938
#
# [183 rows x 203 columns]

# %%
missing_features = []
for feature in X_important_descriptors.columns.values:
    if feature not in x_selected_variables.columns.values:
        missing_features.append(feature)
print(len(missing_features),'Important_descriptors for Predicting Milk:Serum Partitioning (table 5) not selected by selectKBest \n  according to p_value f_score : \n', missing_features)
# Out:
# 8 Important_descriptors for Predicting Milk:Serum Partitioning (table 5) not selected by selectKBest
#   according to p_value f_score :
#  ['a_acc', 'h_logP', 'FCASA+', 'h_mr', 'vsurf_DD13', 'SMR_VSA2', 'vsurf_D4', 'b_rotR']

# %%
kBest_list = stat_significance['input_variable'].values
kBest_list
# Out:
# array(['GCUT_SLOGP_2', 'MACCS(154)', 'SMR_VSA0', 'vsurf_EWmin1',
#        'vsa_acc', 'ENV_CHEM', 'PEOE_VSA_FPNEG', 'PEOE_VSA_PNEG', 'SlogP',
#        'DASA', 'b_double', 'GCUT_SLOGP_1', 'vsurf_CW6', 'PEOE_VSA_POL',
#        'MACCS(134)', 'GCUT_SMR_2', 'PEOE_VSA_FPOL', 'vsurf_W6', 'h_ema',
#        'E_sol', 'a_acid', 'BCUT_SLOGP_2', 'logP(o/w)', 'PEOE_VSA-5',
#        'PEOE_PC-', 'density', 'MACCS(123)', 'vsurf_HB3', 'MACCS(156)',
#        'h_pKb', 'SlogP_VSA9', 'PEOE_VSA-6', 'vsurf_IW7', 'vsurf_D8',
#        'vsurf_CW7', 'vsurf_IW6', 'vsurf_ID3', 'vsurf_IW2', 'FASA+',
#        'SlogP_VSA2', 'vsurf_CW3', 'SlogP_VSA0', 'MACCS(-95)',
#        'PEOE_VSA_FPOS', 'vsa_other', 'ASA+', 'vsurf_IW8', 'GCUT_PEOE_0',
#        'GCUT_SMR_1', 'Q_VSA_PPOS', 'MACCS(103)', 'PEOE_VSA+0',
#        'MACCS(136)', 'ASA-', 'SMR_VSA7', 'PEOE_VSA_POS', 'vsurf_CW8',
#        'Q_PC+', 'vsurf_ID6', 'vsurf_W8', 'MACCS(144)', 'MACCS(159)',
#        'vsurf_W2', 'BCUT_SMR_2', 'Q_VSA_FPPOS', 'vsurf_IW1', 'PEOE_VSA+5',
#        'a_donacc', 'MACCS(158)', 'vsurf_HB1', 'Q_VSA_POL', 'vsurf_IW3',
#        'MACCS(-92)', 'a_nH', 'CHARGED', 'BCUT_SLOGP_1', 'vsurf_D3',
#        'MACCS(137)', 'RPC+', 'dipole', 'SlogP_VSA6', 'ASA_P',
#        'PEOE_VSA_PPOS', 'b_count', 'MACCS(110)', 'h_logS', 'PEOE_VSA+3',
#        'MACCS(121)', 'MACCS(-79)', 'BCUT_SMR_0', 'b_1rotN', 'MACCS(-36)',
#        'vsurf_HL2', 'PEOE_VSA-1', 'GCUT_SMR_0', 'MACCS(-97)', 'Q_VSA_NEG',
#        'MACCS(--8)', 'BCUT_SMR_3', 'KierFlex', 'opr_nrot', 'PEOE_PC+',
#        'FASA_P', 'Kier2', 'GCUT_SLOGP_0', 'MACCS(117)', 'MACCS(142)',
#        'MACCS(-85)', 'SlogP_VSA4', 'MACCS(122)', 'PEOE_VSA_FPPOS',
#        'b_1rotR', 'MACCS(-47)', 'SlogP_VSA1', 'a_nC', 'a_don', 'E_tor',
#        'h_emd_C', 'MACCS(-81)', 'opr_violation', 'MACCS(-83)', 'SMR_VSA5',
#        'MACCS(133)', 'MACCS(140)', 'CASA-', 'vsurf_ID7', 'MACCS(-46)',
#        'std_dim2', 'MACCS(120)', 'FCharge', 'SMR_VSA6', 'MACCS(151)',
#        'Q_VSA_PNEG', 'group', 'b_max1len', 'vsurf_ID8', 'E_str',
#        'std_dim1', 'PEOE_VSA+4', 'FCASA-', 'MACCS(157)', 'MACCS(135)',
#        'GCUT_PEOE_1', 'MACCS(-11)', 'MACCS(108)', 'radius', 'Kier3',
#        'Q_VSA_FPNEG', 'vsurf_Wp6', 'h_emd', 'VDistEq', 'vsurf_Wp5',
#        'MACCS(-80)', 'weinerPath', 'chi1_C', 'MACCS(-96)', 'MACCS(150)',
#        'RPC-', 'MACCS(-65)', 'vsurf_G', 'MACCS(155)', 'MACCS(-45)',
#        'MACCS(145)', 'vsurf_IW5', 'MACCS(149)', 'PEOE_VSA-0', 'vsurf_IW4',
#        'std_dim3', 'chiral', 'MACCS(-98)', 'vsurf_CW2', 'MACCS(143)',
#        'Weight', 'MACCS(-78)', 'MACCS(-89)', 'MACCS(125)', 'SlogP_VSA8',
#        'vsurf_W1', 'KierA1', 'MACCS(-99)', 'conc', 'MACCS(-38)',
#        'reactive', 'MACCS(-93)', 'MACCS(-19)', 'vsurf_CW1', 'ASA_H',
#        'BCUT_SMR_1', 'vsa_don', 'vsurf_Wp2', 'MACCS(111)', 'MACCS(-50)',
#        'BCUT_PEOE_2', 'E', 'MACCS(116)', 'MACCS(-24)', 'MACCS(-77)',
#        'BCUT_PEOE_1', 'SlogP_VSA5', 'MACCS(119)', 'MACCS(-75)',
#        'MACCS(114)'], dtype=object)

# %%
communDescriptoPcaSelectKbest = []
print(len(most_important_names))
print(len(kBest_list))
for name in kBest_list:
    if name in most_important_names:
        communDescriptoPcaSelectKbest.append(name)
      

print('Number of descriptors selected in pca and selectKBest : ', len(communDescriptoPcaSelectKbest), '\n', communDescriptoPcaSelectKbest)
# Out:
# 52
# 202
# Number of descriptors selected in pca and selectKBest :  13
#  ['Q_PC+', 'MACCS(-83)', 'MACCS(-46)', 'FCharge', 'MACCS(-78)', 'conc', 'MACCS(-19)', 'E', 'MACCS(116)', 'MACCS(-24)', 'MACCS(-77)', 'SlogP_VSA5', 'MACCS(114)']

# %%
#save selected_variables to csv
df_selected_variablesToCsv=df_selected_variables.join(df_set)

df_selected_variablesToCsv.to_csv('df_KB_selected_variables.csv', encoding='utf-8')

# %%
df_new_k1 = x_new_k1.join(df_output)
df_new_k10 = x_new_k10.join(df_output)
df_new_k50 = x_new_k50.join(df_output)

# %%
df_new_k1ToCsv=df_new_k1.join(df_set)
df_new_k10ToCsv=df_new_k10.join(df_set)
df_new_k50ToCsv=df_new_k50.join(df_set)

# %%
df_new_k1ToCsv.to_csv('df_KB_k1.csv', encoding='utf-8')
df_new_k10ToCsv.to_csv('df_KB_k10.csv', encoding='utf-8')
df_new_k50ToCsv.to_csv('df_KB_k50.csv', encoding='utf-8')

# %% [markdown]
# ## 8. Corrolation with output

# %%
#Corr_list_relevant_features fuction returns a correlation matrix list between features and output > 0.5
def Corr_list_relevant_features(df, target=0.5):
    cor = df.corr()
    cor_target = abs(cor['Log_MP_RATIO'])
    #Selecting highly correlated features
    relevant_features = cor_target[cor_target>target]
    return relevant_features

correlated_features = Corr_list_relevant_features(df3)

print(len(correlated_features) ,'Number of descriptors correlated with y > 0.5','\n', correlated_features)
# Out:
# 22 Number of descriptors correlated with y > 0.5
#  ENV_CHEM          0.582632
# a_acid            0.500293
# b_double          0.543089
# DASA              0.547024
# E_sol             0.502328
# GCUT_SLOGP_1      0.538647
# GCUT_SLOGP_2      0.600831
# GCUT_SMR_2        0.520091
# h_ema             0.505217
# MACCS(134)        0.525753
# MACCS(154)        0.597222
# PEOE_VSA_FPNEG    0.577693
# PEOE_VSA_FPOL     0.516797
# PEOE_VSA_PNEG     0.572234
# PEOE_VSA_POL      0.535125
# SlogP             0.560981
# SMR_VSA0          0.596317
# vsa_acc           0.584741
# vsurf_CW6         0.538361
# vsurf_EWmin1      0.590682
# vsurf_W6          0.513319
# Log_MP_RATIO      1.000000
# Name: Log_MP_RATIO, dtype: float64

# %%
#List of descriptors correlated with y > 0.5
corr_list = correlated_features.index.tolist
corr_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['ENV_CHEM', 'a_acid', 'b_double', 'DASA', 'E_sol', 'GCUT_SLOGP_1',
#        'GCUT_SLOGP_2', 'GCUT_SMR_2', 'h_ema', 'MACCS(134)', 'MACCS(154)',
#        'PEOE_VSA_FPNEG', 'PEOE_VSA_FPOL', 'PEOE_VSA_PNEG', 'PEOE_VSA_POL',
#        'SlogP', 'SMR_VSA0', 'vsa_acc', 'vsurf_CW6', 'vsurf_EWmin1', 'vsurf_W6',
#        'Log_MP_RATIO'],
#       dtype='object')>

# %%
cor = df3.corr()
cor_features_output = abs(cor['Log_MP_RATIO'])

print(cor_features_output.sort_values(kind="quicksort").to_string())
# Out:
# DCASA             0.000522
# MACCS(-23)        0.001704
# vsurf_DW12        0.003492
# MACCS(-58)        0.005912
# SMR_VSA4          0.008597
# MACCS(-22)        0.011252
# b_triple          0.012733
# MACCS(-70)        0.012844
# MACCS(-63)        0.013217
# MACCS(152)        0.013373
# MACCS(-13)        0.014059
# vsurf_DW23        0.016748
# MACCS(-69)        0.017003
# MACCS(-16)        0.017573
# vsurf_DW13        0.017587
# pmi2              0.027423
# MACCS(130)        0.028162
# E_vdw             0.028307
# vsurf_EDmin1      0.028870
# MACCS(-33)        0.029062
# chi0v             0.029070
# MACCS(-28)        0.031065
# MACCS(-43)        0.031296
# vsa_base          0.031545
# MACCS(-73)        0.032222
# PEOE_VSA-2        0.034502
# PEOE_VSA+6        0.034683
# rgyr              0.034770
# npr2              0.035951
# glob              0.036131
# E_strain          0.036501
# vsurf_DD23        0.037458
# vsurf_Wp1         0.038123
# MACCS(-41)        0.040128
# MACCS(-25)        0.040361
# vsurf_Wp7         0.040956
# vsurf_Wp8         0.041239
# MACCS(-57)        0.042795
# MACCS(102)        0.043811
# npr1              0.044932
# MACCS(106)        0.049078
# MACCS(-66)        0.049258
# MACCS(112)        0.049382
# TEST              0.051759
# E_ele             0.052073
# GCUT_PEOE_2       0.052454
# MACCS(113)        0.054581
# MACCS(-34)        0.057012
# MACCS(-62)        0.057994
# chiral_u          0.058876
# MACCS(-59)        0.064169
# MACCS(-82)        0.064520
# MACCS(-21)        0.069271
# MACCS(-42)        0.069784
# E_oop             0.074547
# MACCS(-74)        0.074858
# MACCS(-86)        0.075986
# opr_leadlike      0.076519
# PEOE_RPC+         0.076784
# h_log_pbo         0.077331
# mutagenic         0.079821
# MACCS(101)        0.080286
# MACCS(124)        0.085868
# MACCS(-84)        0.087316
# vsurf_DD12        0.090545
# SMR_VSA1          0.092255
# MACCS(-17)        0.094376
# SMR_VSA2          0.094824
# MACCS(-72)        0.096301
# MACCS(-37)        0.098856
# MACCS(162)        0.098988
# a_base            0.099079
# PEOE_RPC-         0.099403
# MACCS(126)        0.101610
# E_ang             0.102838
# KierA2            0.103064
# MACCS(100)        0.104746
# KierA3            0.106180
# MACCS(163)        0.106511
# pmi1              0.109842
# SMR_VSA3          0.110066
# weinerPol         0.110230
# MACCS(-53)        0.110279
# mr                0.112330
# PEOE_VSA_HYD      0.112901
# BCUT_SLOGP_3      0.116466
# MACCS(-52)        0.116693
# MACCS(-54)        0.119167
# PEOE_VSA-4        0.119899
# MACCS(-71)        0.121773
# MACCS(-26)        0.124150
# vsurf_DD13        0.126220
# MACCS(-64)        0.127973
# MACCS(-94)        0.130010
# MACCS(129)        0.130444
# MACCS(138)        0.131008
# MACCS(141)        0.134606
# MACCS(118)        0.135374
# opr_nring         0.135795
# SlogP_VSA7        0.139100
# MACCS(109)        0.141270
# MACCS(104)        0.141738
# MACCS(-90)        0.146251
# balabanJ          0.146854
# vsurf_Wp3         0.147648
# MACCS(139)        0.149478
# MACCS(115)        0.149533
# h_pKa             0.149534
# MACCS(-91)        0.152267
# GCUT_SLOGP_3      0.153120
# petitjean         0.153541
# opr_brigid        0.153958
# MACCS(131)        0.154106
# h_pstrain         0.154382
# rsynth            0.154499
# a_hyd             0.155062
# VAdjMa            0.155596
# SlogP_VSA3        0.155602
# MACCS(-76)        0.156096
# MACCS(128)        0.156238
# MACCS(105)        0.156620
# MACCS(132)        0.157387
# b_ar              0.158081
# vsurf_R           0.159016
# MACCS(147)        0.159776
# a_ICM             0.160400
# PEOE_VSA+2        0.161924
# MACCS(127)        0.162145
# PEOE_VSA+1        0.163723
# MACCS(114)        0.167630
# MACCS(-75)        0.172012
# MACCS(119)        0.174404
# SlogP_VSA5        0.174956
# BCUT_PEOE_1       0.176158
# MACCS(-77)        0.176710
# MACCS(-24)        0.177282
# MACCS(116)        0.179022
# E                 0.179881
# BCUT_PEOE_2       0.180471
# MACCS(-50)        0.180684
# MACCS(111)        0.181761
# vsurf_Wp2         0.183266
# vsa_don           0.183855
# BCUT_SMR_1        0.184300
# ASA_H             0.187060
# vsurf_CW1         0.187855
# MACCS(-19)        0.187919
# MACCS(-93)        0.188149
# reactive          0.189340
# MACCS(-38)        0.190626
# conc              0.195354
# MACCS(-99)        0.196168
# KierA1            0.196341
# vsurf_W1          0.200875
# SlogP_VSA8        0.202057
# MACCS(125)        0.203994
# MACCS(-89)        0.204476
# MACCS(-78)        0.204482
# Weight            0.204922
# MACCS(143)        0.205635
# vsurf_CW2         0.206492
# MACCS(-98)        0.207420
# chiral            0.207464
# std_dim3          0.207681
# vsurf_IW4         0.207782
# PEOE_VSA-0        0.208301
# MACCS(149)        0.210173
# vsurf_IW5         0.214050
# MACCS(145)        0.215433
# MACCS(-45)        0.215745
# MACCS(155)        0.216940
# vsurf_G           0.218633
# MACCS(-65)        0.218964
# RPC-              0.219569
# MACCS(150)        0.219668
# MACCS(-96)        0.220188
# chi1_C            0.225936
# weinerPath        0.227026
# MACCS(-80)        0.227769
# vsurf_Wp5         0.229302
# VDistEq           0.230061
# h_emd             0.231082
# vsurf_Wp6         0.232716
# Q_VSA_FPNEG       0.232740
# Kier3             0.235702
# radius            0.236138
# MACCS(108)        0.238922
# MACCS(-11)        0.240546
# GCUT_PEOE_1       0.241293
# MACCS(135)        0.241308
# MACCS(157)        0.243581
# FCASA-            0.244022
# PEOE_VSA+4        0.244378
# std_dim1          0.245089
# E_str             0.247636
# vsurf_ID8         0.250790
# b_max1len         0.252854
# group             0.254372
# Q_VSA_PNEG        0.254423
# MACCS(151)        0.259298
# SMR_VSA6          0.260444
# FCharge           0.260930
# MACCS(120)        0.265617
# std_dim2          0.268065
# MACCS(-46)        0.268999
# vsurf_ID7         0.271674
# CASA-             0.271723
# MACCS(140)        0.273969
# MACCS(133)        0.275457
# SMR_VSA5          0.278582
# MACCS(-83)        0.279459
# opr_violation     0.280079
# MACCS(-81)        0.282126
# h_emd_C           0.283098
# E_tor             0.287453
# a_don             0.293512
# a_nC              0.293917
# SlogP_VSA1        0.295837
# MACCS(-47)        0.295994
# b_1rotR           0.298734
# PEOE_VSA_FPPOS    0.299271
# MACCS(122)        0.299957
# SlogP_VSA4        0.301912
# MACCS(-85)        0.302537
# MACCS(142)        0.303740
# MACCS(117)        0.307665
# GCUT_SLOGP_0      0.309309
# Kier2             0.310718
# FASA_P            0.310872
# PEOE_PC+          0.311085
# opr_nrot          0.311526
# KierFlex          0.314953
# BCUT_SMR_3        0.317410
# MACCS(--8)        0.319130
# Q_VSA_NEG         0.322032
# MACCS(-97)        0.323350
# GCUT_SMR_0        0.323433
# PEOE_VSA-1        0.323847
# vsurf_HL2         0.325577
# MACCS(-36)        0.328484
# b_1rotN           0.339138
# BCUT_SMR_0        0.341168
# MACCS(-79)        0.344224
# MACCS(121)        0.345501
# PEOE_VSA+3        0.351037
# h_logS            0.352773
# MACCS(110)        0.353517
# b_count           0.353628
# PEOE_VSA_PPOS     0.355262
# ASA_P             0.356317
# SlogP_VSA6        0.357914
# dipole            0.358047
# RPC+              0.359248
# MACCS(137)        0.359677
# vsurf_D3          0.363969
# BCUT_SLOGP_1      0.369185
# CHARGED           0.369325
# a_nH              0.379325
# MACCS(-92)        0.379866
# vsurf_IW3         0.380397
# Q_VSA_POL         0.381943
# vsurf_HB1         0.381953
# MACCS(158)        0.382854
# a_donacc          0.382938
# PEOE_VSA+5        0.390327
# vsurf_IW1         0.390808
# Q_VSA_FPPOS       0.397454
# BCUT_SMR_2        0.398307
# vsurf_W2          0.401321
# MACCS(159)        0.404792
# MACCS(144)        0.407664
# vsurf_W8          0.412042
# vsurf_ID6         0.412949
# Q_PC+             0.414380
# vsurf_CW8         0.414800
# PEOE_VSA_POS      0.414868
# SMR_VSA7          0.418641
# ASA-              0.420800
# MACCS(136)        0.421460
# PEOE_VSA+0        0.422046
# MACCS(103)        0.423257
# Q_VSA_PPOS        0.426058
# GCUT_SMR_1        0.426357
# GCUT_PEOE_0       0.427606
# vsurf_IW8         0.429953
# ASA+              0.439010
# vsa_other         0.445519
# PEOE_VSA_FPOS     0.445710
# MACCS(-95)        0.446639
# SlogP_VSA0        0.448073
# vsurf_CW3         0.449484
# SlogP_VSA2        0.454312
# FASA+             0.456056
# vsurf_IW2         0.457351
# vsurf_ID3         0.461601
# vsurf_IW6         0.461873
# vsurf_CW7         0.466214
# vsurf_D8          0.466910
# vsurf_IW7         0.467605
# PEOE_VSA-6        0.474963
# SlogP_VSA9        0.476146
# h_pKb             0.482488
# MACCS(156)        0.488767
# vsurf_HB3         0.491140
# MACCS(123)        0.491722
# density           0.492280
# PEOE_PC-          0.492949
# PEOE_VSA-5        0.497767
# logP(o/w)         0.497841
# BCUT_SLOGP_2      0.498721
# a_acid            0.500293
# E_sol             0.502328
# h_ema             0.505217
# vsurf_W6          0.513319
# PEOE_VSA_FPOL     0.516797
# GCUT_SMR_2        0.520091
# MACCS(134)        0.525753
# PEOE_VSA_POL      0.535125
# vsurf_CW6         0.538361
# GCUT_SLOGP_1      0.538647
# b_double          0.543089
# DASA              0.547024
# SlogP             0.560981
# PEOE_VSA_PNEG     0.572234
# PEOE_VSA_FPNEG    0.577693
# ENV_CHEM          0.582632
# vsa_acc           0.584741
# vsurf_EWmin1      0.590682
# SMR_VSA0          0.596317
# MACCS(154)        0.597222
# GCUT_SLOGP_2      0.600831
# Log_MP_RATIO      1.000000

# %%
# plot corrolation with y

sns.heatmap(cor_features_output.sort_values(ascending=False, kind="quicksort").to_frame())
# Out:
# <AxesSubplot:>

# %%
#only 5 features from important_descriptors are highly correlated with output
Corr_list_relevant_features(df_important_descriptors)
# Out:
# DASA            0.547024
# h_ema           0.505217
# GCUT_SLOGP_2    0.600831
# GCUT_SMR_2      0.520091
# Log_MP_RATIO    1.000000
# Name: Log_MP_RATIO, dtype: float64

# %%
# Function to split the dataframe according to the column  'set' stored in df_set above
# as defined in the 'milk_plasma_all_data_mrg_020821.xlsx' first sheet 'full_dataset'
# and split input (X)/output(y) 

def split(df, df_set=df_set):
    df = df.join(df_set)
    split = df.groupby('set')
    test = split.get_group('TEST')
    training = split.get_group('TRAINING')

    df_Test = test.apply(lambda x: x)
    df_Training = training.apply(lambda x: x)
    X_test = df_Test.drop(columns=['Log_MP_RATIO','set'])
    X_train = df_Training .drop(columns=['Log_MP_RATIO','set'])
    y_test = df_Test['Log_MP_RATIO']
    y_train = df_Training['Log_MP_RATIO']
    return X_test, X_train, y_test, y_train

# %%
X_test, X_train, y_test, y_train = split(df3, df_set)

# %%
X_test.shape, X_train.shape, y_test.shape, y_train.shape
# Out:
# ((37, 331), (146, 331), (37,), (146,))

# %%
type(X_train.shape[1])
# Out:
# int

# %% [markdown]
# ## 9. Find outliers

# %%
#function to find outliers using IQR

def find_outliers_IQR(df):
    q1=df.quantile(0.25)
    q3=df.quantile(0.75)
    IQR=q3-q1
    outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
    return outliers

# %%
#find outliers in df
def df_listOutliers(df):
    listOutliers=[]
    for c in df.columns:
        if len(find_outliers_IQR(df[c]))>0:
            listOutliers.append((c,len(find_outliers_IQR(df[c]))))
    
    return len(listOutliers), listOutliers

# %%
#find outliers in df3
df_listOutliers(df3)
# Out:
# (286,
#  [('conc', 35),
#   ('ASA+', 1),
#   ('ASA_H', 2),
#   ('ASA_P', 6),
#   ('a_acid', 26),
#   ('a_base', 2),
#   ('a_don', 11),
#   ('a_donacc', 3),
#   ('a_hyd', 6),
#   ('a_ICM', 7),
#   ('a_nC', 8),
#   ('a_nH', 3),
#   ('balabanJ', 7),
#   ('BCUT_PEOE_1', 10),
#   ('BCUT_PEOE_2', 19),
#   ('BCUT_SLOGP_1', 4),
#   ('BCUT_SLOGP_3', 7),
#   ('BCUT_SMR_1', 10),
#   ('BCUT_SMR_2', 3),
#   ('BCUT_SMR_3', 1),
#   ('b_1rotN', 1),
#   ('b_1rotR', 4),
#   ('b_count', 3),
#   ('b_double', 23),
#   ('b_max1len', 3),
#   ('b_triple', 4),
#   ('CASA-', 18),
#   ('chi0v', 9),
#   ('chi1_C', 3),
#   ('chiral', 18),
#   ('chiral_u', 37),
#   ('DCASA', 8),
#   ('density', 3),
#   ('dipole', 5),
#   ('E', 13),
#   ('E_ang', 9),
#   ('E_ele', 37),
#   ('E_oop', 48),
#   ('E_sol', 6),
#   ('E_str', 13),
#   ('E_strain', 27),
#   ('E_tor', 8),
#   ('E_vdw', 9),
#   ('FASA_P', 2),
#   ('FCASA-', 17),
#   ('FCharge', 3),
#   ('GCUT_PEOE_1', 10),
#   ('GCUT_PEOE_2', 4),
#   ('GCUT_SLOGP_1', 3),
#   ('GCUT_SLOGP_3', 8),
#   ('GCUT_SMR_1', 6),
#   ('glob', 7),
#   ('h_ema', 13),
#   ('h_emd_C', 2),
#   ('h_pstrain', 32),
#   ('Kier2', 9),
#   ('Kier3', 14),
#   ('KierA1', 5),
#   ('KierA2', 5),
#   ('KierA3', 6),
#   ('KierFlex', 8),
#   ('MACCS(--8)', 8),
#   ('MACCS(-11)', 9),
#   ('MACCS(-13)', 1),
#   ('MACCS(-16)', 2),
#   ('MACCS(-17)', 1),
#   ('MACCS(-19)', 18),
#   ('MACCS(-21)', 1),
#   ('MACCS(-22)', 3),
#   ('MACCS(-23)', 1),
#   ('MACCS(-24)', 3),
#   ('MACCS(-25)', 6),
#   ('MACCS(-26)', 4),
#   ('MACCS(-28)', 5),
#   ('MACCS(-33)', 4),
#   ('MACCS(-34)', 1),
#   ('MACCS(-36)', 15),
#   ('MACCS(-37)', 8),
#   ('MACCS(-38)', 14),
#   ('MACCS(-41)', 3),
#   ('MACCS(-42)', 15),
#   ('MACCS(-43)', 4),
#   ('MACCS(-45)', 11),
#   ('MACCS(-46)', 13),
#   ('MACCS(-47)', 9),
#   ('MACCS(-50)', 23),
#   ('MACCS(-52)', 8),
#   ('MACCS(-53)', 14),
#   ('MACCS(-54)', 24),
#   ('MACCS(-57)', 32),
#   ('MACCS(-58)', 5),
#   ('MACCS(-59)', 8),
#   ('MACCS(-63)', 4),
#   ('MACCS(-64)', 5),
#   ('MACCS(-65)', 26),
#   ('MACCS(-66)', 28),
#   ('MACCS(-69)', 3),
#   ('MACCS(-70)', 5),
#   ('MACCS(-71)', 9),
#   ('MACCS(-72)', 34),
#   ('MACCS(-73)', 8),
#   ('MACCS(-74)', 25),
#   ('MACCS(-75)', 36),
#   ('MACCS(-76)', 25),
#   ('MACCS(-77)', 22),
#   ('MACCS(-78)', 15),
#   ('MACCS(-79)', 39),
#   ('MACCS(-80)', 38),
#   ('MACCS(-81)', 20),
#   ('MACCS(-83)', 43),
#   ('MACCS(-84)', 41),
#   ('MACCS(-85)', 6),
#   ('MACCS(-86)', 45),
#   ('MACCS(-89)', 27),
#   ('MACCS(-90)', 40),
#   ('MACCS(-91)', 43),
#   ('MACCS(-92)', 39),
#   ('MACCS(-93)', 4),
#   ('MACCS(-94)', 18),
#   ('MACCS(-95)', 11),
#   ('MACCS(-97)', 22),
#   ('MACCS(-98)', 12),
#   ('MACCS(-99)', 30),
#   ('MACCS(100)', 12),
#   ('MACCS(101)', 11),
#   ('MACCS(102)', 15),
#   ('MACCS(103)', 1),
#   ('MACCS(104)', 3),
#   ('MACCS(105)', 1),
#   ('MACCS(106)', 28),
#   ('MACCS(108)', 33),
#   ('MACCS(109)', 39),
#   ('MACCS(110)', 42),
#   ('MACCS(111)', 12),
#   ('MACCS(112)', 40),
#   ('MACCS(113)', 5),
#   ('MACCS(114)', 23),
#   ('MACCS(115)', 43),
#   ('MACCS(116)', 11),
#   ('MACCS(117)', 23),
#   ('MACCS(118)', 26),
#   ('MACCS(119)', 19),
#   ('MACCS(121)', 17),
#   ('MACCS(122)', 6),
#   ('MACCS(123)', 38),
#   ('MACCS(124)', 21),
#   ('MACCS(126)', 5),
#   ('MACCS(127)', 34),
#   ('MACCS(128)', 39),
#   ('MACCS(129)', 43),
#   ('MACCS(130)', 12),
#   ('MACCS(131)', 45),
#   ('MACCS(132)', 8),
#   ('MACCS(133)', 38),
#   ('MACCS(134)', 2),
#   ('MACCS(135)', 37),
#   ('MACCS(136)', 39),
#   ('MACCS(137)', 2),
#   ('MACCS(138)', 23),
#   ('MACCS(139)', 38),
#   ('MACCS(140)', 29),
#   ('MACCS(141)', 22),
#   ('MACCS(142)', 17),
#   ('MACCS(143)', 11),
#   ('MACCS(147)', 13),
#   ('MACCS(149)', 13),
#   ('MACCS(150)', 1),
#   ('MACCS(151)', 7),
#   ('MACCS(152)', 6),
#   ('MACCS(154)', 12),
#   ('MACCS(155)', 11),
#   ('MACCS(156)', 9),
#   ('MACCS(157)', 5),
#   ('MACCS(159)', 7),
#   ('MACCS(162)', 19),
#   ('MACCS(163)', 2),
#   ('mr', 11),
#   ('mutagenic', 34),
#   ('npr1', 2),
#   ('npr2', 5),
#   ('opr_brigid', 10),
#   ('opr_leadlike', 24),
#   ('opr_nring', 10),
#   ('opr_nrot', 5),
#   ('opr_violation', 5),
#   ('PEOE_PC+', 2),
#   ('PEOE_PC-', 11),
#   ('PEOE_RPC+', 7),
#   ('PEOE_RPC-', 1),
#   ('PEOE_VSA+0', 5),
#   ('PEOE_VSA+1', 11),
#   ('PEOE_VSA+2', 8),
#   ('PEOE_VSA+3', 12),
#   ('PEOE_VSA+4', 8),
#   ('PEOE_VSA+5', 41),
#   ('PEOE_VSA+6', 14),
#   ('PEOE_VSA-0', 14),
#   ('PEOE_VSA-1', 1),
#   ('PEOE_VSA-2', 27),
#   ('PEOE_VSA-4', 36),
#   ('PEOE_VSA-5', 7),
#   ('PEOE_VSA-6', 14),
#   ('PEOE_VSA_FPNEG', 1),
#   ('PEOE_VSA_FPOL', 2),
#   ('PEOE_VSA_FPPOS', 3),
#   ('PEOE_VSA_HYD', 15),
#   ('PEOE_VSA_PNEG', 8),
#   ('PEOE_VSA_POL', 5),
#   ('PEOE_VSA_POS', 3),
#   ('PEOE_VSA_PPOS', 4),
#   ('petitjean', 8),
#   ('pmi1', 9),
#   ('pmi2', 13),
#   ('Q_PC+', 2),
#   ('Q_VSA_FPNEG', 7),
#   ('Q_VSA_NEG', 1),
#   ('Q_VSA_PNEG', 11),
#   ('Q_VSA_POL', 4),
#   ('radius', 3),
#   ('reactive', 29),
#   ('rgyr', 8),
#   ('RPC+', 15),
#   ('RPC-', 3),
#   ('SlogP_VSA0', 3),
#   ('SlogP_VSA1', 12),
#   ('SlogP_VSA2', 16),
#   ('SlogP_VSA3', 28),
#   ('SlogP_VSA4', 25),
#   ('SlogP_VSA5', 9),
#   ('SlogP_VSA6', 2),
#   ('SlogP_VSA8', 16),
#   ('SMR_VSA0', 23),
#   ('SMR_VSA1', 8),
#   ('SMR_VSA2', 6),
#   ('SMR_VSA3', 11),
#   ('SMR_VSA4', 16),
#   ('SMR_VSA6', 13),
#   ('SMR_VSA7', 3),
#   ('std_dim1', 17),
#   ('std_dim2', 6),
#   ('std_dim3', 19),
#   ('VAdjMa', 12),
#   ('VDistEq', 11),
#   ('vsa_acc', 5),
#   ('vsa_base', 32),
#   ('vsa_don', 25),
#   ('vsa_other', 14),
#   ('vsurf_CW1', 13),
#   ('vsurf_CW2', 3),
#   ('vsurf_CW3', 4),
#   ('vsurf_CW6', 5),
#   ('vsurf_CW7', 12),
#   ('vsurf_CW8', 18),
#   ('vsurf_DD12', 44),
#   ('vsurf_DD13', 1),
#   ('vsurf_DD23', 42),
#   ('vsurf_DW12', 35),
#   ('vsurf_DW13', 30),
#   ('vsurf_DW23', 19),
#   ('vsurf_EDmin1', 3),
#   ('vsurf_G', 6),
#   ('vsurf_HB1', 13),
#   ('vsurf_HB3', 9),
#   ('vsurf_HL2', 12),
#   ('vsurf_ID3', 3),
#   ('vsurf_ID6', 3),
#   ('vsurf_ID7', 4),
#   ('vsurf_ID8', 3),
#   ('vsurf_IW1', 1),
#   ('vsurf_R', 6),
#   ('vsurf_W1', 10),
#   ('vsurf_W2', 8),
#   ('vsurf_W6', 10),
#   ('vsurf_W8', 26),
#   ('vsurf_Wp1', 14),
#   ('vsurf_Wp2', 6),
#   ('vsurf_Wp3', 6),
#   ('vsurf_Wp5', 8),
#   ('vsurf_Wp6', 17),
#   ('vsurf_Wp7', 27),
#   ('vsurf_Wp8', 1),
#   ('Weight', 9),
#   ('weinerPath', 19),
#   ('weinerPol', 8),
#   ('TEST', 36),
#   ('Log_MP_RATIO', 5)])

# %% [markdown]
# ## Recursive Feature Elimination

# %%
# RFE with LinearRegression

# %%
X = df3.drop(columns=['Log_MP_RATIO'])
y = df3['Log_MP_RATIO']

# %%
#finding the optimum number of features with highest accuracy.

#no of features
nof_list=np.arange(1,X_train.shape[1]+1)
high_score=0
#Variable to store the optimum features
nof=0
score_list =[]
for n in range(len(nof_list)):
    model = LinearRegression()
    rfe = RFE(model,n_features_to_select=nof_list[n])
    
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
        
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 8
# Score with 8 features: 0.040296

# %%
X_train
# Out:
#            conc  ENV_CHEM      ASA+      ASA-     ASA_H     ASA_P    a_acid  \
# index
# 1      0.465633  0.805387 -0.313757 -1.007823 -1.224640 -0.084355 -0.392017
# 2     -0.734999  0.805387  0.506408 -1.259266 -1.633506  1.217306 -0.392017
# 3      0.301070  0.805387  0.041518 -0.059331  0.255527 -0.341123 -0.392017
# 4      0.464808  0.805387 -0.002819 -1.312852 -1.036761 -0.239164 -0.392017
# 5     -1.332866  0.805387  0.165890 -0.062957 -0.697547  1.255967  2.081746
# ...         ...       ...       ...       ...       ...       ...       ...
# 179   -3.469375  0.805387  1.155088 -0.447901  0.082529  0.912008 -0.392017
# 180    0.494250 -1.241639 -0.678569  0.621579 -0.382537  0.234038 -0.392017
# 181    0.494250 -1.241639 -0.681108  0.691204  0.672012 -0.965153 -0.392017
# 182    0.494250 -1.241639 -0.733003  0.828976 -0.278066  0.267224 -0.392017
# 183    0.494250 -1.241639 -1.364876  1.309021 -1.950492  1.984357 -0.392017
#
#          a_base     a_don  a_donacc  ...  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  \
# index                                ...
# 1     -0.628828  1.346150  0.605165  ...   0.609743   0.780186  -0.226971
# 2     -0.628828  2.331532  1.972389  ...   2.897804   4.658291  11.873983
# 3     -0.628828 -0.624614  0.263359  ...  -0.755999  -0.651730  -0.226971
# 4      1.114741 -0.624614 -0.762059  ...   1.035428  -0.055099  -0.226971
# 5     -0.628828  1.346150  0.946971  ...   1.336956   1.197828  -0.226971
# ...         ...       ...       ...  ...        ...        ...        ...
# 179    1.114741  2.331532  1.288777  ...   2.277012   1.436480   0.754187
# 180   -0.628828 -0.624614 -0.762059  ...  -0.755999  -0.651730  -0.226971
# 181   -0.628828 -0.624614 -0.762059  ...  -0.755999  -0.651730  -0.226971
# 182   -0.628828 -0.624614 -0.762059  ...  -0.755999  -0.651730  -0.226971
# 183   -0.628828 -0.624614 -0.762059  ...  -0.755999  -0.651730  -0.226971
#
#        vsurf_Wp8    Weight  weinerPath  weinerPol      TEST   CHARGED  \
# index
# 1      -0.074125 -1.510011   -0.615007  -1.495996 -0.494872 -0.805387
# 2      13.490738 -0.928176   -0.415341  -0.771918 -0.494872 -0.805387
# 3      -0.074125 -0.271524   -0.086275   0.412937 -0.494872 -0.805387
# 4      -0.074125 -1.627466   -0.642835  -1.627647 -0.494872  1.241639
# 5      -0.074125  0.039899    0.219138   0.347111  2.020726  1.241639
# ...          ...       ...         ...        ...       ...       ...
# 179    -0.074125 -0.109270    0.387498  -0.047840 -0.494872  1.241639
# 180    -0.074125  0.087739   -0.275505  -0.311141 -0.494872 -0.805387
# 181    -0.074125 -0.198774   -0.310986  -0.508617 -0.494872 -0.805387
# 182    -0.074125  0.087739   -0.258808  -0.376967 -0.494872 -0.805387
# 183    -0.074125  0.792891   -0.363859   1.005364 -0.494872 -0.805387
#
#           group
# index
# 1     -0.939166
# 2     -0.939166
# 3     -0.939166
# 4      0.652199
# 5      2.243563
# ...         ...
# 179    0.652199
# 180   -0.939166
# 181   -0.939166
# 182   -0.939166
# 183   -0.939166
#
# [146 rows x 331 columns]

# %%
rfe = RFE(model, n_features_to_select=nof)
rfe.fit(X_train, y_train)
features = X_train.columns
temp = pd.Series(rfe.support_,index= features)
selected_features_RFE = temp[temp==True].index
print(selected_features_RFE)
# Out:
# Index(['BCUT_PEOE_1', 'BCUT_SLOGP_2', 'DASA', 'MACCS(-84)', 'MACCS(150)',
#        'vsurf_ID7', 'vsurf_ID8', 'vsurf_Wp2'],
#       dtype='object')

# %%
# print out the features in order of ranking
from operator import itemgetter
features = X_train.columns.to_list()
for x, y in (sorted(zip(rfe.ranking_ , features), key=itemgetter(0))):
    print(x, y)
# Out:
# 1 BCUT_PEOE_1
# 1 BCUT_SLOGP_2
# 1 DASA
# 1 MACCS(-84)
# 1 MACCS(150)
# 1 vsurf_ID7
# 1 vsurf_ID8
# 1 vsurf_Wp2
# 2 density
# 3 PEOE_VSA+1
# 4 TEST
# 5 MACCS(152)
# 6 PEOE_VSA_PNEG
# 7 MACCS(-92)
# 8 b_1rotR
# 9 vsurf_EDmin1
# 10 vsurf_W1
# 11 MACCS(-63)
# 12 radius
# 13 KierA1
# 14 Kier3
# 15 MACCS(103)
# 16 PEOE_VSA-0
# 17 MACCS(-43)
# 18 MACCS(-82)
# 19 MACCS(129)
# 20 opr_leadlike
# 21 MACCS(109)
# 22 MACCS(132)
# 23 MACCS(-81)
# 24 std_dim3
# 25 vsurf_EWmin1
# 26 MACCS(156)
# 27 MACCS(-96)
# 28 std_dim1
# 29 glob
# 30 npr2
# 31 h_pKa
# 32 PEOE_VSA-4
# 33 MACCS(131)
# 34 vsurf_Wp6
# 35 vsurf_Wp7
# 36 MACCS(119)
# 37 MACCS(-36)
# 38 BCUT_SLOGP_3
# 39 vsurf_IW4
# 40 mutagenic
# 41 vsurf_IW5
# 42 h_pstrain
# 43 VDistEq
# 44 vsurf_IW8
# 45 MACCS(--8)
# 46 MACCS(-47)
# 47 MACCS(116)
# 48 PEOE_RPC+
# 49 GCUT_PEOE_2
# 50 MACCS(111)
# 51 opr_nrot
# 52 MACCS(-50)
# 53 GCUT_SLOGP_0
# 54 h_emd
# 55 PEOE_VSA_FPPOS
# 56 Q_VSA_PPOS
# 57 MACCS(135)
# 58 balabanJ
# 59 GCUT_SMR_2
# 60 PEOE_VSA-2
# 61 MACCS(-52)
# 62 a_don
# 63 PEOE_VSA+2
# 64 BCUT_PEOE_2
# 65 MACCS(-37)
# 66 rgyr
# 67 E_strain
# 68 MACCS(-38)
# 69 KierFlex
# 70 vsurf_D8
# 71 npr1
# 72 MACCS(-41)
# 73 chiral_u
# 74 MACCS(-46)
# 75 MACCS(121)
# 76 MACCS(141)
# 77 h_log_pbo
# 78 weinerPath
# 79 dipole
# 80 vsurf_DD13
# 81 PEOE_VSA+4
# 82 MACCS(118)
# 83 vsurf_D3
# 84 vsurf_ID3
# 85 SlogP_VSA2
# 86 MACCS(162)
# 87 VAdjMa
# 88 MACCS(-80)
# 89 RPC+
# 90 MACCS(123)
# 91 DCASA
# 92 MACCS(108)
# 93 BCUT_SMR_0
# 94 MACCS(-34)
# 95 PEOE_VSA+3
# 96 MACCS(-72)
# 97 SlogP_VSA5
# 98 vsurf_DW23
# 99 vsurf_DW13
# 100 E_ang
# 101 vsurf_IW6
# 102 MACCS(-91)
# 103 vsurf_R
# 104 group
# 105 vsurf_DW12
# 106 SMR_VSA3
# 107 MACCS(105)
# 108 FASA_P
# 109 MACCS(138)
# 110 MACCS(-19)
# 111 PEOE_VSA-1
# 112 vsurf_Wp3
# 113 vsurf_DD23
# 114 SMR_VSA6
# 115 vsurf_W2
# 116 MACCS(-24)
# 117 vsurf_W8
# 118 SMR_VSA0
# 119 vsurf_HB1
# 120 MACCS(-97)
# 121 KierA3
# 122 BCUT_SMR_2
# 123 MACCS(-99)
# 124 MACCS(-22)
# 125 MACCS(-76)
# 126 MACCS(-86)
# 127 MACCS(120)
# 128 MACCS(114)
# 129 BCUT_SMR_1
# 130 PEOE_VSA-5
# 131 vsa_base
# 132 E_vdw
# 133 CHARGED
# 134 Q_VSA_PNEG
# 135 MACCS(140)
# 136 vsurf_CW1
# 137 vsurf_Wp1
# 138 E_sol
# 139 MACCS(115)
# 140 MACCS(147)
# 141 MACCS(106)
# 142 vsurf_HB3
# 143 Q_VSA_NEG
# 144 MACCS(158)
# 145 MACCS(163)
# 146 h_emd_C
# 147 MACCS(125)
# 148 MACCS(-59)
# 149 PEOE_VSA_PPOS
# 150 conc
# 151 vsurf_CW7
# 152 KierA2
# 153 E_str
# 154 h_logS
# 155 BCUT_SLOGP_1
# 156 MACCS(136)
# 157 GCUT_SLOGP_2
# 158 MACCS(-77)
# 159 MACCS(-62)
# 160 MACCS(-98)
# 161 vsurf_Wp5
# 162 vsurf_IW2
# 163 MACCS(137)
# 164 b_ar
# 165 PEOE_RPC-
# 166 Q_VSA_FPPOS
# 167 Weight
# 168 h_pKb
# 169 GCUT_PEOE_1
# 170 MACCS(126)
# 171 vsurf_CW6
# 172 Q_VSA_FPNEG
# 173 MACCS(-90)
# 174 MACCS(-95)
# 175 MACCS(-25)
# 176 vsurf_CW3
# 177 std_dim2
# 178 MACCS(113)
# 179 E
# 180 MACCS(-93)
# 181 b_double
# 182 MACCS(-45)
# 183 vsurf_CW8
# 184 opr_violation
# 185 SlogP
# 186 MACCS(-94)
# 187 MACCS(-69)
# 188 MACCS(-28)
# 189 Q_VSA_POL
# 190 MACCS(110)
# 191 MACCS(-89)
# 192 petitjean
# 193 MACCS(-75)
# 194 SlogP_VSA3
# 195 MACCS(155)
# 196 pmi1
# 197 FCharge
# 198 MACCS(-53)
# 199 MACCS(-71)
# 200 vsurf_IW3
# 201 RPC-
# 202 PEOE_VSA_FPOS
# 203 a_ICM
# 204 PEOE_VSA+5
# 205 MACCS(122)
# 206 MACCS(154)
# 207 SlogP_VSA7
# 208 logP(o/w)
# 209 MACCS(142)
# 210 chi1_C
# 211 ASA-
# 212 MACCS(149)
# 213 MACCS(-54)
# 214 chiral
# 215 SlogP_VSA1
# 216 PEOE_PC+
# 217 vsurf_W6
# 218 PEOE_VSA_FPNEG
# 219 vsurf_HL2
# 220 PEOE_VSA-6
# 221 a_acid
# 222 vsa_don
# 223 MACCS(143)
# 224 MACCS(-79)
# 225 ASA_H
# 226 MACCS(-70)
# 227 ENV_CHEM
# 228 MACCS(159)
# 229 b_triple
# 230 SMR_VSA5
# 231 SMR_VSA7
# 232 MACCS(-66)
# 233 MACCS(139)
# 234 a_base
# 235 MACCS(-42)
# 236 E_tor
# 237 MACCS(-57)
# 238 reactive
# 239 MACCS(104)
# 240 Kier2
# 241 SMR_VSA1
# 242 vsurf_CW2
# 243 vsurf_IW1
# 244 vsurf_ID6
# 245 PEOE_VSA_FPOL
# 246 MACCS(-16)
# 247 opr_nring
# 248 GCUT_SLOGP_3
# 249 vsurf_IW7
# 250 PEOE_VSA_HYD
# 251 SlogP_VSA9
# 252 MACCS(-73)
# 253 a_nH
# 254 MACCS(124)
# 255 MACCS(-33)
# 256 MACCS(117)
# 257 pmi2
# 258 MACCS(-23)
# 259 h_ema
# 260 vsa_acc
# 261 MACCS(-78)
# 262 MACCS(102)
# 263 MACCS(-26)
# 264 MACCS(144)
# 265 GCUT_SMR_1
# 266 vsurf_DD12
# 267 MACCS(130)
# 268 GCUT_PEOE_0
# 269 vsa_other
# 270 MACCS(133)
# 271 MACCS(100)
# 272 SlogP_VSA8
# 273 SlogP_VSA4
# 274 MACCS(-17)
# 275 chi0v
# 276 PEOE_PC-
# 277 MACCS(-83)
# 278 MACCS(-58)
# 279 PEOE_VSA+6
# 280 b_count
# 281 MACCS(-64)
# 282 GCUT_SMR_0
# 283 MACCS(-65)
# 284 MACCS(-85)
# 285 MACCS(-21)
# 286 CASA-
# 287 opr_brigid
# 288 Q_PC+
# 289 FASA+
# 290 rsynth
# 291 ASA_P
# 292 FCASA-
# 293 b_max1len
# 294 SlogP_VSA0
# 295 mr
# 296 MACCS(-74)
# 297 a_donacc
# 298 MACCS(145)
# 299 weinerPol
# 300 MACCS(157)
# 301 MACCS(112)
# 302 a_hyd
# 303 E_oop
# 304 MACCS(127)
# 305 MACCS(-13)
# 306 MACCS(151)
# 307 MACCS(-11)
# 308 SMR_VSA2
# 309 vsurf_G
# 310 vsurf_Wp8
# 311 b_1rotN
# 312 PEOE_VSA_POS
# 313 BCUT_SMR_3
# 314 E_ele
# 315 ASA+
# 316 MACCS(134)
# 317 a_nC
# 318 GCUT_SLOGP_1
# 319 MACCS(128)
# 320 PEOE_VSA+0
# 321 MACCS(101)
# 322 SMR_VSA4
# 323 SlogP_VSA6
# 324 PEOE_VSA_POL

# %%
# print out the features in order of ranking
from operator import itemgetter
features = X_train.columns.to_list()
for x, y in (sorted(zip(rfe.ranking_ , features), key=itemgetter(0))):
    print(x, y)
# Out:
# 1 DASA
# 1 E_sol
# 1 FASA+
# 1 FCharge
# 1 GCUT_SLOGP_2
# 1 GCUT_SLOGP_3
# 1 h_emd
# 1 h_logS
# 1 SlogP_VSA9
# 1 vsa_other
# 2 h_log_pbo
# 3 std_dim2
# 4 SMR_VSA0
# 5 PEOE_VSA_PNEG
# 6 GCUT_SMR_0
# 7 h_emd_C
# 8 RPC-
# 9 PEOE_PC+
# 10 GCUT_PEOE_1
# 11 GCUT_SLOGP_1
# 12 RPC+
# 13 E_oop
# 14 GCUT_SMR_1
# 15 PEOE_VSA_POS
# 16 E
# 17 vsurf_IW2
# 18 BCUT_SMR_3
# 19 ASA+
# 20 npr2
# 21 vsurf_Wp3
# 22 b_1rotR
# 23 SlogP
# 24 weinerPol
# 25 vsurf_IW4
# 26 PEOE_VSA-0
# 27 GCUT_PEOE_0
# 28 Q_VSA_NEG
# 29 Q_VSA_FPPOS
# 30 vsurf_EDmin1
# 31 vsurf_CW8
# 32 SlogP_VSA5
# 33 PEOE_VSA_FPNEG
# 34 DCASA
# 35 balabanJ
# 36 chi1_C
# 37 SMR_VSA3
# 38 h_pstrain
# 39 SlogP_VSA7
# 40 Q_VSA_PPOS
# 41 std_dim3
# 42 PEOE_VSA_FPPOS
# 43 PEOE_VSA+0
# 44 density
# 45 SlogP_VSA1
# 46 PEOE_RPC+
# 47 ASA-
# 48 vsurf_ID8
# 49 vsurf_DD13
# 50 vsurf_Wp2
# 51 GCUT_PEOE_2
# 52 BCUT_SLOGP_3
# 53 E_ang
# 54 vsurf_DD23
# 55 pmi1
# 56 MACCS(108)
# 57 vsurf_ID3
# 58 FCASA-
# 59 Q_VSA_FPNEG
# 60 vsurf_ID7
# 61 PEOE_RPC-
# 62 SMR_VSA1
# 63 logP(o/w)
# 64 vsurf_IW1
# 65 BCUT_SLOGP_1
# 66 SMR_VSA5
# 67 vsurf_CW1
# 68 vsurf_W1
# 69 GCUT_SMR_2
# 70 vsurf_DW13
# 71 vsurf_DD12
# 72 vsurf_IW6
# 73 a_ICM
# 74 vsurf_R
# 75 vsurf_ID6
# 76 BCUT_PEOE_1
# 77 PEOE_VSA+2
# 78 BCUT_PEOE_2
# 79 PEOE_VSA_POL
# 80 E_ele
# 81 GCUT_SLOGP_0
# 82 dipole
# 83 npr1
# 84 SMR_VSA6
# 85 SlogP_VSA4
# 86 vsurf_EWmin1
# 87 weinerPath
# 88 BCUT_SLOGP_2
# 89 PEOE_VSA+1
# 90 vsurf_IW7
# 91 conc
# 92 vsurf_D3
# 93 vsurf_IW5
# 94 rsynth
# 95 vsurf_D8
# 96 SlogP_VSA0
# 97 opr_brigid
# 98 h_ema
# 99 MACCS(150)
# 100 vsurf_CW3
# 101 E_vdw
# 102 BCUT_SMR_0
# 103 vsurf_IW3
# 104 PEOE_VSA_PPOS
# 105 PEOE_VSA_FPOS
# 106 BCUT_SMR_1
# 107 BCUT_SMR_2
# 108 vsurf_G
# 109 PEOE_VSA-1
# 110 E_strain
# 111 std_dim1
# 112 h_pKa
# 113 vsurf_CW2
# 114 KierFlex
# 115 Q_VSA_PNEG
# 116 E_str
# 117 SMR_VSA7
# 118 vsurf_DW12
# 119 a_hyd
# 120 vsurf_Wp5
# 121 PEOE_VSA_FPOL
# 122 Kier3
# 123 E_tor
# 124 vsa_acc
# 125 KierA1
# 126 glob
# 127 vsurf_HB1
# 128 PEOE_PC-
# 129 vsurf_HB3
# 130 SMR_VSA2
# 131 vsurf_CW7
# 132 MACCS(134)
# 133 a_donacc
# 134 MACCS(152)
# 135 KierA3
# 136 chi0v
# 137 vsurf_Wp6
# 138 MACCS(156)
# 139 vsurf_DW23
# 140 ASA_H
# 141 rgyr
# 142 SlogP_VSA8
# 143 h_pKb
# 144 PEOE_VSA_HYD
# 145 PEOE_VSA+4
# 146 vsurf_Wp1
# 147 MACCS(155)
# 148 MACCS(144)
# 149 petitjean
# 150 mr
# 151 Q_VSA_POL
# 152 Q_PC+
# 153 SlogP_VSA3
# 154 MACCS(113)
# 155 vsurf_IW8
# 156 b_1rotN
# 157 VDistEq
# 158 a_nH
# 159 vsurf_W2
# 160 vsurf_W6
# 161 MACCS(105)
# 162 KierA2
# 163 group
# 164 MACCS(-78)
# 165 vsurf_W8
# 166 chiral
# 167 PEOE_VSA+6
# 168 CASA-
# 169 Weight
# 170 PEOE_VSA-6
# 171 PEOE_VSA-4
# 172 FASA_P
# 173 SlogP_VSA2
# 174 vsurf_CW6
# 175 MACCS(154)
# 176 a_nC
# 177 VAdjMa
# 178 MACCS(123)
# 179 b_double
# 180 ASA_P
# 181 b_count
# 182 SlogP_VSA6
# 183 b_max1len
# 184 PEOE_VSA+5
# 185 b_ar
# 186 pmi2
# 187 MACCS(159)
# 188 PEOE_VSA-5
# 189 MACCS(111)
# 190 MACCS(116)
# 191 MACCS(147)
# 192 MACCS(-54)
# 193 MACCS(-82)
# 194 MACCS(-85)
# 195 opr_nring
# 196 MACCS(137)
# 197 Kier2
# 198 MACCS(-91)
# 199 vsurf_HL2
# 200 MACCS(-90)
# 201 MACCS(163)
# 202 MACCS(-79)
# 203 MACCS(126)
# 204 MACCS(143)
# 205 MACCS(157)
# 206 MACCS(-95)
# 207 PEOE_VSA+3
# 208 vsa_don
# 209 MACCS(-83)
# 210 MACCS(149)
# 211 a_base
# 212 opr_nrot
# 213 MACCS(121)
# 214 mutagenic
# 215 MACCS(-75)
# 216 SMR_VSA4
# 217 MACCS(-96)
# 218 chiral_u
# 219 MACCS(-97)
# 220 MACCS(128)
# 221 MACCS(-98)
# 222 MACCS(139)
# 223 MACCS(100)
# 224 MACCS(104)
# 225 MACCS(138)
# 226 MACCS(109)
# 227 MACCS(-92)
# 228 a_don
# 229 MACCS(-89)
# 230 MACCS(117)
# 231 radius
# 232 MACCS(135)
# 233 PEOE_VSA-2
# 234 MACCS(103)
# 235 MACCS(-93)
# 236 MACCS(-62)
# 237 MACCS(131)
# 238 vsurf_Wp7
# 239 MACCS(-74)
# 240 MACCS(-99)
# 241 MACCS(110)
# 242 opr_violation
# 243 MACCS(-66)
# 244 MACCS(158)
# 245 MACCS(-65)
# 246 MACCS(115)
# 247 MACCS(133)
# 248 vsa_base
# 249 MACCS(-72)
# 250 MACCS(112)
# 251 MACCS(151)
# 252 MACCS(132)
# 253 MACCS(118)
# 254 MACCS(-57)
# 255 MACCS(120)
# 256 MACCS(119)
# 257 MACCS(-86)
# 258 MACCS(122)
# 259 MACCS(-84)
# 260 MACCS(129)
# 261 MACCS(142)
# 262 MACCS(-50)
# 263 MACCS(106)
# 264 MACCS(124)
# 265 MACCS(145)
# 266 MACCS(140)
# 267 MACCS(114)
# 268 MACCS(-76)
# 269 opr_leadlike
# 270 MACCS(141)
# 271 MACCS(125)
# 272 MACCS(127)
# 273 CHARGED
# 274 MACCS(102)
# 275 MACCS(-80)
# 276 MACCS(-46)
# 277 MACCS(-73)
# 278 TEST
# 279 MACCS(-94)
# 280 MACCS(136)
# 281 MACCS(-52)
# 282 MACCS(-77)
# 283 MACCS(-11)
# 284 MACCS(-36)
# 285 MACCS(-42)
# 286 MACCS(-81)
# 287 MACCS(162)
# 288 MACCS(101)
# 289 MACCS(-53)
# 290 reactive
# 291 MACCS(-38)
# 292 b_triple
# 293 MACCS(-45)
# 294 MACCS(-37)
# 295 MACCS(-71)
# 296 a_acid
# 297 MACCS(-19)
# 298 MACCS(-70)
# 299 MACCS(-26)
# 300 MACCS(-22)
# 301 MACCS(-33)
# 302 MACCS(-25)
# 303 MACCS(-63)
# 304 MACCS(-69)
# 305 MACCS(-21)
# 306 MACCS(-64)
# 307 MACCS(-16)
# 308 MACCS(-23)
# 309 MACCS(-47)
# 310 MACCS(130)
# 311 ENV_CHEM
# 312 vsurf_Wp8
# 313 MACCS(-28)
# 314 MACCS(-13)
# 315 MACCS(-58)
# 316 MACCS(-34)
# 317 MACCS(--8)
# 318 MACCS(-41)
# 319 MACCS(-24)
# 320 MACCS(-43)
# 321 MACCS(-17)
# 322 MACCS(-59)

# %%
# https://www.kaggle.com/code/carlmcbrideellis/recursive-feature-elimination-rfe-example/notebook

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100, max_depth=10)


# scikit-learn Recursive Feature Elimination (RFE)

from sklearn.feature_selection import RFE

# here we want only one final feature, we do this to produce a ranking
n_features_to_select = 1
rfe = RFE(regressor, n_features_to_select=n_features_to_select)
rfe.fit(X_train, y_train)

# the features in order of ranking

from operator import itemgetter
features = X_train.columns.to_list()
for x, y in (sorted(zip(rfe.ranking_ , features), key=itemgetter(0))):
    print(x, y)

# the top 10 featues and use them for the model

n_features_to_select = 10
rfe = RFE(regressor, n_features_to_select=n_features_to_select)
rfe.fit(X_train, y_train)

# use the model to predict the prices for the test data

predictions = rfe.predict(X_test)

# write out CSV submission file

# output = pd.DataFrame({"Id":test_data.index, target:predictions})
# output.to_csv('submission.csv', index=False)
# Out:
# 1 GCUT_SLOGP_2
# 2 FASA+
# 3 E_sol
# 4 h_emd
# 5 h_logS
# 6 vsa_other
# 7 DASA
# 8 FCharge
# 9 SlogP_VSA9
# 10 GCUT_SLOGP_3
# 11 h_log_pbo
# 12 GCUT_SMR_0
# 13 std_dim2
# 14 SMR_VSA0
# 15 PEOE_VSA_PNEG
# 16 RPC+
# 17 h_emd_C
# 18 GCUT_PEOE_1
# 19 RPC-
# 20 ASA-
# 21 BCUT_SMR_3
# 22 chi1_C
# 23 vsurf_IW2
# 24 GCUT_SLOGP_1
# 25 GCUT_PEOE_0
# 26 E_oop
# 27 vsurf_Wp2
# 28 SlogP_VSA5
# 29 npr2
# 30 vsurf_IW4
# 31 ASA+
# 32 PEOE_VSA-0
# 33 E
# 34 Q_VSA_FPPOS
# 35 DCASA
# 36 GCUT_SMR_1
# 37 vsurf_EDmin1
# 38 npr1
# 39 SMR_VSA3
# 40 PEOE_PC+
# 41 PEOE_VSA_FPOS
# 42 SlogP_VSA1
# 43 weinerPol
# 44 GCUT_PEOE_2
# 45 PEOE_RPC+
# 46 vsurf_ID3
# 47 PEOE_VSA_FPPOS
# 48 SlogP
# 49 vsurf_Wp3
# 50 SMR_VSA5
# 51 balabanJ
# 52 MACCS(150)
# 53 a_ICM
# 54 vsurf_DD23
# 55 Q_VSA_FPNEG
# 56 b_1rotR
# 57 std_dim3
# 58 MACCS(108)
# 59 E_ele
# 60 BCUT_SLOGP_3
# 61 vsurf_IW3
# 62 PEOE_VSA_POL
# 63 conc
# 64 MACCS(156)
# 65 vsurf_DW13
# 66 PEOE_VSA+0
# 67 BCUT_SLOGP_1
# 68 vsurf_DD13
# 69 Q_VSA_PPOS
# 70 GCUT_SMR_2
# 71 pmi1
# 72 vsurf_IW6
# 73 PEOE_RPC-
# 74 PEOE_VSA+2
# 75 vsurf_CW8
# 76 Q_VSA_NEG
# 77 PEOE_VSA_FPNEG
# 78 SlogP_VSA4
# 79 E_ang
# 80 SlogP_VSA7
# 81 BCUT_SLOGP_2
# 82 vsurf_ID7
# 83 vsurf_IW1
# 84 vsurf_D3
# 85 BCUT_SMR_1
# 86 vsurf_D8
# 87 vsurf_ID8
# 88 glob
# 89 E_str
# 90 FCASA-
# 91 rsynth
# 92 BCUT_PEOE_1
# 93 PEOE_VSA+1
# 94 Kier3
# 95 weinerPath
# 96 ASA_H
# 97 rgyr
# 98 SlogP_VSA0
# 99 PEOE_VSA_POS
# 100 vsurf_ID6
# 101 SMR_VSA1
# 102 PEOE_VSA-1
# 103 E_strain
# 104 vsurf_DW23
# 105 logP(o/w)
# 106 opr_brigid
# 107 vsurf_R
# 108 h_ema
# 109 PEOE_PC-
# 110 dipole
# 111 PEOE_VSA_PPOS
# 112 SMR_VSA6
# 113 BCUT_PEOE_2
# 114 BCUT_SMR_2
# 115 vsurf_DD12
# 116 KierFlex
# 117 MACCS(134)
# 118 a_hyd
# 119 vsurf_EWmin1
# 120 KierA1
# 121 GCUT_SLOGP_0
# 122 PEOE_VSA-6
# 123 vsurf_CW1
# 124 SlogP_VSA2
# 125 MACCS(144)
# 126 h_pstrain
# 127 SMR_VSA7
# 128 chi0v
# 129 vsurf_DW12
# 130 h_pKb
# 131 density
# 132 MACCS(152)
# 133 E_vdw
# 134 std_dim1
# 135 Q_VSA_PNEG
# 136 vsurf_W1
# 137 PEOE_VSA_HYD
# 138 vsurf_IW7
# 139 vsurf_CW2
# 140 vsurf_Wp6
# 141 vsurf_IW5
# 142 vsurf_IW8
# 143 BCUT_SMR_0
# 144 vsurf_Wp5
# 145 FASA_P
# 146 Kier2
# 147 vsurf_CW3
# 148 E_tor
# 149 MACCS(143)
# 150 SlogP_VSA8
# 151 vsurf_HB3
# 152 Q_VSA_POL
# 153 vsurf_HL2
# 154 Q_PC+
# 155 CASA-
# 156 pmi2
# 157 vsurf_Wp1
# 158 KierA2
# 159 petitjean
# 160 PEOE_VSA+6
# 161 vsurf_CW6
# 162 VDistEq
# 163 h_pKa
# 164 PEOE_VSA+3
# 165 a_donacc
# 166 MACCS(116)
# 167 PEOE_VSA_FPOL
# 168 VAdjMa
# 169 chiral
# 170 mr
# 171 MACCS(154)
# 172 b_count
# 173 SMR_VSA2
# 174 vsa_acc
# 175 ASA_P
# 176 MACCS(113)
# 177 SMR_VSA4
# 178 vsurf_HB1
# 179 MACCS(155)
# 180 KierA3
# 181 vsurf_G
# 182 MACCS(100)
# 183 b_max1len
# 184 Weight
# 185 MACCS(123)
# 186 a_nH
# 187 MACCS(126)
# 188 MACCS(-72)
# 189 PEOE_VSA-4
# 190 MACCS(-90)
# 191 MACCS(157)
# 192 PEOE_VSA+4
# 193 MACCS(147)
# 194 a_nC
# 195 MACCS(129)
# 196 b_double
# 197 vsurf_W6
# 198 vsurf_W2
# 199 MACCS(-93)
# 200 PEOE_VSA-5
# 201 MACCS(-79)
# 202 MACCS(163)
# 203 MACCS(-74)
# 204 vsurf_CW7
# 205 MACCS(128)
# 206 opr_nrot
# 207 MACCS(137)
# 208 MACCS(-82)
# 209 MACCS(-95)
# 210 b_1rotN
# 211 SlogP_VSA3
# 212 vsurf_W8
# 213 MACCS(-91)
# 214 opr_nring
# 215 vsa_don
# 216 chiral_u
# 217 MACCS(121)
# 218 MACCS(109)
# 219 MACCS(159)
# 220 group
# 221 vsurf_Wp7
# 222 MACCS(-80)
# 223 SlogP_VSA6
# 224 MACCS(105)
# 225 MACCS(-75)
# 226 MACCS(111)
# 227 MACCS(-98)
# 228 MACCS(131)
# 229 MACCS(-89)
# 230 a_don
# 231 MACCS(135)
# 232 MACCS(132)
# 233 MACCS(-99)
# 234 MACCS(-97)
# 235 MACCS(104)
# 236 b_ar
# 237 vsa_base
# 238 MACCS(122)
# 239 PEOE_VSA+5
# 240 radius
# 241 MACCS(-54)
# 242 reactive
# 243 MACCS(103)
# 244 MACCS(117)
# 245 opr_violation
# 246 MACCS(-78)
# 247 MACCS(138)
# 248 MACCS(149)
# 249 MACCS(115)
# 250 MACCS(-65)
# 251 MACCS(140)
# 252 MACCS(-66)
# 253 MACCS(-76)
# 254 MACCS(124)
# 255 PEOE_VSA-2
# 256 MACCS(-86)
# 257 a_acid
# 258 MACCS(-96)
# 259 MACCS(125)
# 260 MACCS(106)
# 261 TEST
# 262 MACCS(-57)
# 263 mutagenic
# 264 MACCS(151)
# 265 MACCS(158)
# 266 MACCS(-92)
# 267 MACCS(120)
# 268 MACCS(141)
# 269 MACCS(-84)
# 270 MACCS(133)
# 271 MACCS(-83)
# 272 MACCS(114)
# 273 MACCS(-94)
# 274 MACCS(118)
# 275 MACCS(112)
# 276 MACCS(119)
# 277 MACCS(139)
# 278 MACCS(110)
# 279 MACCS(142)
# 280 MACCS(-62)
# 281 MACCS(-81)
# 282 MACCS(-42)
# 283 MACCS(162)
# 284 MACCS(-50)
# 285 MACCS(102)
# 286 MACCS(-46)
# 287 MACCS(136)
# 288 MACCS(-19)
# 289 MACCS(-53)
# 290 MACCS(-85)
# 291 MACCS(-77)
# 292 MACCS(145)
# 293 MACCS(127)
# 294 MACCS(130)
# 295 opr_leadlike
# 296 MACCS(101)
# 297 MACCS(-38)
# 298 CHARGED
# 299 MACCS(-47)
# 300 MACCS(-37)
# 301 a_base
# 302 MACCS(-73)
# 303 MACCS(-45)
# 304 MACCS(-59)
# 305 MACCS(-52)
# 306 MACCS(-36)
# 307 MACCS(--8)
# 308 MACCS(-26)
# 309 MACCS(-25)
# 310 MACCS(-41)
# 311 MACCS(-11)
# 312 MACCS(-63)
# 313 MACCS(-16)
# 314 MACCS(-58)
# 315 MACCS(-23)
# 316 MACCS(-69)
# 317 b_triple
# 318 vsurf_Wp8
# 319 MACCS(-21)
# 320 ENV_CHEM
# 321 MACCS(-71)
# 322 MACCS(-43)
# 323 MACCS(-34)
# 324 MACCS(-17)
# 325 MACCS(-70)
# 326 MACCS(-64)
# 327 MACCS(-24)
# 328 MACCS(-33)
# 329 MACCS(-22)
# 330 MACCS(-28)
# 331 MACCS(-13)

# %%
# Random Forest Built-in Feature Importance
cols_name = list(X_train.columns)
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
importance = rf.feature_importances_

important_features_dict = {}
for idx, val in enumerate(rf.feature_importances_):
    important_features_dict[idx] = val

important_features_list = sorted(important_features_dict,
                                 key=important_features_dict.get,
                                 reverse=True)

print(f'5 most important features: {important_features_list[:5]}')



#################
featureImpList= []
for feat, importance in zip(X_train.columns, rf.feature_importances_):  
    temp = [feat, importance*100]
    featureImpList.append(temp)

fT_df = pd.DataFrame(featureImpList, columns = ['Feature', 'Importance'])
df_rf=fT_df.sort_values('Importance', ascending = False)
df_rf[:30] 

rf_first_30feature = df_rf['Feature'].tolist()
rf_first_30feature
# Out:
# 5 most important features: [58, 44, 36, 280, 52]
# ['GCUT_SLOGP_2',
#  'E_sol',
#  'DASA',
#  'vsa_other',
#  'FCharge',
#  'SMR_VSA0',
#  'SlogP_VSA9',
#  'h_logS',
#  'FASA+',
#  'h_log_pbo',
#  'GCUT_SMR_0',
#  'GCUT_SLOGP_1',
#  'SlogP_VSA2',
#  'h_emd',
#  'RPC-',
#  'PEOE_VSA_PNEG',
#  'h_ema',
#  'MACCS(154)',
#  'PEOE_VSA_POS',
#  'ASA+',
#  'SlogP_VSA5',
#  'PEOE_PC+',
#  'GCUT_PEOE_1',
#  'PEOE_VSA-0',
#  'DCASA',
#  'RPC+',
#  'ASA-',
#  'chi1_C',
#  'SlogP_VSA7',
#  'SlogP_VSA1',
#  'std_dim2',
#  'vsurf_DD13',
#  'GCUT_SMR_2',
#  'h_pKb',
#  'PEOE_VSA_POL',
#  'GCUT_SMR_1',
#  'BCUT_SMR_3',
#  'GCUT_SLOGP_0',
#  'Q_VSA_PPOS',
#  'MACCS(108)',
#  'vsa_acc',
#  'FCASA-',
#  'vsurf_W6',
#  'vsurf_CW8',
#  'vsurf_Wp2',
#  'KierFlex',
#  'vsurf_ID8',
#  'weinerPol',
#  'E_oop',
#  'h_emd_C',
#  'conc',
#  'vsurf_ID3',
#  'E',
#  'GCUT_PEOE_0',
#  'PEOE_VSA_PPOS',
#  'npr2',
#  'PEOE_PC-',
#  'density',
#  'balabanJ',
#  'SMR_VSA5',
#  'vsurf_IW2',
#  'a_nH',
#  'PEOE_VSA-1',
#  'PEOE_VSA_FPOS',
#  'vsurf_ID7',
#  'MACCS(144)',
#  'dipole',
#  'vsurf_D3',
#  'a_base',
#  'SMR_VSA7',
#  'vsurf_IW3',
#  'SlogP_VSA4',
#  'vsurf_IW4',
#  'chiral',
#  'SlogP',
#  'GCUT_PEOE_2',
#  'E_ele',
#  'Q_VSA_NEG',
#  'E_ang',
#  'PEOE_RPC-',
#  'PEOE_VSA-6',
#  'vsurf_CW1',
#  'vsurf_IW6',
#  'a_ICM',
#  'SMR_VSA3',
#  'vsurf_EDmin1',
#  'MACCS(150)',
#  'vsurf_IW1',
#  'vsurf_Wp3',
#  'MACCS(129)',
#  'BCUT_SMR_0',
#  'opr_brigid',
#  'E_str',
#  'vsurf_R',
#  'logP(o/w)',
#  'PEOE_VSA+1',
#  'PEOE_VSA+4',
#  'ASA_H',
#  'h_pKa',
#  'vsurf_DD23',
#  'MACCS(-78)',
#  'vsurf_EWmin1',
#  'b_1rotR',
#  'PEOE_VSA_FPPOS',
#  'Kier2',
#  'Q_VSA_FPPOS',
#  'MACCS(156)',
#  'weinerPath',
#  'GCUT_SLOGP_3',
#  'std_dim3',
#  'a_hyd',
#  'npr1',
#  'group',
#  'BCUT_SMR_2',
#  'Q_VSA_FPNEG',
#  'CASA-',
#  'b_double',
#  'BCUT_SLOGP_1',
#  'MACCS(116)',
#  'vsurf_DW23',
#  'PEOE_RPC+',
#  'vsurf_CW2',
#  'rsynth',
#  'PEOE_VSA+3',
#  'BCUT_PEOE_1',
#  'PEOE_VSA+0',
#  'PEOE_VSA+2',
#  'SMR_VSA1',
#  'PEOE_VSA_FPNEG',
#  'MACCS(-95)',
#  'SlogP_VSA0',
#  'std_dim1',
#  'h_pstrain',
#  'vsurf_HB3',
#  'vsurf_IW7',
#  'BCUT_SLOGP_2',
#  'vsurf_IW8',
#  'pmi1',
#  'MACCS(-62)',
#  'b_1rotN',
#  'MACCS(132)',
#  'vsurf_DW12',
#  'KierA1',
#  'BCUT_SLOGP_3',
#  'MACCS(113)',
#  'Q_VSA_PNEG',
#  'vsurf_D8',
#  'SlogP_VSA8',
#  'SMR_VSA6',
#  'SlogP_VSA3',
#  'PEOE_VSA-4',
#  'vsurf_DD12',
#  'BCUT_SMR_1',
#  'Q_PC+',
#  'SMR_VSA2',
#  'PEOE_VSA+6',
#  'b_max1len',
#  'E_tor',
#  'MACCS(-79)',
#  'MACCS(152)',
#  'VDistEq',
#  'SMR_VSA4',
#  'E_strain',
#  'MACCS(131)',
#  'radius',
#  'vsurf_IW5',
#  'vsurf_Wp1',
#  'MACCS(111)',
#  'MACCS(-75)',
#  'MACCS(159)',
#  'vsurf_W8',
#  'vsurf_CW3',
#  'Q_VSA_POL',
#  'a_donacc',
#  'vsurf_DW13',
#  'vsurf_ID6',
#  'MACCS(127)',
#  'a_don',
#  'glob',
#  'MACCS(-46)',
#  'vsurf_W1',
#  'MACCS(105)',
#  'MACCS(157)',
#  'MACCS(-72)',
#  'BCUT_PEOE_2',
#  'FASA_P',
#  'E_vdw',
#  'vsurf_Wp5',
#  'MACCS(-54)',
#  'rgyr',
#  'vsurf_HL2',
#  'VAdjMa',
#  'Weight',
#  'vsurf_HB1',
#  'b_ar',
#  'MACCS(-90)',
#  'KierA2',
#  'KierA3',
#  'MACCS(-91)',
#  'MACCS(143)',
#  'vsurf_G',
#  'Kier3',
#  'opr_nring',
#  'vsurf_Wp7',
#  'PEOE_VSA_HYD',
#  'MACCS(109)',
#  'chi0v',
#  'a_nC',
#  'MACCS(-94)',
#  'pmi2',
#  'PEOE_VSA_FPOL',
#  'vsurf_CW7',
#  'MACCS(121)',
#  'vsurf_Wp6',
#  'MACCS(-97)',
#  'petitjean',
#  'vsurf_W2',
#  'b_count',
#  'MACCS(103)',
#  'opr_nrot',
#  'PEOE_VSA-2',
#  'PEOE_VSA+5',
#  'MACCS(-98)',
#  'MACCS(147)',
#  'MACCS(115)',
#  'MACCS(134)',
#  'MACCS(149)',
#  'MACCS(-37)',
#  'TEST',
#  'MACCS(135)',
#  'MACCS(-81)',
#  'MACCS(163)',
#  'ASA_P',
#  'MACCS(155)',
#  'MACCS(138)',
#  'MACCS(-47)',
#  'MACCS(-96)',
#  'MACCS(-57)',
#  'MACCS(-83)',
#  'MACCS(133)',
#  'MACCS(139)',
#  'MACCS(-93)',
#  'MACCS(-82)',
#  'MACCS(-85)',
#  'MACCS(-80)',
#  'MACCS(118)',
#  'MACCS(137)',
#  'MACCS(123)',
#  'vsurf_CW6',
#  'MACCS(-77)',
#  'mr',
#  'MACCS(136)',
#  'MACCS(126)',
#  'MACCS(-86)',
#  'MACCS(-66)',
#  'MACCS(128)',
#  'MACCS(120)',
#  'chiral_u',
#  'MACCS(162)',
#  'vsa_don',
#  'SlogP_VSA6',
#  'MACCS(158)',
#  'MACCS(110)',
#  'MACCS(-36)',
#  'MACCS(-89)',
#  'MACCS(-28)',
#  'MACCS(125)',
#  'MACCS(-53)',
#  'MACCS(-70)',
#  'MACCS(140)',
#  'MACCS(-99)',
#  'MACCS(104)',
#  'MACCS(-41)',
#  'MACCS(142)',
#  'MACCS(-52)',
#  'MACCS(-24)',
#  'MACCS(-92)',
#  'MACCS(119)',
#  'MACCS(124)',
#  'MACCS(145)',
#  'MACCS(-71)',
#  'MACCS(-84)',
#  'mutagenic',
#  'MACCS(151)',
#  'opr_violation',
#  'MACCS(106)',
#  'MACCS(100)',
#  'PEOE_VSA-5',
#  'MACCS(122)',
#  'MACCS(-65)',
#  'MACCS(130)',
#  'reactive',
#  'opr_leadlike',
#  'MACCS(-76)',
#  'MACCS(112)',
#  'MACCS(117)',
#  'a_acid',
#  'MACCS(-64)',
#  'MACCS(-17)',
#  'MACCS(-74)',
#  'MACCS(102)',
#  'MACCS(-38)',
#  'MACCS(-19)',
#  'MACCS(-21)',
#  'MACCS(114)',
#  'CHARGED',
#  'MACCS(141)',
#  'MACCS(--8)',
#  'MACCS(-42)',
#  'MACCS(-43)',
#  'ENV_CHEM',
#  'vsa_base',
#  'MACCS(-33)',
#  'MACCS(-45)',
#  'MACCS(-58)',
#  'MACCS(101)',
#  'MACCS(-50)',
#  'MACCS(-69)',
#  'MACCS(-59)',
#  'MACCS(-34)',
#  'MACCS(-73)',
#  'MACCS(-22)',
#  'MACCS(-26)',
#  'MACCS(-63)',
#  'MACCS(-25)',
#  'b_triple',
#  'MACCS(-23)',
#  'vsurf_Wp8',
#  'MACCS(-16)',
#  'MACCS(-13)',
#  'MACCS(-11)']

# %%
# Random Forest Regression Feature Importance
df8 = df3[rf_first_30feature].join(df_output)
df8
# Out:
#        GCUT_SLOGP_2     E_sol      DASA  vsa_other   FCharge  SMR_VSA0  \
# index
# 1         -0.687403  0.507683 -1.294161  -0.184788 -0.253452 -0.105379
# 2         -1.027004  0.260350 -0.109509   3.184661 -0.253452  0.154266
# 3         -0.547918  0.464254 -1.577503   0.510156 -0.253452 -0.668632
# 4         -0.606131 -0.732552 -0.642459  -0.742665  1.242733 -0.668632
# 5         -0.749591 -1.550813 -1.656184   1.006745 -1.749637  2.028640
# ...             ...       ...       ...        ...       ...       ...
# 179       -0.592030 -0.710219 -0.148477  -0.184788  1.242733 -0.105379
# 180        0.908113  0.769663 -0.092884  -0.742665 -0.253452 -0.668632
# 181        0.588175  0.839146 -0.022709  -0.448382 -0.253452 -0.668632
# 182        0.913525  0.781263  0.169973  -0.742665 -0.253452 -0.668632
# 183        1.303808  0.720119  1.359257  -0.742665 -0.253452 -0.668632
#
#        SlogP_VSA9    h_logS     FASA+  h_log_pbo  ...  MACCS(-26)  MACCS(-63)  \
# index                                             ...
# 1       -0.855510  0.992564  0.464017  -0.772421  ...   -0.141083   -0.149487
# 2       -1.032228  1.318782  1.141394  -0.493965  ...   -0.141083   -0.149487
# 3       -0.381850 -0.347701  0.090893   1.589455  ...   -0.141083   -0.149487
# 4       -0.931927  1.850001  0.961370  -1.365962  ...   -0.141083   -0.149487
# 5       -0.305843  0.325178  0.047874  -0.048588  ...   -0.141083   -0.149487
# ...           ...       ...       ...        ...  ...         ...         ...
# 179     -0.881842  1.077555  0.813981   0.536375  ...   -0.141083   -0.149487
# 180      0.619465 -0.875037 -0.731036   0.128865  ...   -0.141083   -0.149487
# 181      0.245521 -0.863664 -0.754461   0.826864  ...   -0.141083   -0.149487
# 182      0.619465 -0.865436 -0.840206   0.128905  ...   -0.141083   -0.149487
# 183      2.115240 -0.932456 -1.589070  -2.199457  ...   -0.141083   -0.149487
#
#        MACCS(-25)  b_triple  MACCS(-23)  vsurf_Wp8  MACCS(-16)  MACCS(-13)  \
# index
# 1       -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
# 2        5.431390 -0.149487   -0.074125  13.490738   -0.105118   -0.074125
# 3       -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
# 4       -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
# 5       -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
# ...           ...       ...         ...        ...         ...         ...
# 179     -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
# 180     -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
# 181     -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
# 182     -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
# 183     -0.184115 -0.149487   -0.074125  -0.074125   -0.105118   -0.074125
#
#        MACCS(-11)  Log_MP_RATIO
# index
# 1       -0.218426     -0.119186
# 2       -0.218426      0.423246
# 3       -0.218426     -0.443698
# 4       -0.218426      0.711807
# 5        3.778770     -0.530178
# ...           ...           ...
# 179     -0.218426      0.176091
# 180     -0.218426      0.472628
# 181     -0.218426      0.667194
# 182     -0.218426      0.850593
# 183     -0.218426      0.847938
#
# [183 rows x 332 columns]

# %%
cols_name_arr=np.asarray(cols_name)
sorted_idx = rf.feature_importances_.argsort()
plt.barh(cols_name_arr[sorted_idx][:30], rf.feature_importances_[sorted_idx][:30])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
from sklearn.feature_selection import SelectPercentile, f_regression
from sklearn.pipeline import Pipeline
select = SelectPercentile(score_func=f_regression, percentile=5).fit(X_train, y_train)
X_selected = select.transform(X_train)
print("X_selected.shape: {}".format(X_selected.shape))

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge

pipe = Pipeline([("select", SelectPercentile(score_func=f_regression,
percentile=5)),
("ridge", Ridge())])
print("Cross-validation accuracy (pipeline): {:.2f}".format(
np.mean(cross_val_score(pipe, X_train, y_train, cv=5))))
# Out:
# X_selected.shape: (146, 17)
# Cross-validation accuracy (pipeline): 0.05

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.decomposition import PCA
estimators = [('reduce_dim', PCA()), ('clf', SVC())]
pipe = Pipeline(estimators)
pipe
# Out:
# Pipeline(steps=[('reduce_dim', PCA()), ('clf', SVC())])

# %% [markdown]
# ## Wrapper Method
# include rfe

# %%
## Forward Selection
# The main issues It does not consider all possible combination of potential predictors

# %%
# 1.

# https://www.analyticsvidhya.com/blog/2020/10/a-comprehensive-guide-to-feature-selection-using-wrapper-methods-in-python/

import statsmodels.api as sm

def forward_selection(data, target, significance_level=0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features
