# %%
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

# %%
# Global variable
TRAINING: str = "TRAINING"
TEST: str = "TEST"


# Modifying the values
SHOULD_DROP_NA: bool = True # If True just drops all NA; if False applies another logic

# Logic to adapt if not
SHOULD_USE_AVG: bool = True # Replace Nan values by average if continuous values else uses interpolation

# %% [markdown]
# # Opening data and comparing data
#
# *sources*:
# - [kaggle data visualisation notebook](https://www.kaggle.com/code/ekami66/detailed-exploratory-data-analysis-with-python)

# %% [markdown]
# ## Ionizable

# %%
df_ionizable_train: pd.DataFrame = pd.read_csv("../Data/ionizable_dataset_72_train_divprio.csv", delimiter=';')
df_ionizable_test: pd.DataFrame = pd.read_csv("../Data/ionizable_dataset_72_test_divprio.csv", delimiter=';')
print("===== TRAIN =====")
display(df_ionizable_train.head())
print(">>> Rows and features")
display(df_ionizable_train.shape)
print("===== TEST =====")
display(df_ionizable_test.head())
print(">>> Rows and features")
display(df_ionizable_test.shape)
# Out:
# ===== TRAIN =====
#    Log_MP_RATIO       apol        ASA       ASA+       ASA-      ASA_H  \
# 0      0.711807  26.275103  349.46716  242.22882  107.23836  264.31046
# 1      0.793092  25.823965  413.37534  175.84161  237.53374  131.72211
# 2     -1.301030  25.685896  360.75131  232.50258  128.24873  238.14108
# 3     -1.301030  18.059965  295.84061  129.55249  166.28812  165.86299
# 4      0.255273  53.428448  573.00171  387.61703  185.38469  426.20108
#
#         ASA_P  a_acc  a_acid  a_aro  ...  vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  \
# 0   85.156723      0       0      6  ...    113.125     38.250     12.625
# 1  281.653260      1       3      5  ...     27.875      0.000      0.000
# 2  122.610240      0       2      0  ...      3.375      0.000      0.000
# 3  129.977600      1       2      6  ...     25.375      7.750      3.375
# 4  146.800640      2       0     12  ...     92.750     14.625      4.875
#
#    vsurf_Wp6  vsurf_Wp7  vsurf_Wp8     Weight  weinerPath  weinerPol  zagreb
# 0       1.25      0.000          0  136.21800         126          9      44
# 1       0.00      0.000          0  237.15100         580         20      86
# 2       0.00      0.000          0  143.20599         131         10      38
# 3       1.00      0.125          0  137.11400         114         12      46
# 4       1.00      0.000          0  325.40698        1298         39     126
#
# [5 rows x 479 columns]
# >>> Rows and features
# (58, 479)
# ===== TEST =====
#    Log_MP_RATIO       apol        ASA       ASA+        ASA-      ASA_H  \
# 0     -0.530178  49.570274  561.79968  267.19226  262.834690  309.97708
# 1     -1.698970  50.500687  558.84418  236.19672  291.529910  293.11432
# 2     -1.397940  65.462685  758.27393  371.97479  350.024600  313.36160
# 3      0.334454  49.855446  487.60828  387.69373   99.914536  380.27148
# 4     -0.167491  46.162067  556.22620  315.47986  240.746310  391.94083
#
#        ASA_P  a_acc  a_acid  a_aro  ...  vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  \
# 0  251.82259      3       2      6  ...     110.50     36.250     14.750
# 1  265.72986      2       4      6  ...      34.75      0.000      0.000
# 2  444.91232      7       3      5  ...     180.25     37.875     14.000
# 3  107.33679      3       0      6  ...      59.00     11.375      4.625
# 4  164.28537      1       0     12  ...     113.25     33.125     11.000
#
#    vsurf_Wp6  vsurf_Wp7  vsurf_Wp8     Weight  weinerPath  weinerPol  zagreb
# 0      3.875      0.000          0  348.40298        1365         39     132
# 1      0.000      0.000          0  376.38901        1651         43     142
# 2      4.750      0.625          0  552.57300        4386         59     192
# 3      1.125      0.000          0  300.37799         824         51     136
# 4      1.750      0.000          0  310.33899        1148         30     108
#
# [5 rows x 479 columns]
# >>> Rows and features
# (14, 479)

# %% [markdown]
# ## Neutral

# %%
df_neutral_train: pd.DataFrame = pd.read_csv("../Data/neutral_dataset_111_train_divprio.csv", delimiter=';')
df_neutral_test: pd.DataFrame = pd.read_csv("../Data/neutral_dataset_111_test_divprio.csv", delimiter=';')
print("===== TRAIN =====")
display(df_neutral_train.head())
print(">>> Rows and features")
display(df_neutral_train.shape)

print("===== TEST =====")
display(df_neutral_test.head())
print(">>> Rows and features")
display(df_neutral_test.shape)
# Out:
# ===== TRAIN =====
#    Log_MP_RATIO       apol        ASA        ASA+        ASA-      ASA_H  \
# 0     -0.119186  22.785137  341.43088  196.220180  145.210690  239.01727
# 1      0.363698  43.759998  488.54459    0.000000  488.544590    0.00000
# 2      0.698970  30.486586  498.01099   58.344425  439.666560    0.00000
# 3     -0.050610   8.322758  197.57458  106.382390   91.192207  133.01698
# 4     -0.130768  39.397514  478.52527  307.091030  171.434250  333.33282
#
#        ASA_P  a_acc  a_acid  a_aro  ...  vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  \
# 0  102.41361      2       0      6  ...     64.000     22.375      9.625
# 1  488.54459      0       0      0  ...      0.250      0.000      0.000
# 2  498.01099      2       0      0  ...     80.625     33.000     13.750
# 3   64.55761      1       0      0  ...     19.250      6.250      2.750
# 4  145.19243      5       0     16  ...     54.250      0.000      0.000
#
#    vsurf_Wp6  vsurf_Wp7  vsurf_Wp8     Weight  weinerPath  weinerPol  zagreb
# 0      3.000      0.000        0.0  151.16499         166         11      50
# 1      0.000      0.000        0.0  545.54596         680         78     172
# 2      4.625      0.125        0.0  499.14099        1864         72     164
# 3      0.750      0.000        0.0   46.06900           4          0       6
# 4      0.000      0.000        0.0  306.27600        1000         30     116
#
# [5 rows x 479 columns]
# >>> Rows and features
# (89, 479)
# ===== TEST =====
#    Log_MP_RATIO       apol        ASA       ASA+       ASA-      ASA_H  ASA_P  \
# 0      0.172137  36.867172  498.12390  90.310730  405.87415  498.12390    0.0
# 1      0.561543  38.380379  509.62424  86.720169  422.32901  509.62424    0.0
# 2      0.463998  38.380379  511.85873  79.011894  432.55930  511.85873    0.0
# 3      0.558712  38.380379  502.14569  81.493713  420.36444  502.14569    0.0
# 4      0.691549  38.380379  506.02533  75.370956  430.36685  506.02533    0.0
#
#    a_acc  a_acid  a_aro  ...  vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  \
# 0      0       0     12  ...     53.750        0.0        0.0        0.0
# 1      0       0     12  ...     50.375        0.0        0.0        0.0
# 2      0       0     12  ...     54.500        0.0        0.0        0.0
# 3      0       0     12  ...     45.250        0.0        0.0        0.0
# 4      0       0     12  ...     48.625        0.0        0.0        0.0
#
#    vsurf_Wp7  vsurf_Wp8     Weight  weinerPath  weinerPol  zagreb
# 0          0          0  360.88199         580         30      94
# 1          0          0  395.32700         650         35     100
# 2          0          0  395.32700         642         34     100
# 3          0          0  395.32700         634         35     100
# 4          0          0  395.32700         626         34     100
#
# [5 rows x 479 columns]
# >>> Rows and features
# (22, 479)

# %% [markdown]
# ## Full

# %%
df_full_train: pd.DataFrame = pd.read_csv("../Data/full_dataset_train_divprio.csv", delimiter=';')
df_full_test: pd.DataFrame = pd.read_csv("../Data/full_dataset_test_divprio.csv", delimiter=';')


print("===== TRAIN =====")
display(df_full_train.head())
print(">>> Rows and features")
display(df_full_train.shape)

print("===== TEST =====")
display(df_full_test.head())
print(">>> Rows and features")
display(df_full_test.shape)
# Out:
# ===== TRAIN =====
#    Log_MP_RATIO       apol        ASA        ASA+        ASA-      ASA_H  \
# 0     -0.119186  22.785137  341.43088  196.220180  145.210690  239.01727
# 1      0.363698  43.759998  488.54459    0.000000  488.544590    0.00000
# 2      0.698970  30.486586  498.01099   58.344425  439.666560    0.00000
# 3      0.761176  38.435482  528.63080  414.456510  114.174280  291.23990
# 4     -0.050610   8.322758  197.57458  106.382390   91.192207  133.01698
#
#        ASA_P  a_acc  a_acid  a_aro  ...  vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  \
# 0  102.41361      2       0      6  ...     64.000     22.375      9.625
# 1  488.54459      0       0      0  ...      0.250      0.000      0.000
# 2  498.01099      2       0      0  ...     80.625     33.000     13.750
# 3  237.39088      2       0      5  ...    190.000     53.375     19.625
# 4   64.55761      1       0      0  ...     19.250      6.250      2.750
#
#    vsurf_Wp6  vsurf_Wp7  vsurf_Wp8     Weight  weinerPath  weinerPol  zagreb
# 0      3.000      0.000        0.0  151.16499         166         11      50
# 1      0.000      0.000        0.0  545.54596         680         78     172
# 2      4.625      0.125        0.0  499.14099        1864         72     164
# 3      5.000      0.375        0.0  253.35400         664         18      74
# 4      0.750      0.000        0.0   46.06900           4          0       6
#
# [5 rows x 479 columns]
# >>> Rows and features
# (146, 479)
# ===== TEST =====
#    Log_MP_RATIO       apol        ASA       ASA+       ASA-      ASA_H  \
# 0      0.538977  36.335587  479.30493  79.206154  389.74368  469.82861
# 1      0.889231  36.335587  487.70731  80.014854  397.33737  481.38589
# 2      0.819654  34.822380  468.08173  91.811241  365.91544  457.55453
# 3      0.350319  40.164001  532.39777  87.560234  444.83752  532.39777
# 4     -0.359296  39.362000  511.36078  68.310173  432.51224  507.88873
#
#        ASA_P  a_acc  a_acid  a_aro  ...  vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  \
# 0   9.476298      0       0     13  ...     51.500        0.0        0.0
# 1   6.321409      0       0     13  ...     50.625        0.0        0.0
# 2  10.527193      0       0     13  ...     38.125        0.0        0.0
# 3   0.000000      0       0     12  ...     91.625        0.0        0.0
# 4   3.472069      0       0     13  ...     72.125        0.0        0.0
#
#    vsurf_Wp6  vsurf_Wp7  vsurf_Wp8     Weight  weinerPath  weinerPol  zagreb
# 0        0.0          0          0  374.86499         613         37     108
# 1        0.0          0          0  374.86499         616         37     108
# 2        0.0          0          0  340.41998         541         33     102
# 3        0.0          0          0  459.75400         915         47     124
# 4        0.0          0          0  443.75497         775         45     120
#
# [5 rows x 479 columns]
# >>> Rows and features
# (37, 479)

# %% [markdown]
# ## Comparing full with ionizable and neutral
# Comparison done to check the header differences between all dataframe and see if some need to be merged together

# %%
# Difference of headers in the dataframe
print("===== HEADER COMPARISON =====")
print("> TRAIN")
print(">>> NEUTRAL VS FULL")
display(len(df_neutral_train.columns.difference(df_full_train.columns)))
print(">>> FULL VS NEUTRAL")
display(len(df_full_train.columns.difference(df_neutral_train.columns)))

print(">>> IONIZABLE VS FULL")
display(len(df_ionizable_train.columns.difference(df_full_train.columns)))
print(">>> FULL VS IONIZABLE")
display(len(df_full_train.columns.difference(df_ionizable_train.columns)))

print(">>> NEUTRAL VS IONIZABLE")
display(len(df_neutral_train.columns.difference(df_ionizable_train.columns)))

print(">>> IONIZABLE VS NEUTRAL")
display(len(df_ionizable_train.columns.difference(df_neutral_train.columns)))



print("> TEST")
print(">>> NEUTRAL VS FULL")
display(len(df_neutral_test.columns.difference(df_full_test.columns)))
print(">>> FULL VS NEUTRAL")
display(len(df_full_test.columns.difference(df_neutral_test.columns)))

print(">>> IONIZABLE VS FULL")
display(len(df_ionizable_test.columns.difference(df_full_test.columns)))
print(">>> FULL VS IONIZABLE")
display(len(df_full_test.columns.difference(df_ionizable_test.columns)))

print(">>> NEUTRAL VS IONIZABLE")
display(len(df_neutral_test.columns.difference(df_ionizable_test.columns)))

print(">>> IONIZABLE VS NEUTRAL")
display(len(df_ionizable_test.columns.difference(df_neutral_test.columns)))
# Out:
# ===== HEADER COMPARISON =====
# > TRAIN
# >>> NEUTRAL VS FULL
# 0
# >>> FULL VS NEUTRAL
# 0
# >>> IONIZABLE VS FULL
# 0
# >>> FULL VS IONIZABLE
# 0
# >>> NEUTRAL VS IONIZABLE
# 0
# >>> IONIZABLE VS NEUTRAL
# 0
# > TEST
# >>> NEUTRAL VS FULL
# 0
# >>> FULL VS NEUTRAL
# 0
# >>> IONIZABLE VS FULL
# 0
# >>> FULL VS IONIZABLE
# 0
# >>> NEUTRAL VS IONIZABLE
# 0
# >>> IONIZABLE VS NEUTRAL
# 0

# %% [markdown]
# # Describing and cleaning the data

# %% [markdown]
# ## Ionizable

# %% [markdown]
# ### Values and missing values

# %%
print("===== BASIC DATA OVERVIEW (TRAIN) =====")
print(">>> Description")
display(df_ionizable_train.describe())
print(">>> Info")
display(df_ionizable_train.info(verbose=True))
print("===== COLS WITH NAN VALUES =====")
display(df_ionizable_train.isna().sum())

print("===== BASIC DATA OVERVIEW (TEST) =====")
print(">>> Description")
display(df_ionizable_test.describe())
print(">>> Info")
display(df_ionizable_test.info(verbose=True))
print("===== COLS WITH NAN VALUES =====")
display(df_ionizable_test.isna().sum())
# Out:
# ===== BASIC DATA OVERVIEW (TRAIN) =====
# >>> Description
#        Log_MP_RATIO        apol         ASA        ASA+        ASA-  \
# count     58.000000   58.000000   58.000000   58.000000   58.000000
# mean      -0.193418   48.931856  546.808675  349.373759  194.552224
# std        0.705376   15.945415  119.585499  106.296749   70.212878
# min       -2.259637   18.059965  295.840610  118.873230   68.862923
# 25%       -0.431798   39.435989  475.798502  275.327828  149.002465
# 50%       -0.023676   48.002051  538.751740  361.514160  182.802255
# 75%        0.339801   53.987316  605.620958  410.803538  232.416348
# max        0.793092  121.987920  896.699710  674.181880  449.023770
#
#             ASA_H       ASA_P      a_acc     a_acid      a_aro  ...  \
# count   58.000000   58.000000  58.000000  58.000000  58.000000  ...
# mean   394.809622  151.999057   2.051724   0.637931   8.620690  ...
# std    121.114319   90.307555   2.081012   1.037850   4.221198  ...
# min     97.029968   39.299633   0.000000   0.000000   0.000000  ...
# 25%    324.064768   92.200664   1.000000   0.000000   6.000000  ...
# 50%    406.328935  122.527965   1.500000   0.000000   9.500000  ...
# 75%    455.076975  184.903485   3.000000   2.000000  12.000000  ...
# max    725.847960  470.867030  12.000000   4.000000  17.000000  ...
#
#         vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  \
# count   58.000000  58.000000  58.000000  58.000000  58.000000       58.0
# mean   100.760776  24.411638   8.879310   2.043103   0.081897        0.0
# std     56.242623  18.915425   7.232244   2.058965   0.186660        0.0
# min      3.375000   0.000000   0.000000   0.000000   0.000000        0.0
# 25%     62.656250  11.656250   4.343750   0.531250   0.000000        0.0
# 50%     99.625000  25.187500   8.125000   1.312500   0.000000        0.0
# 75%    135.500000  37.937500  12.875000   3.187500   0.000000        0.0
# max    262.750000  72.375000  28.875000   8.125000   0.875000        0.0
#
#            Weight   weinerPath   weinerPol      zagreb
# count   58.000000    58.000000   58.000000   58.000000
# mean   313.266339  1376.431034   34.413793  111.931034
# std    109.145602  1414.512874   16.896002   41.609657
# min    136.218000   114.000000    9.000000   38.000000
# 25%    253.603750   650.750000   24.250000   87.000000
# 50%    298.560990   930.000000   32.500000  105.000000
# 75%    339.740000  1566.500000   41.250000  131.000000
# max    734.945010  8842.000000  101.000000  270.000000
#
# [8 rows x 479 columns]
# >>> Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 479 columns):
#  #    Column          Dtype
# ---   ------          -----
#  0    Log_MP_RATIO    float64
#  1    apol            float64
#  2    ASA             float64
#  3    ASA+            float64
#  4    ASA-            float64
#  5    ASA_H           float64
#  6    ASA_P           float64
#  7    a_acc           int64
#  8    a_acid          int64
#  9    a_aro           int64
#  10   a_base          int64
#  11   a_count         int64
#  12   a_don           int64
#  13   a_donacc        int64
#  14   a_heavy         int64
#  15   a_hyd           int64
#  16   a_IC            float64
#  17   a_ICM           float64
#  18   a_nB            int64
#  19   a_nBr           int64
#  20   a_nC            int64
#  21   a_nCl           int64
#  22   a_nF            int64
#  23   a_nH            int64
#  24   a_nI            int64
#  25   a_nN            int64
#  26   a_nO            int64
#  27   a_nP            int64
#  28   a_nS            int64
#  29   balabanJ        float64
#  30   BCUT_PEOE_0     float64
#  31   BCUT_PEOE_1     float64
#  32   BCUT_PEOE_2     float64
#  33   BCUT_PEOE_3     float64
#  34   BCUT_SLOGP_0    float64
#  35   BCUT_SLOGP_1    float64
#  36   BCUT_SLOGP_2    float64
#  37   BCUT_SLOGP_3    float64
#  38   BCUT_SMR_0      float64
#  39   BCUT_SMR_1      float64
#  40   BCUT_SMR_2      float64
#  41   BCUT_SMR_3      float64
#  42   bpol            float64
#  43   b_1rotN         int64
#  44   b_1rotR         float64
#  45   b_ar            int64
#  46   b_count         int64
#  47   b_double        int64
#  48   b_heavy         int64
#  49   b_max1len       int64
#  50   b_rotN          int64
#  51   b_rotR          float64
#  52   b_single        int64
#  53   b_triple        int64
#  54   CASA+           float64
#  55   CASA-           float64
#  56   chi0            float64
#  57   chi0v           float64
#  58   chi0v_C         float64
#  59   chi0_C          float64
#  60   chi1            float64
#  61   chi1v           float64
#  62   chi1v_C         float64
#  63   chi1_C          float64
#  64   chiral          int64
#  65   chiral_u        int64
#  66   DASA            float64
#  67   DCASA           float64
#  68   density         float64
#  69   diameter        int64
#  70   dipole          float64
#  71   E               float64
#  72   E_ang           float64
#  73   E_ele           float64
#  74   E_nb            float64
#  75   E_oop           float64
#  76   E_sol           float64
#  77   E_stb           int64
#  78   E_str           float64
#  79   E_strain        float64
#  80   E_tor           float64
#  81   E_vdw           float64
#  82   FASA+           float64
#  83   FASA-           float64
#  84   FASA_H          float64
#  85   FASA_P          float64
#  86   FCASA+          float64
#  87   FCASA-          float64
#  88   FCharge         int64
#  89   GCUT_PEOE_0     float64
#  90   GCUT_PEOE_1     float64
#  91   GCUT_PEOE_2     float64
#  92   GCUT_PEOE_3     float64
#  93   GCUT_SLOGP_0    float64
#  94   GCUT_SLOGP_1    float64
#  95   GCUT_SLOGP_2    float64
#  96   GCUT_SLOGP_3    float64
#  97   GCUT_SMR_0      float64
#  98   GCUT_SMR_1      float64
#  99   GCUT_SMR_2      float64
#  100  GCUT_SMR_3      float64
#  101  glob            float64
#  102  h_ema           float64
#  103  h_emd           float64
#  104  h_emd_C         float64
#  105  h_logD          float64
#  106  h_logP          float64
#  107  h_logS          float64
#  108  h_log_dbo       float64
#  109  h_log_pbo       float64
#  110  h_mr            float64
#  111  h_pavgQ         float64
#  112  h_pKa           float64
#  113  h_pKb           float64
#  114  h_pstates       float64
#  115  h_pstrain       float64
#  116  Kier1           float64
#  117  Kier2           float64
#  118  Kier3           float64
#  119  KierA1          float64
#  120  KierA2          float64
#  121  KierA3          float64
#  122  KierFlex        float64
#  123  logP(o/w)       float64
#  124  logS            float64
#  125  MACCS(--1)      int64
#  126  MACCS(--2)      int64
#  127  MACCS(--3)      int64
#  128  MACCS(--4)      int64
#  129  MACCS(--5)      int64
#  130  MACCS(--6)      int64
#  131  MACCS(--7)      int64
#  132  MACCS(--8)      int64
#  133  MACCS(--9)      int64
#  134  MACCS(-10)      int64
#  135  MACCS(-11)      int64
#  136  MACCS(-12)      int64
#  137  MACCS(-13)      int64
#  138  MACCS(-14)      int64
#  139  MACCS(-15)      int64
#  140  MACCS(-16)      int64
#  141  MACCS(-17)      int64
#  142  MACCS(-18)      int64
#  143  MACCS(-19)      int64
#  144  MACCS(-20)      int64
#  145  MACCS(-21)      int64
#  146  MACCS(-22)      int64
#  147  MACCS(-23)      int64
#  148  MACCS(-24)      int64
#  149  MACCS(-25)      int64
#  150  MACCS(-26)      int64
#  151  MACCS(-27)      int64
#  152  MACCS(-28)      int64
#  153  MACCS(-29)      int64
#  154  MACCS(-30)      int64
#  155  MACCS(-31)      int64
#  156  MACCS(-32)      int64
#  157  MACCS(-33)      int64
#  158  MACCS(-34)      int64
#  159  MACCS(-35)      int64
#  160  MACCS(-36)      int64
#  161  MACCS(-37)      int64
#  162  MACCS(-38)      int64
#  163  MACCS(-39)      int64
#  164  MACCS(-40)      int64
#  165  MACCS(-41)      int64
#  166  MACCS(-42)      int64
#  167  MACCS(-43)      int64
#  168  MACCS(-44)      int64
#  169  MACCS(-45)      int64
#  170  MACCS(-46)      int64
#  171  MACCS(-47)      int64
#  172  MACCS(-48)      int64
#  173  MACCS(-49)      int64
#  174  MACCS(-50)      int64
#  175  MACCS(-51)      int64
#  176  MACCS(-52)      int64
#  177  MACCS(-53)      int64
#  178  MACCS(-54)      int64
#  179  MACCS(-55)      int64
#  180  MACCS(-56)      int64
#  181  MACCS(-57)      int64
#  182  MACCS(-58)      int64
#  183  MACCS(-59)      int64
#  184  MACCS(-60)      int64
#  185  MACCS(-61)      int64
#  186  MACCS(-62)      int64
#  187  MACCS(-63)      int64
#  188  MACCS(-64)      int64
#  189  MACCS(-65)      int64
#  190  MACCS(-66)      int64
#  191  MACCS(-67)      int64
#  192  MACCS(-68)      int64
#  193  MACCS(-69)      int64
#  194  MACCS(-70)      int64
#  195  MACCS(-71)      int64
#  196  MACCS(-72)      int64
#  197  MACCS(-73)      int64
#  198  MACCS(-74)      int64
#  199  MACCS(-75)      int64
#  200  MACCS(-76)      int64
#  201  MACCS(-77)      int64
#  202  MACCS(-78)      int64
#  203  MACCS(-79)      int64
#  204  MACCS(-80)      int64
#  205  MACCS(-81)      int64
#  206  MACCS(-82)      int64
#  207  MACCS(-83)      int64
#  208  MACCS(-84)      int64
#  209  MACCS(-85)      int64
#  210  MACCS(-86)      int64
#  211  MACCS(-87)      int64
#  212  MACCS(-88)      int64
#  213  MACCS(-89)      int64
#  214  MACCS(-90)      int64
#  215  MACCS(-91)      int64
#  216  MACCS(-92)      int64
#  217  MACCS(-93)      int64
#  218  MACCS(-94)      int64
#  219  MACCS(-95)      int64
#  220  MACCS(-96)      int64
#  221  MACCS(-97)      int64
#  222  MACCS(-98)      int64
#  223  MACCS(-99)      int64
#  224  MACCS(100)      int64
#  225  MACCS(101)      int64
#  226  MACCS(102)      int64
#  227  MACCS(103)      int64
#  228  MACCS(104)      int64
#  229  MACCS(105)      int64
#  230  MACCS(106)      int64
#  231  MACCS(107)      int64
#  232  MACCS(108)      int64
#  233  MACCS(109)      int64
#  234  MACCS(110)      int64
#  235  MACCS(111)      int64
#  236  MACCS(112)      int64
#  237  MACCS(113)      int64
#  238  MACCS(114)      int64
#  239  MACCS(115)      int64
#  240  MACCS(116)      int64
#  241  MACCS(117)      int64
#  242  MACCS(118)      int64
#  243  MACCS(119)      int64
#  244  MACCS(120)      int64
#  245  MACCS(121)      int64
#  246  MACCS(122)      int64
#  247  MACCS(123)      int64
#  248  MACCS(124)      int64
#  249  MACCS(125)      int64
#  250  MACCS(126)      int64
#  251  MACCS(127)      int64
#  252  MACCS(128)      int64
#  253  MACCS(129)      int64
#  254  MACCS(130)      int64
#  255  MACCS(131)      int64
#  256  MACCS(132)      int64
#  257  MACCS(133)      int64
#  258  MACCS(134)      int64
#  259  MACCS(135)      int64
#  260  MACCS(136)      int64
#  261  MACCS(137)      int64
#  262  MACCS(138)      int64
#  263  MACCS(139)      int64
#  264  MACCS(140)      int64
#  265  MACCS(141)      int64
#  266  MACCS(142)      int64
#  267  MACCS(143)      int64
#  268  MACCS(144)      int64
#  269  MACCS(145)      int64
#  270  MACCS(146)      int64
#  271  MACCS(147)      int64
#  272  MACCS(148)      int64
#  273  MACCS(149)      int64
#  274  MACCS(150)      int64
#  275  MACCS(151)      int64
#  276  MACCS(152)      int64
#  277  MACCS(153)      int64
#  278  MACCS(154)      int64
#  279  MACCS(155)      int64
#  280  MACCS(156)      int64
#  281  MACCS(157)      int64
#  282  MACCS(158)      int64
#  283  MACCS(159)      int64
#  284  MACCS(160)      int64
#  285  MACCS(161)      int64
#  286  MACCS(162)      int64
#  287  MACCS(163)      int64
#  288  MACCS(164)      int64
#  289  MACCS(165)      int64
#  290  MACCS(166)      int64
#  291  mr              float64
#  292  mutagenic       int64
#  293  nmol            int64
#  294  npr1            float64
#  295  npr2            float64
#  296  opr_brigid      int64
#  297  opr_leadlike    int64
#  298  opr_nring       int64
#  299  opr_nrot        int64
#  300  opr_violation   int64
#  301  PC+             float64
#  302  PC-             float64
#  303  PEOE_PC+        float64
#  304  PEOE_PC-        float64
#  305  PEOE_RPC+       float64
#  306  PEOE_RPC-       float64
#  307  PEOE_VSA+0      float64
#  308  PEOE_VSA+1      float64
#  309  PEOE_VSA+2      float64
#  310  PEOE_VSA+3      float64
#  311  PEOE_VSA+4      float64
#  312  PEOE_VSA+5      float64
#  313  PEOE_VSA+6      float64
#  314  PEOE_VSA-0      float64
#  315  PEOE_VSA-1      float64
#  316  PEOE_VSA-2      float64
#  317  PEOE_VSA-3      float64
#  318  PEOE_VSA-4      float64
#  319  PEOE_VSA-5      float64
#  320  PEOE_VSA-6      float64
#  321  PEOE_VSA_FHYD   float64
#  322  PEOE_VSA_FNEG   float64
#  323  PEOE_VSA_FPNEG  float64
#  324  PEOE_VSA_FPOL   float64
#  325  PEOE_VSA_FPOS   float64
#  326  PEOE_VSA_FPPOS  float64
#  327  PEOE_VSA_HYD    float64
#  328  PEOE_VSA_NEG    float64
#  329  PEOE_VSA_PNEG   float64
#  330  PEOE_VSA_POL    float64
#  331  PEOE_VSA_POS    float64
#  332  PEOE_VSA_PPOS   float64
#  333  petitjean       float64
#  334  petitjeanSC     float64
#  335  pmi             float64
#  336  pmi1            float64
#  337  pmi2            float64
#  338  pmi3            float64
#  339  Q_PC+           float64
#  340  Q_PC-           float64
#  341  Q_RPC+          float64
#  342  Q_RPC-          float64
#  343  Q_VSA_FHYD      float64
#  344  Q_VSA_FNEG      float64
#  345  Q_VSA_FPNEG     float64
#  346  Q_VSA_FPOL      float64
#  347  Q_VSA_FPOS      float64
#  348  Q_VSA_FPPOS     float64
#  349  Q_VSA_HYD       float64
#  350  Q_VSA_NEG       float64
#  351  Q_VSA_PNEG      float64
#  352  Q_VSA_POL       float64
#  353  Q_VSA_POS       float64
#  354  Q_VSA_PPOS      float64
#  355  radius          int64
#  356  reactive        int64
#  357  rgyr            float64
#  358  rings           int64
#  359  RPC+            float64
#  360  RPC-            float64
#  361  rsynth          float64
#  362  SlogP           float64
#  363  SlogP_VSA0      float64
#  364  SlogP_VSA1      float64
#  365  SlogP_VSA2      float64
#  366  SlogP_VSA3      float64
#  367  SlogP_VSA4      float64
#  368  SlogP_VSA5      float64
#  369  SlogP_VSA6      float64
#  370  SlogP_VSA7      float64
#  371  SlogP_VSA8      float64
#  372  SlogP_VSA9      float64
#  373  SMR             float64
#  374  SMR_VSA0        float64
#  375  SMR_VSA1        float64
#  376  SMR_VSA2        float64
#  377  SMR_VSA3        float64
#  378  SMR_VSA4        float64
#  379  SMR_VSA5        float64
#  380  SMR_VSA6        float64
#  381  SMR_VSA7        float64
#  382  std_dim1        float64
#  383  std_dim2        float64
#  384  std_dim3        float64
#  385  TPSA            float64
#  386  VAdjEq          float64
#  387  VAdjMa          float64
#  388  VDistEq         float64
#  389  VDistMa         float64
#  390  vdw_area        float64
#  391  vdw_vol         float64
#  392  vol             float64
#  393  VSA             float64
#  394  vsa_acc         float64
#  395  vsa_acid        float64
#  396  vsa_base        float64
#  397  vsa_don         float64
#  398  vsa_hyd         float64
#  399  vsa_other       float64
#  400  vsa_pol         float64
#  401  vsurf_CW1       float64
#  402  vsurf_CW2       float64
#  403  vsurf_CW3       float64
#  404  vsurf_CW4       float64
#  405  vsurf_CW5       float64
#  406  vsurf_CW6       float64
#  407  vsurf_CW7       float64
#  408  vsurf_CW8       float64
#  409  vsurf_D1        float64
#  410  vsurf_D2        float64
#  411  vsurf_D3        float64
#  412  vsurf_D4        float64
#  413  vsurf_D5        float64
#  414  vsurf_D6        float64
#  415  vsurf_D7        float64
#  416  vsurf_D8        float64
#  417  vsurf_DD12      float64
#  418  vsurf_DD13      float64
#  419  vsurf_DD23      float64
#  420  vsurf_DW12      float64
#  421  vsurf_DW13      float64
#  422  vsurf_DW23      float64
#  423  vsurf_EDmin1    float64
#  424  vsurf_EDmin2    float64
#  425  vsurf_EDmin3    float64
#  426  vsurf_EWmin1    float64
#  427  vsurf_EWmin2    float64
#  428  vsurf_EWmin3    float64
#  429  vsurf_G         float64
#  430  vsurf_HB1       float64
#  431  vsurf_HB2       float64
#  432  vsurf_HB3       float64
#  433  vsurf_HB4       float64
#  434  vsurf_HB5       float64
#  435  vsurf_HB6       float64
#  436  vsurf_HB7       float64
#  437  vsurf_HB8       float64
#  438  vsurf_HL1       float64
#  439  vsurf_HL2       float64
#  440  vsurf_ID1       float64
#  441  vsurf_ID2       float64
#  442  vsurf_ID3       float64
#  443  vsurf_ID4       float64
#  444  vsurf_ID5       float64
#  445  vsurf_ID6       float64
#  446  vsurf_ID7       float64
#  447  vsurf_ID8       float64
#  448  vsurf_IW1       float64
#  449  vsurf_IW2       float64
#  450  vsurf_IW3       float64
#  451  vsurf_IW4       float64
#  452  vsurf_IW5       float64
#  453  vsurf_IW6       float64
#  454  vsurf_IW7       float64
#  455  vsurf_IW8       float64
#  456  vsurf_R         float64
#  457  vsurf_S         float64
#  458  vsurf_V         float64
#  459  vsurf_W1        float64
#  460  vsurf_W2        float64
#  461  vsurf_W3        float64
#  462  vsurf_W4        float64
#  463  vsurf_W5        float64
#  464  vsurf_W6        float64
#  465  vsurf_W7        float64
#  466  vsurf_W8        float64
#  467  vsurf_Wp1       float64
#  468  vsurf_Wp2       float64
#  469  vsurf_Wp3       float64
#  470  vsurf_Wp4       float64
#  471  vsurf_Wp5       float64
#  472  vsurf_Wp6       float64
#  473  vsurf_Wp7       float64
#  474  vsurf_Wp8       int64
#  475  Weight          float64
#  476  weinerPath      int64
#  477  weinerPol       int64
#  478  zagreb          int64
# dtypes: float64(265), int64(214)
# memory usage: 217.2 KB
# None
# ===== COLS WITH NAN VALUES =====
# Log_MP_RATIO    0
# apol            0
# ASA             0
# ASA+            0
# ASA-            0
#                ..
# vsurf_Wp8       0
# Weight          0
# weinerPath      0
# weinerPol       0
# zagreb          0
# Length: 479, dtype: int64
# ===== BASIC DATA OVERVIEW (TEST) =====
# >>> Description
#        Log_MP_RATIO       apol         ASA        ASA+        ASA-  \
# count     14.000000  14.000000   14.000000   14.000000   14.000000
# mean      -0.389061  54.420879  585.290244  369.607896  207.420523
# std        0.753420  13.542840   96.787614   90.472124   75.165576
# min       -1.698970  45.533447  487.608280  236.196720   80.522285
# 25%       -0.902542  47.277533  525.792160  313.754687  149.730255
# 50%       -0.331171  50.178066  557.535190  363.106595  219.140205
# 75%        0.240546  55.297703  616.793795  412.299070  252.565718
# max        0.617000  97.551239  814.912720  588.984500  350.024600
#
#             ASA_H       ASA_P      a_acc     a_acid      a_aro  ...  \
# count   14.000000   14.000000  14.000000  14.000000  14.000000  ...
# mean   427.683325  157.606922   2.500000   0.642857   7.785714  ...
# std     80.951366  113.097632   2.345208   1.336306   3.598687  ...
# min    293.114320   38.270668   0.000000   0.000000   0.000000  ...
# 25%    383.188818   89.814440   1.000000   0.000000   6.000000  ...
# 50%    445.226850  106.645155   2.000000   0.000000   6.000000  ...
# 75%    474.025685  229.938285   3.000000   0.000000  11.500000  ...
# max    549.115600  444.912320   8.000000   4.000000  12.000000  ...
#
#         vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  \
# count   14.000000  14.000000  14.000000  14.000000  14.000000       14.0
# mean    99.258929  22.937500   8.437500   2.080357   0.053571        0.0
# std     41.217600  12.819264   4.978017   1.702379   0.167807        0.0
# min     34.750000   0.000000   0.000000   0.000000   0.000000        0.0
# 25%     78.343750  13.718750   4.781250   1.187500   0.000000        0.0
# 50%     96.312500  20.562500   7.937500   1.687500   0.000000        0.0
# 75%    107.437500  31.875000  10.625000   2.000000   0.000000        0.0
# max    183.875000  47.250000  18.750000   6.125000   0.625000        0.0
#
#            Weight   weinerPath  weinerPol      zagreb
# count   14.000000    14.000000  14.000000   14.000000
# mean   348.517564  1640.000000  38.571429  126.000000
# std    100.125673  1414.677348  13.403296   36.894861
# min    260.356990   759.000000  21.000000   84.000000
# 25%    283.906490   800.000000  30.500000  103.000000
# 50%    313.607500  1027.000000  34.000000  110.000000
# 75%    366.760745  1585.750000  42.000000  137.500000
# max    582.755000  5278.000000  70.000000  212.000000
#
# [8 rows x 479 columns]
# >>> Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 479 columns):
#  #    Column          Dtype
# ---   ------          -----
#  0    Log_MP_RATIO    float64
#  1    apol            float64
#  2    ASA             float64
#  3    ASA+            float64
#  4    ASA-            float64
#  5    ASA_H           float64
#  6    ASA_P           float64
#  7    a_acc           int64
#  8    a_acid          int64
#  9    a_aro           int64
#  10   a_base          int64
#  11   a_count         int64
#  12   a_don           int64
#  13   a_donacc        int64
#  14   a_heavy         int64
#  15   a_hyd           int64
#  16   a_IC            float64
#  17   a_ICM           float64
#  18   a_nB            int64
#  19   a_nBr           int64
#  20   a_nC            int64
#  21   a_nCl           int64
#  22   a_nF            int64
#  23   a_nH            int64
#  24   a_nI            int64
#  25   a_nN            int64
#  26   a_nO            int64
#  27   a_nP            int64
#  28   a_nS            int64
#  29   balabanJ        float64
#  30   BCUT_PEOE_0     float64
#  31   BCUT_PEOE_1     float64
#  32   BCUT_PEOE_2     float64
#  33   BCUT_PEOE_3     float64
#  34   BCUT_SLOGP_0    float64
#  35   BCUT_SLOGP_1    float64
#  36   BCUT_SLOGP_2    float64
#  37   BCUT_SLOGP_3    float64
#  38   BCUT_SMR_0      float64
#  39   BCUT_SMR_1      float64
#  40   BCUT_SMR_2      float64
#  41   BCUT_SMR_3      float64
#  42   bpol            float64
#  43   b_1rotN         int64
#  44   b_1rotR         float64
#  45   b_ar            int64
#  46   b_count         int64
#  47   b_double        int64
#  48   b_heavy         int64
#  49   b_max1len       int64
#  50   b_rotN          int64
#  51   b_rotR          float64
#  52   b_single        int64
#  53   b_triple        int64
#  54   CASA+           float64
#  55   CASA-           float64
#  56   chi0            float64
#  57   chi0v           float64
#  58   chi0v_C         float64
#  59   chi0_C          float64
#  60   chi1            float64
#  61   chi1v           float64
#  62   chi1v_C         float64
#  63   chi1_C          float64
#  64   chiral          int64
#  65   chiral_u        int64
#  66   DASA            float64
#  67   DCASA           float64
#  68   density         float64
#  69   diameter        int64
#  70   dipole          float64
#  71   E               float64
#  72   E_ang           float64
#  73   E_ele           float64
#  74   E_nb            float64
#  75   E_oop           float64
#  76   E_sol           float64
#  77   E_stb           int64
#  78   E_str           float64
#  79   E_strain        float64
#  80   E_tor           float64
#  81   E_vdw           float64
#  82   FASA+           float64
#  83   FASA-           float64
#  84   FASA_H          float64
#  85   FASA_P          float64
#  86   FCASA+          float64
#  87   FCASA-          float64
#  88   FCharge         int64
#  89   GCUT_PEOE_0     float64
#  90   GCUT_PEOE_1     float64
#  91   GCUT_PEOE_2     float64
#  92   GCUT_PEOE_3     float64
#  93   GCUT_SLOGP_0    float64
#  94   GCUT_SLOGP_1    float64
#  95   GCUT_SLOGP_2    float64
#  96   GCUT_SLOGP_3    float64
#  97   GCUT_SMR_0      float64
#  98   GCUT_SMR_1      float64
#  99   GCUT_SMR_2      float64
#  100  GCUT_SMR_3      float64
#  101  glob            float64
#  102  h_ema           float64
#  103  h_emd           float64
#  104  h_emd_C         float64
#  105  h_logD          float64
#  106  h_logP          float64
#  107  h_logS          float64
#  108  h_log_dbo       int64
#  109  h_log_pbo       float64
#  110  h_mr            float64
#  111  h_pavgQ         float64
#  112  h_pKa           float64
#  113  h_pKb           float64
#  114  h_pstates       float64
#  115  h_pstrain       float64
#  116  Kier1           float64
#  117  Kier2           float64
#  118  Kier3           float64
#  119  KierA1          float64
#  120  KierA2          float64
#  121  KierA3          float64
#  122  KierFlex        float64
#  123  logP(o/w)       float64
#  124  logS            float64
#  125  MACCS(--1)      int64
#  126  MACCS(--2)      int64
#  127  MACCS(--3)      int64
#  128  MACCS(--4)      int64
#  129  MACCS(--5)      int64
#  130  MACCS(--6)      int64
#  131  MACCS(--7)      int64
#  132  MACCS(--8)      int64
#  133  MACCS(--9)      int64
#  134  MACCS(-10)      int64
#  135  MACCS(-11)      int64
#  136  MACCS(-12)      int64
#  137  MACCS(-13)      int64
#  138  MACCS(-14)      int64
#  139  MACCS(-15)      int64
#  140  MACCS(-16)      int64
#  141  MACCS(-17)      int64
#  142  MACCS(-18)      int64
#  143  MACCS(-19)      int64
#  144  MACCS(-20)      int64
#  145  MACCS(-21)      int64
#  146  MACCS(-22)      int64
#  147  MACCS(-23)      int64
#  148  MACCS(-24)      int64
#  149  MACCS(-25)      int64
#  150  MACCS(-26)      int64
#  151  MACCS(-27)      int64
#  152  MACCS(-28)      int64
#  153  MACCS(-29)      int64
#  154  MACCS(-30)      int64
#  155  MACCS(-31)      int64
#  156  MACCS(-32)      int64
#  157  MACCS(-33)      int64
#  158  MACCS(-34)      int64
#  159  MACCS(-35)      int64
#  160  MACCS(-36)      int64
#  161  MACCS(-37)      int64
#  162  MACCS(-38)      int64
#  163  MACCS(-39)      int64
#  164  MACCS(-40)      int64
#  165  MACCS(-41)      int64
#  166  MACCS(-42)      int64
#  167  MACCS(-43)      int64
#  168  MACCS(-44)      int64
#  169  MACCS(-45)      int64
#  170  MACCS(-46)      int64
#  171  MACCS(-47)      int64
#  172  MACCS(-48)      int64
#  173  MACCS(-49)      int64
#  174  MACCS(-50)      int64
#  175  MACCS(-51)      int64
#  176  MACCS(-52)      int64
#  177  MACCS(-53)      int64
#  178  MACCS(-54)      int64
#  179  MACCS(-55)      int64
#  180  MACCS(-56)      int64
#  181  MACCS(-57)      int64
#  182  MACCS(-58)      int64
#  183  MACCS(-59)      int64
#  184  MACCS(-60)      int64
#  185  MACCS(-61)      int64
#  186  MACCS(-62)      int64
#  187  MACCS(-63)      int64
#  188  MACCS(-64)      int64
#  189  MACCS(-65)      int64
#  190  MACCS(-66)      int64
#  191  MACCS(-67)      int64
#  192  MACCS(-68)      int64
#  193  MACCS(-69)      int64
#  194  MACCS(-70)      int64
#  195  MACCS(-71)      int64
#  196  MACCS(-72)      int64
#  197  MACCS(-73)      int64
#  198  MACCS(-74)      int64
#  199  MACCS(-75)      int64
#  200  MACCS(-76)      int64
#  201  MACCS(-77)      int64
#  202  MACCS(-78)      int64
#  203  MACCS(-79)      int64
#  204  MACCS(-80)      int64
#  205  MACCS(-81)      int64
#  206  MACCS(-82)      int64
#  207  MACCS(-83)      int64
#  208  MACCS(-84)      int64
#  209  MACCS(-85)      int64
#  210  MACCS(-86)      int64
#  211  MACCS(-87)      int64
#  212  MACCS(-88)      int64
#  213  MACCS(-89)      int64
#  214  MACCS(-90)      int64
#  215  MACCS(-91)      int64
#  216  MACCS(-92)      int64
#  217  MACCS(-93)      int64
#  218  MACCS(-94)      int64
#  219  MACCS(-95)      int64
#  220  MACCS(-96)      int64
#  221  MACCS(-97)      int64
#  222  MACCS(-98)      int64
#  223  MACCS(-99)      int64
#  224  MACCS(100)      int64
#  225  MACCS(101)      int64
#  226  MACCS(102)      int64
#  227  MACCS(103)      int64
#  228  MACCS(104)      int64
#  229  MACCS(105)      int64
#  230  MACCS(106)      int64
#  231  MACCS(107)      int64
#  232  MACCS(108)      int64
#  233  MACCS(109)      int64
#  234  MACCS(110)      int64
#  235  MACCS(111)      int64
#  236  MACCS(112)      int64
#  237  MACCS(113)      int64
#  238  MACCS(114)      int64
#  239  MACCS(115)      int64
#  240  MACCS(116)      int64
#  241  MACCS(117)      int64
#  242  MACCS(118)      int64
#  243  MACCS(119)      int64
#  244  MACCS(120)      int64
#  245  MACCS(121)      int64
#  246  MACCS(122)      int64
#  247  MACCS(123)      int64
#  248  MACCS(124)      int64
#  249  MACCS(125)      int64
#  250  MACCS(126)      int64
#  251  MACCS(127)      int64
#  252  MACCS(128)      int64
#  253  MACCS(129)      int64
#  254  MACCS(130)      int64
#  255  MACCS(131)      int64
#  256  MACCS(132)      int64
#  257  MACCS(133)      int64
#  258  MACCS(134)      int64
#  259  MACCS(135)      int64
#  260  MACCS(136)      int64
#  261  MACCS(137)      int64
#  262  MACCS(138)      int64
#  263  MACCS(139)      int64
#  264  MACCS(140)      int64
#  265  MACCS(141)      int64
#  266  MACCS(142)      int64
#  267  MACCS(143)      int64
#  268  MACCS(144)      int64
#  269  MACCS(145)      int64
#  270  MACCS(146)      int64
#  271  MACCS(147)      int64
#  272  MACCS(148)      int64
#  273  MACCS(149)      int64
#  274  MACCS(150)      int64
#  275  MACCS(151)      int64
#  276  MACCS(152)      int64
#  277  MACCS(153)      int64
#  278  MACCS(154)      int64
#  279  MACCS(155)      int64
#  280  MACCS(156)      int64
#  281  MACCS(157)      int64
#  282  MACCS(158)      int64
#  283  MACCS(159)      int64
#  284  MACCS(160)      int64
#  285  MACCS(161)      int64
#  286  MACCS(162)      int64
#  287  MACCS(163)      int64
#  288  MACCS(164)      int64
#  289  MACCS(165)      int64
#  290  MACCS(166)      int64
#  291  mr              float64
#  292  mutagenic       int64
#  293  nmol            int64
#  294  npr1            float64
#  295  npr2            float64
#  296  opr_brigid      int64
#  297  opr_leadlike    int64
#  298  opr_nring       int64
#  299  opr_nrot        int64
#  300  opr_violation   int64
#  301  PC+             float64
#  302  PC-             float64
#  303  PEOE_PC+        float64
#  304  PEOE_PC-        float64
#  305  PEOE_RPC+       float64
#  306  PEOE_RPC-       float64
#  307  PEOE_VSA+0      float64
#  308  PEOE_VSA+1      float64
#  309  PEOE_VSA+2      float64
#  310  PEOE_VSA+3      float64
#  311  PEOE_VSA+4      float64
#  312  PEOE_VSA+5      float64
#  313  PEOE_VSA+6      float64
#  314  PEOE_VSA-0      float64
#  315  PEOE_VSA-1      float64
#  316  PEOE_VSA-2      float64
#  317  PEOE_VSA-3      float64
#  318  PEOE_VSA-4      float64
#  319  PEOE_VSA-5      float64
#  320  PEOE_VSA-6      float64
#  321  PEOE_VSA_FHYD   float64
#  322  PEOE_VSA_FNEG   float64
#  323  PEOE_VSA_FPNEG  float64
#  324  PEOE_VSA_FPOL   float64
#  325  PEOE_VSA_FPOS   float64
#  326  PEOE_VSA_FPPOS  float64
#  327  PEOE_VSA_HYD    float64
#  328  PEOE_VSA_NEG    float64
#  329  PEOE_VSA_PNEG   float64
#  330  PEOE_VSA_POL    float64
#  331  PEOE_VSA_POS    float64
#  332  PEOE_VSA_PPOS   float64
#  333  petitjean       float64
#  334  petitjeanSC     float64
#  335  pmi             float64
#  336  pmi1            float64
#  337  pmi2            float64
#  338  pmi3            float64
#  339  Q_PC+           float64
#  340  Q_PC-           float64
#  341  Q_RPC+          float64
#  342  Q_RPC-          float64
#  343  Q_VSA_FHYD      float64
#  344  Q_VSA_FNEG      float64
#  345  Q_VSA_FPNEG     float64
#  346  Q_VSA_FPOL      float64
#  347  Q_VSA_FPOS      float64
#  348  Q_VSA_FPPOS     float64
#  349  Q_VSA_HYD       float64
#  350  Q_VSA_NEG       float64
#  351  Q_VSA_PNEG      float64
#  352  Q_VSA_POL       float64
#  353  Q_VSA_POS       float64
#  354  Q_VSA_PPOS      float64
#  355  radius          int64
#  356  reactive        int64
#  357  rgyr            float64
#  358  rings           int64
#  359  RPC+            float64
#  360  RPC-            float64
#  361  rsynth          float64
#  362  SlogP           float64
#  363  SlogP_VSA0      float64
#  364  SlogP_VSA1      float64
#  365  SlogP_VSA2      float64
#  366  SlogP_VSA3      float64
#  367  SlogP_VSA4      float64
#  368  SlogP_VSA5      float64
#  369  SlogP_VSA6      float64
#  370  SlogP_VSA7      float64
#  371  SlogP_VSA8      float64
#  372  SlogP_VSA9      float64
#  373  SMR             float64
#  374  SMR_VSA0        float64
#  375  SMR_VSA1        float64
#  376  SMR_VSA2        float64
#  377  SMR_VSA3        float64
#  378  SMR_VSA4        float64
#  379  SMR_VSA5        float64
#  380  SMR_VSA6        float64
#  381  SMR_VSA7        float64
#  382  std_dim1        float64
#  383  std_dim2        float64
#  384  std_dim3        float64
#  385  TPSA            float64
#  386  VAdjEq          float64
#  387  VAdjMa          float64
#  388  VDistEq         float64
#  389  VDistMa         float64
#  390  vdw_area        float64
#  391  vdw_vol         float64
#  392  vol             float64
#  393  VSA             float64
#  394  vsa_acc         float64
#  395  vsa_acid        float64
#  396  vsa_base        float64
#  397  vsa_don         float64
#  398  vsa_hyd         float64
#  399  vsa_other       float64
#  400  vsa_pol         float64
#  401  vsurf_CW1       float64
#  402  vsurf_CW2       float64
#  403  vsurf_CW3       float64
#  404  vsurf_CW4       float64
#  405  vsurf_CW5       float64
#  406  vsurf_CW6       float64
#  407  vsurf_CW7       float64
#  408  vsurf_CW8       float64
#  409  vsurf_D1        float64
#  410  vsurf_D2        float64
#  411  vsurf_D3        float64
#  412  vsurf_D4        float64
#  413  vsurf_D5        float64
#  414  vsurf_D6        float64
#  415  vsurf_D7        float64
#  416  vsurf_D8        float64
#  417  vsurf_DD12      float64
#  418  vsurf_DD13      float64
#  419  vsurf_DD23      float64
#  420  vsurf_DW12      float64
#  421  vsurf_DW13      float64
#  422  vsurf_DW23      float64
#  423  vsurf_EDmin1    float64
#  424  vsurf_EDmin2    float64
#  425  vsurf_EDmin3    float64
#  426  vsurf_EWmin1    float64
#  427  vsurf_EWmin2    float64
#  428  vsurf_EWmin3    float64
#  429  vsurf_G         float64
#  430  vsurf_HB1       float64
#  431  vsurf_HB2       float64
#  432  vsurf_HB3       float64
#  433  vsurf_HB4       float64
#  434  vsurf_HB5       float64
#  435  vsurf_HB6       float64
#  436  vsurf_HB7       float64
#  437  vsurf_HB8       float64
#  438  vsurf_HL1       float64
#  439  vsurf_HL2       float64
#  440  vsurf_ID1       float64
#  441  vsurf_ID2       float64
#  442  vsurf_ID3       float64
#  443  vsurf_ID4       float64
#  444  vsurf_ID5       float64
#  445  vsurf_ID6       float64
#  446  vsurf_ID7       float64
#  447  vsurf_ID8       float64
#  448  vsurf_IW1       float64
#  449  vsurf_IW2       float64
#  450  vsurf_IW3       float64
#  451  vsurf_IW4       float64
#  452  vsurf_IW5       float64
#  453  vsurf_IW6       float64
#  454  vsurf_IW7       float64
#  455  vsurf_IW8       float64
#  456  vsurf_R         float64
#  457  vsurf_S         float64
#  458  vsurf_V         float64
#  459  vsurf_W1        float64
#  460  vsurf_W2        float64
#  461  vsurf_W3        float64
#  462  vsurf_W4        float64
#  463  vsurf_W5        float64
#  464  vsurf_W6        float64
#  465  vsurf_W7        float64
#  466  vsurf_W8        float64
#  467  vsurf_Wp1       float64
#  468  vsurf_Wp2       float64
#  469  vsurf_Wp3       float64
#  470  vsurf_Wp4       float64
#  471  vsurf_Wp5       float64
#  472  vsurf_Wp6       float64
#  473  vsurf_Wp7       float64
#  474  vsurf_Wp8       int64
#  475  Weight          float64
#  476  weinerPath      int64
#  477  weinerPol       int64
#  478  zagreb          int64
# dtypes: float64(264), int64(215)
# memory usage: 52.5 KB
# None
# ===== COLS WITH NAN VALUES =====
# Log_MP_RATIO    0
# apol            0
# ASA             0
# ASA+            0
# ASA-            0
#                ..
# vsurf_Wp8       0
# Weight          0
# weinerPath      0
# weinerPol       0
# zagreb          0
# Length: 479, dtype: int64

# %% [markdown]
# ## Neutral

# %% [markdown]
# ### Values and missing values

# %%
print("===== BASIC DATA OVERVIEW (TRAIN) =====")
print(">>> Description")
display(df_neutral_train.describe())
print(">>> Info")
display(df_neutral_train.info(verbose=True))
print("===== COLS WITH NAN VALUES =====")
display(df_neutral_train.isna().sum())

print("===== BASIC DATA OVERVIEW (TEST) =====")
print(">>> Description")
display(df_neutral_test.describe())
print(">>> Info")
display(df_neutral_test.info(verbose=True))
print("===== COLS WITH NAN VALUES =====")
display(df_neutral_test.isna().sum())
# Out:
# ===== BASIC DATA OVERVIEW (TRAIN) =====
# >>> Description
#        Log_MP_RATIO        apol          ASA        ASA+        ASA-  \
# count     89.000000   89.000000    89.000000   89.000000   89.000000
# mean       0.205050   39.213344   492.867794  189.358713  302.016805
# std        0.551593   13.463072   104.785824  134.880187  132.590706
# min       -1.000000    8.322758   197.574580    0.000000   64.410759
# 25%       -0.159894   34.822380   450.575990   90.301811  182.822480
# 50%        0.269513   37.137585   490.290860  141.864210  332.514560
# 75%        0.667194   42.087173   532.397770  263.049500  399.243130
# max        1.311038  126.062750  1094.164700  794.894100  625.281980
#
#             ASA_H       ASA_P      a_acc     a_acid      a_aro  ...  \
# count   89.000000   89.000000  89.000000  89.000000  89.000000  ...
# mean   391.694980  101.172813   1.505618   0.134831   8.921348  ...
# std    152.233089  117.607082   2.078699   0.504322   4.548288  ...
# min      0.000000    0.000000   0.000000   0.000000   0.000000  ...
# 25%    272.204560    0.000000   0.000000   0.000000   6.000000  ...
# 50%    438.416870   75.795723   1.000000   0.000000  12.000000  ...
# 75%    501.342380  145.247270   2.000000   0.000000  12.000000  ...
# max    704.761290  498.010990  13.000000   2.000000  17.000000  ...
#
#         vsurf_Wp3  vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8  \
# count   89.000000  89.000000  89.000000  89.000000  89.000000  89.000000
# mean    68.057584   9.712079   3.780899   1.129213   0.116573   0.014045
# std     41.516422  16.528045   6.833586   2.250982   0.523523   0.132500
# min      0.250000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     42.125000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     56.375000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     84.375000  14.750000   5.750000   1.375000   0.000000   0.000000
# max    205.250000  68.625000  27.375000  11.125000   4.625000   1.250000
#
#            Weight    weinerPath   weinerPol      zagreb
# count   89.000000     89.000000   89.000000   89.000000
# mean   358.253496    865.595506   33.157303  101.573034
# std    148.898579   1573.746093   15.804127   37.437793
# min     46.069000      4.000000    0.000000    6.000000
# 25%    268.743990    488.000000   25.000000   86.000000
# 50%    344.495000    612.000000   30.000000   96.000000
# 75%    406.898990    791.000000   40.000000  116.000000
# max    959.170960  14940.000000  113.000000  320.000000
#
# [8 rows x 479 columns]
# >>> Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 479 columns):
#  #    Column          Dtype
# ---   ------          -----
#  0    Log_MP_RATIO    float64
#  1    apol            float64
#  2    ASA             float64
#  3    ASA+            float64
#  4    ASA-            float64
#  5    ASA_H           float64
#  6    ASA_P           float64
#  7    a_acc           int64
#  8    a_acid          int64
#  9    a_aro           int64
#  10   a_base          int64
#  11   a_count         int64
#  12   a_don           int64
#  13   a_donacc        int64
#  14   a_heavy         int64
#  15   a_hyd           int64
#  16   a_IC            float64
#  17   a_ICM           float64
#  18   a_nB            int64
#  19   a_nBr           int64
#  20   a_nC            int64
#  21   a_nCl           int64
#  22   a_nF            int64
#  23   a_nH            int64
#  24   a_nI            int64
#  25   a_nN            int64
#  26   a_nO            int64
#  27   a_nP            int64
#  28   a_nS            int64
#  29   balabanJ        float64
#  30   BCUT_PEOE_0     float64
#  31   BCUT_PEOE_1     float64
#  32   BCUT_PEOE_2     float64
#  33   BCUT_PEOE_3     float64
#  34   BCUT_SLOGP_0    float64
#  35   BCUT_SLOGP_1    float64
#  36   BCUT_SLOGP_2    float64
#  37   BCUT_SLOGP_3    float64
#  38   BCUT_SMR_0      float64
#  39   BCUT_SMR_1      float64
#  40   BCUT_SMR_2      float64
#  41   BCUT_SMR_3      float64
#  42   bpol            float64
#  43   b_1rotN         int64
#  44   b_1rotR         float64
#  45   b_ar            int64
#  46   b_count         int64
#  47   b_double        int64
#  48   b_heavy         int64
#  49   b_max1len       int64
#  50   b_rotN          int64
#  51   b_rotR          float64
#  52   b_single        int64
#  53   b_triple        int64
#  54   CASA+           float64
#  55   CASA-           float64
#  56   chi0            float64
#  57   chi0v           float64
#  58   chi0v_C         float64
#  59   chi0_C          float64
#  60   chi1            float64
#  61   chi1v           float64
#  62   chi1v_C         float64
#  63   chi1_C          float64
#  64   chiral          int64
#  65   chiral_u        int64
#  66   DASA            float64
#  67   DCASA           float64
#  68   density         float64
#  69   diameter        int64
#  70   dipole          float64
#  71   E               float64
#  72   E_ang           float64
#  73   E_ele           float64
#  74   E_nb            float64
#  75   E_oop           float64
#  76   E_sol           float64
#  77   E_stb           int64
#  78   E_str           float64
#  79   E_strain        float64
#  80   E_tor           float64
#  81   E_vdw           float64
#  82   FASA+           float64
#  83   FASA-           float64
#  84   FASA_H          float64
#  85   FASA_P          float64
#  86   FCASA+          float64
#  87   FCASA-          float64
#  88   FCharge         int64
#  89   GCUT_PEOE_0     float64
#  90   GCUT_PEOE_1     float64
#  91   GCUT_PEOE_2     float64
#  92   GCUT_PEOE_3     float64
#  93   GCUT_SLOGP_0    float64
#  94   GCUT_SLOGP_1    float64
#  95   GCUT_SLOGP_2    float64
#  96   GCUT_SLOGP_3    float64
#  97   GCUT_SMR_0      float64
#  98   GCUT_SMR_1      float64
#  99   GCUT_SMR_2      float64
#  100  GCUT_SMR_3      float64
#  101  glob            float64
#  102  h_ema           float64
#  103  h_emd           float64
#  104  h_emd_C         float64
#  105  h_logD          float64
#  106  h_logP          float64
#  107  h_logS          float64
#  108  h_log_dbo       float64
#  109  h_log_pbo       float64
#  110  h_mr            float64
#  111  h_pavgQ         float64
#  112  h_pKa           float64
#  113  h_pKb           float64
#  114  h_pstates       float64
#  115  h_pstrain       float64
#  116  Kier1           float64
#  117  Kier2           float64
#  118  Kier3           float64
#  119  KierA1          float64
#  120  KierA2          float64
#  121  KierA3          float64
#  122  KierFlex        float64
#  123  logP(o/w)       float64
#  124  logS            float64
#  125  MACCS(--1)      int64
#  126  MACCS(--2)      int64
#  127  MACCS(--3)      int64
#  128  MACCS(--4)      int64
#  129  MACCS(--5)      int64
#  130  MACCS(--6)      int64
#  131  MACCS(--7)      int64
#  132  MACCS(--8)      int64
#  133  MACCS(--9)      int64
#  134  MACCS(-10)      int64
#  135  MACCS(-11)      int64
#  136  MACCS(-12)      int64
#  137  MACCS(-13)      int64
#  138  MACCS(-14)      int64
#  139  MACCS(-15)      int64
#  140  MACCS(-16)      int64
#  141  MACCS(-17)      int64
#  142  MACCS(-18)      int64
#  143  MACCS(-19)      int64
#  144  MACCS(-20)      int64
#  145  MACCS(-21)      int64
#  146  MACCS(-22)      int64
#  147  MACCS(-23)      int64
#  148  MACCS(-24)      int64
#  149  MACCS(-25)      int64
#  150  MACCS(-26)      int64
#  151  MACCS(-27)      int64
#  152  MACCS(-28)      int64
#  153  MACCS(-29)      int64
#  154  MACCS(-30)      int64
#  155  MACCS(-31)      int64
#  156  MACCS(-32)      int64
#  157  MACCS(-33)      int64
#  158  MACCS(-34)      int64
#  159  MACCS(-35)      int64
#  160  MACCS(-36)      int64
#  161  MACCS(-37)      int64
#  162  MACCS(-38)      int64
#  163  MACCS(-39)      int64
#  164  MACCS(-40)      int64
#  165  MACCS(-41)      int64
#  166  MACCS(-42)      int64
#  167  MACCS(-43)      int64
#  168  MACCS(-44)      int64
#  169  MACCS(-45)      int64
#  170  MACCS(-46)      int64
#  171  MACCS(-47)      int64
#  172  MACCS(-48)      int64
#  173  MACCS(-49)      int64
#  174  MACCS(-50)      int64
#  175  MACCS(-51)      int64
#  176  MACCS(-52)      int64
#  177  MACCS(-53)      int64
#  178  MACCS(-54)      int64
#  179  MACCS(-55)      int64
#  180  MACCS(-56)      int64
#  181  MACCS(-57)      int64
#  182  MACCS(-58)      int64
#  183  MACCS(-59)      int64
#  184  MACCS(-60)      int64
#  185  MACCS(-61)      int64
#  186  MACCS(-62)      int64
#  187  MACCS(-63)      int64
#  188  MACCS(-64)      int64
#  189  MACCS(-65)      int64
#  190  MACCS(-66)      int64
#  191  MACCS(-67)      int64
#  192  MACCS(-68)      int64
#  193  MACCS(-69)      int64
#  194  MACCS(-70)      int64
#  195  MACCS(-71)      int64
#  196  MACCS(-72)      int64
#  197  MACCS(-73)      int64
#  198  MACCS(-74)      int64
#  199  MACCS(-75)      int64
#  200  MACCS(-76)      int64
#  201  MACCS(-77)      int64
#  202  MACCS(-78)      int64
#  203  MACCS(-79)      int64
#  204  MACCS(-80)      int64
#  205  MACCS(-81)      int64
#  206  MACCS(-82)      int64
#  207  MACCS(-83)      int64
#  208  MACCS(-84)      int64
#  209  MACCS(-85)      int64
#  210  MACCS(-86)      int64
#  211  MACCS(-87)      int64
#  212  MACCS(-88)      int64
#  213  MACCS(-89)      int64
#  214  MACCS(-90)      int64
#  215  MACCS(-91)      int64
#  216  MACCS(-92)      int64
#  217  MACCS(-93)      int64
#  218  MACCS(-94)      int64
#  219  MACCS(-95)      int64
#  220  MACCS(-96)      int64
#  221  MACCS(-97)      int64
#  222  MACCS(-98)      int64
#  223  MACCS(-99)      int64
#  224  MACCS(100)      int64
#  225  MACCS(101)      int64
#  226  MACCS(102)      int64
#  227  MACCS(103)      int64
#  228  MACCS(104)      int64
#  229  MACCS(105)      int64
#  230  MACCS(106)      int64
#  231  MACCS(107)      int64
#  232  MACCS(108)      int64
#  233  MACCS(109)      int64
#  234  MACCS(110)      int64
#  235  MACCS(111)      int64
#  236  MACCS(112)      int64
#  237  MACCS(113)      int64
#  238  MACCS(114)      int64
#  239  MACCS(115)      int64
#  240  MACCS(116)      int64
#  241  MACCS(117)      int64
#  242  MACCS(118)      int64
#  243  MACCS(119)      int64
#  244  MACCS(120)      int64
#  245  MACCS(121)      int64
#  246  MACCS(122)      int64
#  247  MACCS(123)      int64
#  248  MACCS(124)      int64
#  249  MACCS(125)      int64
#  250  MACCS(126)      int64
#  251  MACCS(127)      int64
#  252  MACCS(128)      int64
#  253  MACCS(129)      int64
#  254  MACCS(130)      int64
#  255  MACCS(131)      int64
#  256  MACCS(132)      int64
#  257  MACCS(133)      int64
#  258  MACCS(134)      int64
#  259  MACCS(135)      int64
#  260  MACCS(136)      int64
#  261  MACCS(137)      int64
#  262  MACCS(138)      int64
#  263  MACCS(139)      int64
#  264  MACCS(140)      int64
#  265  MACCS(141)      int64
#  266  MACCS(142)      int64
#  267  MACCS(143)      int64
#  268  MACCS(144)      int64
#  269  MACCS(145)      int64
#  270  MACCS(146)      int64
#  271  MACCS(147)      int64
#  272  MACCS(148)      int64
#  273  MACCS(149)      int64
#  274  MACCS(150)      int64
#  275  MACCS(151)      int64
#  276  MACCS(152)      int64
#  277  MACCS(153)      int64
#  278  MACCS(154)      int64
#  279  MACCS(155)      int64
#  280  MACCS(156)      int64
#  281  MACCS(157)      int64
#  282  MACCS(158)      int64
#  283  MACCS(159)      int64
#  284  MACCS(160)      int64
#  285  MACCS(161)      int64
#  286  MACCS(162)      int64
#  287  MACCS(163)      int64
#  288  MACCS(164)      int64
#  289  MACCS(165)      int64
#  290  MACCS(166)      int64
#  291  mr              float64
#  292  mutagenic       int64
#  293  nmol            int64
#  294  npr1            float64
#  295  npr2            float64
#  296  opr_brigid      int64
#  297  opr_leadlike    int64
#  298  opr_nring       int64
#  299  opr_nrot        int64
#  300  opr_violation   int64
#  301  PC+             float64
#  302  PC-             float64
#  303  PEOE_PC+        float64
#  304  PEOE_PC-        float64
#  305  PEOE_RPC+       float64
#  306  PEOE_RPC-       float64
#  307  PEOE_VSA+0      float64
#  308  PEOE_VSA+1      float64
#  309  PEOE_VSA+2      float64
#  310  PEOE_VSA+3      float64
#  311  PEOE_VSA+4      float64
#  312  PEOE_VSA+5      float64
#  313  PEOE_VSA+6      float64
#  314  PEOE_VSA-0      float64
#  315  PEOE_VSA-1      float64
#  316  PEOE_VSA-2      float64
#  317  PEOE_VSA-3      float64
#  318  PEOE_VSA-4      float64
#  319  PEOE_VSA-5      float64
#  320  PEOE_VSA-6      float64
#  321  PEOE_VSA_FHYD   float64
#  322  PEOE_VSA_FNEG   float64
#  323  PEOE_VSA_FPNEG  float64
#  324  PEOE_VSA_FPOL   float64
#  325  PEOE_VSA_FPOS   float64
#  326  PEOE_VSA_FPPOS  float64
#  327  PEOE_VSA_HYD    float64
#  328  PEOE_VSA_NEG    float64
#  329  PEOE_VSA_PNEG   float64
#  330  PEOE_VSA_POL    float64
#  331  PEOE_VSA_POS    float64
#  332  PEOE_VSA_PPOS   float64
#  333  petitjean       float64
#  334  petitjeanSC     float64
#  335  pmi             float64
#  336  pmi1            float64
#  337  pmi2            float64
#  338  pmi3            float64
#  339  Q_PC+           float64
#  340  Q_PC-           float64
#  341  Q_RPC+          float64
#  342  Q_RPC-          float64
#  343  Q_VSA_FHYD      float64
#  344  Q_VSA_FNEG      float64
#  345  Q_VSA_FPNEG     float64
#  346  Q_VSA_FPOL      float64
#  347  Q_VSA_FPOS      float64
#  348  Q_VSA_FPPOS     float64
#  349  Q_VSA_HYD       float64
#  350  Q_VSA_NEG       float64
#  351  Q_VSA_PNEG      float64
#  352  Q_VSA_POL       float64
#  353  Q_VSA_POS       float64
#  354  Q_VSA_PPOS      float64
#  355  radius          int64
#  356  reactive        int64
#  357  rgyr            float64
#  358  rings           int64
#  359  RPC+            float64
#  360  RPC-            float64
#  361  rsynth          float64
#  362  SlogP           float64
#  363  SlogP_VSA0      float64
#  364  SlogP_VSA1      float64
#  365  SlogP_VSA2      float64
#  366  SlogP_VSA3      float64
#  367  SlogP_VSA4      float64
#  368  SlogP_VSA5      float64
#  369  SlogP_VSA6      float64
#  370  SlogP_VSA7      float64
#  371  SlogP_VSA8      float64
#  372  SlogP_VSA9      float64
#  373  SMR             float64
#  374  SMR_VSA0        float64
#  375  SMR_VSA1        float64
#  376  SMR_VSA2        float64
#  377  SMR_VSA3        float64
#  378  SMR_VSA4        float64
#  379  SMR_VSA5        float64
#  380  SMR_VSA6        float64
#  381  SMR_VSA7        float64
#  382  std_dim1        float64
#  383  std_dim2        float64
#  384  std_dim3        float64
#  385  TPSA            float64
#  386  VAdjEq          float64
#  387  VAdjMa          float64
#  388  VDistEq         float64
#  389  VDistMa         float64
#  390  vdw_area        float64
#  391  vdw_vol         float64
#  392  vol             float64
#  393  VSA             float64
#  394  vsa_acc         float64
#  395  vsa_acid        float64
#  396  vsa_base        float64
#  397  vsa_don         float64
#  398  vsa_hyd         float64
#  399  vsa_other       float64
#  400  vsa_pol         float64
#  401  vsurf_CW1       float64
#  402  vsurf_CW2       float64
#  403  vsurf_CW3       float64
#  404  vsurf_CW4       float64
#  405  vsurf_CW5       float64
#  406  vsurf_CW6       float64
#  407  vsurf_CW7       float64
#  408  vsurf_CW8       float64
#  409  vsurf_D1        float64
#  410  vsurf_D2        float64
#  411  vsurf_D3        float64
#  412  vsurf_D4        float64
#  413  vsurf_D5        float64
#  414  vsurf_D6        float64
#  415  vsurf_D7        float64
#  416  vsurf_D8        float64
#  417  vsurf_DD12      float64
#  418  vsurf_DD13      float64
#  419  vsurf_DD23      float64
#  420  vsurf_DW12      float64
#  421  vsurf_DW13      float64
#  422  vsurf_DW23      float64
#  423  vsurf_EDmin1    float64
#  424  vsurf_EDmin2    float64
#  425  vsurf_EDmin3    float64
#  426  vsurf_EWmin1    float64
#  427  vsurf_EWmin2    float64
#  428  vsurf_EWmin3    float64
#  429  vsurf_G         float64
#  430  vsurf_HB1       float64
#  431  vsurf_HB2       float64
#  432  vsurf_HB3       float64
#  433  vsurf_HB4       float64
#  434  vsurf_HB5       float64
#  435  vsurf_HB6       float64
#  436  vsurf_HB7       float64
#  437  vsurf_HB8       float64
#  438  vsurf_HL1       float64
#  439  vsurf_HL2       float64
#  440  vsurf_ID1       float64
#  441  vsurf_ID2       float64
#  442  vsurf_ID3       float64
#  443  vsurf_ID4       float64
#  444  vsurf_ID5       float64
#  445  vsurf_ID6       float64
#  446  vsurf_ID7       float64
#  447  vsurf_ID8       float64
#  448  vsurf_IW1       float64
#  449  vsurf_IW2       float64
#  450  vsurf_IW3       float64
#  451  vsurf_IW4       float64
#  452  vsurf_IW5       float64
#  453  vsurf_IW6       float64
#  454  vsurf_IW7       float64
#  455  vsurf_IW8       float64
#  456  vsurf_R         float64
#  457  vsurf_S         float64
#  458  vsurf_V         float64
#  459  vsurf_W1        float64
#  460  vsurf_W2        float64
#  461  vsurf_W3        float64
#  462  vsurf_W4        float64
#  463  vsurf_W5        float64
#  464  vsurf_W6        float64
#  465  vsurf_W7        float64
#  466  vsurf_W8        float64
#  467  vsurf_Wp1       float64
#  468  vsurf_Wp2       float64
#  469  vsurf_Wp3       float64
#  470  vsurf_Wp4       float64
#  471  vsurf_Wp5       float64
#  472  vsurf_Wp6       float64
#  473  vsurf_Wp7       float64
#  474  vsurf_Wp8       float64
#  475  Weight          float64
#  476  weinerPath      int64
#  477  weinerPol       int64
#  478  zagreb          int64
# dtypes: float64(266), int64(213)
# memory usage: 333.2 KB
# None
# ===== COLS WITH NAN VALUES =====
# Log_MP_RATIO    0
# apol            0
# ASA             0
# ASA+            0
# ASA-            0
#                ..
# vsurf_Wp8       0
# Weight          0
# weinerPath      0
# weinerPol       0
# zagreb          0
# Length: 479, dtype: int64
# ===== BASIC DATA OVERVIEW (TEST) =====
# >>> Description
#        Log_MP_RATIO       apol         ASA        ASA+        ASA-  \
# count     22.000000  22.000000   22.000000   22.000000   22.000000
# mean       0.463298  36.260081  481.776489   96.049504  384.798805
# std        0.279653   4.477118   49.611632   45.466567   89.548391
# min       -0.161151  23.658344  341.985020   34.995163   81.638962
# 25%        0.343768  33.840759  455.034967   72.344755  334.419340
# 50%        0.543557  38.380379  503.208875   80.391411  421.346725
# 75%        0.665917  38.380379  511.350437  119.223663  432.979248
# max        1.041625  42.919998  540.454650  260.346040  500.342440
#
#             ASA_H       ASA_P      a_acc  a_acid      a_aro  ...  vsurf_Wp3  \
# count   22.000000   22.000000  22.000000    22.0  22.000000  ...  22.000000
# mean   461.973113   19.803375   0.181818     0.0  11.136364  ...  44.346591
# std    110.366487   71.153459   0.852803     0.0   2.899843  ...  14.672919
# min     61.816746    0.000000   0.000000     0.0   0.000000  ...  17.750000
# 25%    455.034967    0.000000   0.000000     0.0  12.000000  ...  30.812500
# 50%    503.208875    0.000000   0.000000     0.0  12.000000  ...  50.125000
# 75%    511.350437    0.000000   0.000000     0.0  12.000000  ...  54.125000
# max    540.454650  317.939330   4.000000     0.0  12.000000  ...  64.500000
#
#        vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8      Weight  \
# count  22.000000  22.000000  22.000000       22.0       22.0   22.000000
# mean    0.721591   0.244318   0.079545        0.0        0.0  358.877679
# std     3.061117   1.145954   0.373101        0.0        0.0   77.236318
# min     0.000000   0.000000   0.000000        0.0        0.0  180.166990
# 25%     0.000000   0.000000   0.000000        0.0        0.0  291.992000
# 50%     0.000000   0.000000   0.000000        0.0        0.0  395.327000
# 75%     0.000000   0.000000   0.000000        0.0        0.0  395.327000
# max    14.375000   5.375000   1.750000        0.0        0.0  498.661990
#
#        weinerPath  weinerPol      zagreb
# count   22.000000  22.000000   22.000000
# mean   560.045455  31.136364   93.000000
# std    185.800322   7.285311   14.432107
# min    174.000000  21.000000   60.000000
# 25%    422.250000  24.000000   82.000000
# 50%    630.000000  34.000000  100.000000
# 75%    651.500000  35.000000  100.000000
# max    907.000000  46.000000  118.000000
#
# [8 rows x 479 columns]
# >>> Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 479 columns):
#  #    Column          Dtype
# ---   ------          -----
#  0    Log_MP_RATIO    float64
#  1    apol            float64
#  2    ASA             float64
#  3    ASA+            float64
#  4    ASA-            float64
#  5    ASA_H           float64
#  6    ASA_P           float64
#  7    a_acc           int64
#  8    a_acid          int64
#  9    a_aro           int64
#  10   a_base          int64
#  11   a_count         int64
#  12   a_don           int64
#  13   a_donacc        int64
#  14   a_heavy         int64
#  15   a_hyd           int64
#  16   a_IC            float64
#  17   a_ICM           float64
#  18   a_nB            int64
#  19   a_nBr           int64
#  20   a_nC            int64
#  21   a_nCl           int64
#  22   a_nF            int64
#  23   a_nH            int64
#  24   a_nI            int64
#  25   a_nN            int64
#  26   a_nO            int64
#  27   a_nP            int64
#  28   a_nS            int64
#  29   balabanJ        float64
#  30   BCUT_PEOE_0     float64
#  31   BCUT_PEOE_1     float64
#  32   BCUT_PEOE_2     float64
#  33   BCUT_PEOE_3     float64
#  34   BCUT_SLOGP_0    float64
#  35   BCUT_SLOGP_1    float64
#  36   BCUT_SLOGP_2    float64
#  37   BCUT_SLOGP_3    float64
#  38   BCUT_SMR_0      float64
#  39   BCUT_SMR_1      float64
#  40   BCUT_SMR_2      float64
#  41   BCUT_SMR_3      float64
#  42   bpol            float64
#  43   b_1rotN         int64
#  44   b_1rotR         float64
#  45   b_ar            int64
#  46   b_count         int64
#  47   b_double        int64
#  48   b_heavy         int64
#  49   b_max1len       int64
#  50   b_rotN          int64
#  51   b_rotR          float64
#  52   b_single        int64
#  53   b_triple        int64
#  54   CASA+           float64
#  55   CASA-           float64
#  56   chi0            float64
#  57   chi0v           float64
#  58   chi0v_C         float64
#  59   chi0_C          float64
#  60   chi1            float64
#  61   chi1v           float64
#  62   chi1v_C         float64
#  63   chi1_C          float64
#  64   chiral          int64
#  65   chiral_u        int64
#  66   DASA            float64
#  67   DCASA           float64
#  68   density         float64
#  69   diameter        int64
#  70   dipole          float64
#  71   E               float64
#  72   E_ang           float64
#  73   E_ele           float64
#  74   E_nb            float64
#  75   E_oop           float64
#  76   E_sol           float64
#  77   E_stb           int64
#  78   E_str           float64
#  79   E_strain        float64
#  80   E_tor           float64
#  81   E_vdw           float64
#  82   FASA+           float64
#  83   FASA-           float64
#  84   FASA_H          float64
#  85   FASA_P          float64
#  86   FCASA+          float64
#  87   FCASA-          float64
#  88   FCharge         int64
#  89   GCUT_PEOE_0     float64
#  90   GCUT_PEOE_1     float64
#  91   GCUT_PEOE_2     float64
#  92   GCUT_PEOE_3     float64
#  93   GCUT_SLOGP_0    float64
#  94   GCUT_SLOGP_1    float64
#  95   GCUT_SLOGP_2    float64
#  96   GCUT_SLOGP_3    float64
#  97   GCUT_SMR_0      float64
#  98   GCUT_SMR_1      float64
#  99   GCUT_SMR_2      float64
#  100  GCUT_SMR_3      float64
#  101  glob            float64
#  102  h_ema           float64
#  103  h_emd           float64
#  104  h_emd_C         float64
#  105  h_logD          float64
#  106  h_logP          float64
#  107  h_logS          float64
#  108  h_log_dbo       int64
#  109  h_log_pbo       float64
#  110  h_mr            float64
#  111  h_pavgQ         float64
#  112  h_pKa           float64
#  113  h_pKb           float64
#  114  h_pstates       float64
#  115  h_pstrain       float64
#  116  Kier1           float64
#  117  Kier2           float64
#  118  Kier3           float64
#  119  KierA1          float64
#  120  KierA2          float64
#  121  KierA3          float64
#  122  KierFlex        float64
#  123  logP(o/w)       float64
#  124  logS            float64
#  125  MACCS(--1)      int64
#  126  MACCS(--2)      int64
#  127  MACCS(--3)      int64
#  128  MACCS(--4)      int64
#  129  MACCS(--5)      int64
#  130  MACCS(--6)      int64
#  131  MACCS(--7)      int64
#  132  MACCS(--8)      int64
#  133  MACCS(--9)      int64
#  134  MACCS(-10)      int64
#  135  MACCS(-11)      int64
#  136  MACCS(-12)      int64
#  137  MACCS(-13)      int64
#  138  MACCS(-14)      int64
#  139  MACCS(-15)      int64
#  140  MACCS(-16)      int64
#  141  MACCS(-17)      int64
#  142  MACCS(-18)      int64
#  143  MACCS(-19)      int64
#  144  MACCS(-20)      int64
#  145  MACCS(-21)      int64
#  146  MACCS(-22)      int64
#  147  MACCS(-23)      int64
#  148  MACCS(-24)      int64
#  149  MACCS(-25)      int64
#  150  MACCS(-26)      int64
#  151  MACCS(-27)      int64
#  152  MACCS(-28)      int64
#  153  MACCS(-29)      int64
#  154  MACCS(-30)      int64
#  155  MACCS(-31)      int64
#  156  MACCS(-32)      int64
#  157  MACCS(-33)      int64
#  158  MACCS(-34)      int64
#  159  MACCS(-35)      int64
#  160  MACCS(-36)      int64
#  161  MACCS(-37)      int64
#  162  MACCS(-38)      int64
#  163  MACCS(-39)      int64
#  164  MACCS(-40)      int64
#  165  MACCS(-41)      int64
#  166  MACCS(-42)      int64
#  167  MACCS(-43)      int64
#  168  MACCS(-44)      int64
#  169  MACCS(-45)      int64
#  170  MACCS(-46)      int64
#  171  MACCS(-47)      int64
#  172  MACCS(-48)      int64
#  173  MACCS(-49)      int64
#  174  MACCS(-50)      int64
#  175  MACCS(-51)      int64
#  176  MACCS(-52)      int64
#  177  MACCS(-53)      int64
#  178  MACCS(-54)      int64
#  179  MACCS(-55)      int64
#  180  MACCS(-56)      int64
#  181  MACCS(-57)      int64
#  182  MACCS(-58)      int64
#  183  MACCS(-59)      int64
#  184  MACCS(-60)      int64
#  185  MACCS(-61)      int64
#  186  MACCS(-62)      int64
#  187  MACCS(-63)      int64
#  188  MACCS(-64)      int64
#  189  MACCS(-65)      int64
#  190  MACCS(-66)      int64
#  191  MACCS(-67)      int64
#  192  MACCS(-68)      int64
#  193  MACCS(-69)      int64
#  194  MACCS(-70)      int64
#  195  MACCS(-71)      int64
#  196  MACCS(-72)      int64
#  197  MACCS(-73)      int64
#  198  MACCS(-74)      int64
#  199  MACCS(-75)      int64
#  200  MACCS(-76)      int64
#  201  MACCS(-77)      int64
#  202  MACCS(-78)      int64
#  203  MACCS(-79)      int64
#  204  MACCS(-80)      int64
#  205  MACCS(-81)      int64
#  206  MACCS(-82)      int64
#  207  MACCS(-83)      int64
#  208  MACCS(-84)      int64
#  209  MACCS(-85)      int64
#  210  MACCS(-86)      int64
#  211  MACCS(-87)      int64
#  212  MACCS(-88)      int64
#  213  MACCS(-89)      int64
#  214  MACCS(-90)      int64
#  215  MACCS(-91)      int64
#  216  MACCS(-92)      int64
#  217  MACCS(-93)      int64
#  218  MACCS(-94)      int64
#  219  MACCS(-95)      int64
#  220  MACCS(-96)      int64
#  221  MACCS(-97)      int64
#  222  MACCS(-98)      int64
#  223  MACCS(-99)      int64
#  224  MACCS(100)      int64
#  225  MACCS(101)      int64
#  226  MACCS(102)      int64
#  227  MACCS(103)      int64
#  228  MACCS(104)      int64
#  229  MACCS(105)      int64
#  230  MACCS(106)      int64
#  231  MACCS(107)      int64
#  232  MACCS(108)      int64
#  233  MACCS(109)      int64
#  234  MACCS(110)      int64
#  235  MACCS(111)      int64
#  236  MACCS(112)      int64
#  237  MACCS(113)      int64
#  238  MACCS(114)      int64
#  239  MACCS(115)      int64
#  240  MACCS(116)      int64
#  241  MACCS(117)      int64
#  242  MACCS(118)      int64
#  243  MACCS(119)      int64
#  244  MACCS(120)      int64
#  245  MACCS(121)      int64
#  246  MACCS(122)      int64
#  247  MACCS(123)      int64
#  248  MACCS(124)      int64
#  249  MACCS(125)      int64
#  250  MACCS(126)      int64
#  251  MACCS(127)      int64
#  252  MACCS(128)      int64
#  253  MACCS(129)      int64
#  254  MACCS(130)      int64
#  255  MACCS(131)      int64
#  256  MACCS(132)      int64
#  257  MACCS(133)      int64
#  258  MACCS(134)      int64
#  259  MACCS(135)      int64
#  260  MACCS(136)      int64
#  261  MACCS(137)      int64
#  262  MACCS(138)      int64
#  263  MACCS(139)      int64
#  264  MACCS(140)      int64
#  265  MACCS(141)      int64
#  266  MACCS(142)      int64
#  267  MACCS(143)      int64
#  268  MACCS(144)      int64
#  269  MACCS(145)      int64
#  270  MACCS(146)      int64
#  271  MACCS(147)      int64
#  272  MACCS(148)      int64
#  273  MACCS(149)      int64
#  274  MACCS(150)      int64
#  275  MACCS(151)      int64
#  276  MACCS(152)      int64
#  277  MACCS(153)      int64
#  278  MACCS(154)      int64
#  279  MACCS(155)      int64
#  280  MACCS(156)      int64
#  281  MACCS(157)      int64
#  282  MACCS(158)      int64
#  283  MACCS(159)      int64
#  284  MACCS(160)      int64
#  285  MACCS(161)      int64
#  286  MACCS(162)      int64
#  287  MACCS(163)      int64
#  288  MACCS(164)      int64
#  289  MACCS(165)      int64
#  290  MACCS(166)      int64
#  291  mr              float64
#  292  mutagenic       int64
#  293  nmol            int64
#  294  npr1            float64
#  295  npr2            float64
#  296  opr_brigid      int64
#  297  opr_leadlike    int64
#  298  opr_nring       int64
#  299  opr_nrot        int64
#  300  opr_violation   int64
#  301  PC+             float64
#  302  PC-             float64
#  303  PEOE_PC+        float64
#  304  PEOE_PC-        float64
#  305  PEOE_RPC+       float64
#  306  PEOE_RPC-       float64
#  307  PEOE_VSA+0      float64
#  308  PEOE_VSA+1      float64
#  309  PEOE_VSA+2      float64
#  310  PEOE_VSA+3      float64
#  311  PEOE_VSA+4      int64
#  312  PEOE_VSA+5      float64
#  313  PEOE_VSA+6      float64
#  314  PEOE_VSA-0      float64
#  315  PEOE_VSA-1      float64
#  316  PEOE_VSA-2      float64
#  317  PEOE_VSA-3      int64
#  318  PEOE_VSA-4      float64
#  319  PEOE_VSA-5      float64
#  320  PEOE_VSA-6      float64
#  321  PEOE_VSA_FHYD   float64
#  322  PEOE_VSA_FNEG   float64
#  323  PEOE_VSA_FPNEG  float64
#  324  PEOE_VSA_FPOL   float64
#  325  PEOE_VSA_FPOS   float64
#  326  PEOE_VSA_FPPOS  float64
#  327  PEOE_VSA_HYD    float64
#  328  PEOE_VSA_NEG    float64
#  329  PEOE_VSA_PNEG   float64
#  330  PEOE_VSA_POL    float64
#  331  PEOE_VSA_POS    float64
#  332  PEOE_VSA_PPOS   float64
#  333  petitjean       float64
#  334  petitjeanSC     float64
#  335  pmi             float64
#  336  pmi1            float64
#  337  pmi2            float64
#  338  pmi3            float64
#  339  Q_PC+           float64
#  340  Q_PC-           float64
#  341  Q_RPC+          float64
#  342  Q_RPC-          float64
#  343  Q_VSA_FHYD      float64
#  344  Q_VSA_FNEG      float64
#  345  Q_VSA_FPNEG     float64
#  346  Q_VSA_FPOL      float64
#  347  Q_VSA_FPOS      float64
#  348  Q_VSA_FPPOS     float64
#  349  Q_VSA_HYD       float64
#  350  Q_VSA_NEG       float64
#  351  Q_VSA_PNEG      float64
#  352  Q_VSA_POL       float64
#  353  Q_VSA_POS       float64
#  354  Q_VSA_PPOS      float64
#  355  radius          int64
#  356  reactive        int64
#  357  rgyr            float64
#  358  rings           int64
#  359  RPC+            float64
#  360  RPC-            float64
#  361  rsynth          float64
#  362  SlogP           float64
#  363  SlogP_VSA0      float64
#  364  SlogP_VSA1      float64
#  365  SlogP_VSA2      float64
#  366  SlogP_VSA3      int64
#  367  SlogP_VSA4      float64
#  368  SlogP_VSA5      float64
#  369  SlogP_VSA6      float64
#  370  SlogP_VSA7      float64
#  371  SlogP_VSA8      int64
#  372  SlogP_VSA9      float64
#  373  SMR             float64
#  374  SMR_VSA0        float64
#  375  SMR_VSA1        float64
#  376  SMR_VSA2        float64
#  377  SMR_VSA3        float64
#  378  SMR_VSA4        float64
#  379  SMR_VSA5        float64
#  380  SMR_VSA6        float64
#  381  SMR_VSA7        float64
#  382  std_dim1        float64
#  383  std_dim2        float64
#  384  std_dim3        float64
#  385  TPSA            float64
#  386  VAdjEq          float64
#  387  VAdjMa          float64
#  388  VDistEq         float64
#  389  VDistMa         float64
#  390  vdw_area        float64
#  391  vdw_vol         float64
#  392  vol             float64
#  393  VSA             float64
#  394  vsa_acc         float64
#  395  vsa_acid        int64
#  396  vsa_base        int64
#  397  vsa_don         int64
#  398  vsa_hyd         float64
#  399  vsa_other       float64
#  400  vsa_pol         float64
#  401  vsurf_CW1       float64
#  402  vsurf_CW2       float64
#  403  vsurf_CW3       float64
#  404  vsurf_CW4       float64
#  405  vsurf_CW5       float64
#  406  vsurf_CW6       float64
#  407  vsurf_CW7       float64
#  408  vsurf_CW8       float64
#  409  vsurf_D1        float64
#  410  vsurf_D2        float64
#  411  vsurf_D3        float64
#  412  vsurf_D4        float64
#  413  vsurf_D5        float64
#  414  vsurf_D6        float64
#  415  vsurf_D7        float64
#  416  vsurf_D8        float64
#  417  vsurf_DD12      float64
#  418  vsurf_DD13      float64
#  419  vsurf_DD23      float64
#  420  vsurf_DW12      float64
#  421  vsurf_DW13      float64
#  422  vsurf_DW23      float64
#  423  vsurf_EDmin1    float64
#  424  vsurf_EDmin2    float64
#  425  vsurf_EDmin3    float64
#  426  vsurf_EWmin1    float64
#  427  vsurf_EWmin2    float64
#  428  vsurf_EWmin3    float64
#  429  vsurf_G         float64
#  430  vsurf_HB1       float64
#  431  vsurf_HB2       float64
#  432  vsurf_HB3       float64
#  433  vsurf_HB4       float64
#  434  vsurf_HB5       float64
#  435  vsurf_HB6       float64
#  436  vsurf_HB7       float64
#  437  vsurf_HB8       float64
#  438  vsurf_HL1       float64
#  439  vsurf_HL2       float64
#  440  vsurf_ID1       float64
#  441  vsurf_ID2       float64
#  442  vsurf_ID3       float64
#  443  vsurf_ID4       float64
#  444  vsurf_ID5       float64
#  445  vsurf_ID6       float64
#  446  vsurf_ID7       float64
#  447  vsurf_ID8       float64
#  448  vsurf_IW1       float64
#  449  vsurf_IW2       float64
#  450  vsurf_IW3       float64
#  451  vsurf_IW4       float64
#  452  vsurf_IW5       float64
#  453  vsurf_IW6       float64
#  454  vsurf_IW7       float64
#  455  vsurf_IW8       float64
#  456  vsurf_R         float64
#  457  vsurf_S         float64
#  458  vsurf_V         float64
#  459  vsurf_W1        float64
#  460  vsurf_W2        float64
#  461  vsurf_W3        float64
#  462  vsurf_W4        float64
#  463  vsurf_W5        float64
#  464  vsurf_W6        int64
#  465  vsurf_W7        float64
#  466  vsurf_W8        float64
#  467  vsurf_Wp1       float64
#  468  vsurf_Wp2       float64
#  469  vsurf_Wp3       float64
#  470  vsurf_Wp4       float64
#  471  vsurf_Wp5       float64
#  472  vsurf_Wp6       float64
#  473  vsurf_Wp7       int64
#  474  vsurf_Wp8       int64
#  475  Weight          float64
#  476  weinerPath      int64
#  477  weinerPol       int64
#  478  zagreb          int64
# dtypes: float64(255), int64(224)
# memory usage: 82.5 KB
# None
# ===== COLS WITH NAN VALUES =====
# Log_MP_RATIO    0
# apol            0
# ASA             0
# ASA+            0
# ASA-            0
#                ..
# vsurf_Wp8       0
# Weight          0
# weinerPath      0
# weinerPol       0
# zagreb          0
# Length: 479, dtype: int64

# %% [markdown]
# ## Full

# %% [markdown]
# ### Values and missing values

# %%
print("===== BASIC DATA OVERVIEW (TRAIN) =====")
print(">>> Description")
display(df_full_train.describe())
print(">>> Info")
display(df_full_train.info(verbose=True))
print("===== COLS WITH NAN VALUES =====")
display(df_full_train.isna().sum())

print("===== BASIC DATA OVERVIEW (TEST) =====")
print(">>> Description")
display(df_full_test.describe())
print(">>> Info")
display(df_full_test.info(verbose=True))
print("===== COLS WITH NAN VALUES =====")
display(df_full_test.isna().sum())
# Out:
# ===== BASIC DATA OVERVIEW (TRAIN) =====
# >>> Description
#        Log_MP_RATIO        apol          ASA        ASA+        ASA-  \
# count    146.000000  146.000000   146.000000  146.000000  146.000000
# mean      -0.037626   44.713290   523.422960  278.826194  242.218148
# std        0.670619   15.944047   118.856771  143.077179  118.670391
# min       -2.259637    8.322758   197.574580    0.000000   64.410759
# 25%       -0.425336   35.761043   466.609140  182.358847  157.780025
# 50%       -0.013251   42.889172   510.104235  273.280885  208.773565
# 75%        0.470817   51.779402   579.544525  378.712695  306.548475
# max        1.311038  126.062750  1094.164700  794.894100  625.281980
#
#             ASA_H       ASA_P       a_acc      a_acid       a_aro  ...  \
# count  146.000000  146.000000  146.000000  146.000000  146.000000  ...
# mean   387.070649  136.352312    1.972603    0.397260    8.349315  ...
# std    140.067772  109.051699    2.139756    0.890404    4.401555  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%    300.612572   65.432325    0.000000    0.000000    6.000000  ...
# 50%    403.971465  119.773765    2.000000    0.000000    9.500000  ...
# 75%    479.892145  186.266363    3.000000    0.000000   12.000000  ...
# max    725.847960  498.010990   13.000000    4.000000   17.000000  ...
#
#         vsurf_Wp3   vsurf_Wp4   vsurf_Wp5   vsurf_Wp6   vsurf_Wp7   vsurf_Wp8  \
# count  146.000000  146.000000  146.000000  146.000000  146.000000  146.000000
# mean    85.479452   17.716610    6.605308    1.693493    0.108733    0.008562
# std     51.077331   18.726855    7.361226    2.231296    0.426560    0.103451
# min      0.250000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     47.468750    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%     79.625000   14.625000    4.875000    1.000000    0.000000    0.000000
# 75%    110.187500   30.218750   11.000000    2.250000    0.000000    0.000000
# max    262.750000   72.375000   28.875000   11.125000    4.625000    1.250000
#
#            Weight    weinerPath   weinerPol      zagreb
# count  146.000000    146.000000  146.000000  146.000000
# mean   339.363061   1168.938356   34.226027  108.273973
# std    138.945211   1590.612678   16.678613   41.149437
# min     46.069000      4.000000    0.000000    6.000000
# 25%    256.142260    528.500000   24.250000   86.000000
# 50%    314.666505    734.000000   31.000000  102.000000
# 75%    394.292995   1276.750000   41.750000  128.000000
# max    959.170960  14940.000000  113.000000  320.000000
#
# [8 rows x 479 columns]
# >>> Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 479 columns):
#  #    Column          Dtype
# ---   ------          -----
#  0    Log_MP_RATIO    float64
#  1    apol            float64
#  2    ASA             float64
#  3    ASA+            float64
#  4    ASA-            float64
#  5    ASA_H           float64
#  6    ASA_P           float64
#  7    a_acc           int64
#  8    a_acid          int64
#  9    a_aro           int64
#  10   a_base          int64
#  11   a_count         int64
#  12   a_don           int64
#  13   a_donacc        int64
#  14   a_heavy         int64
#  15   a_hyd           int64
#  16   a_IC            float64
#  17   a_ICM           float64
#  18   a_nB            int64
#  19   a_nBr           int64
#  20   a_nC            int64
#  21   a_nCl           int64
#  22   a_nF            int64
#  23   a_nH            int64
#  24   a_nI            int64
#  25   a_nN            int64
#  26   a_nO            int64
#  27   a_nP            int64
#  28   a_nS            int64
#  29   balabanJ        float64
#  30   BCUT_PEOE_0     float64
#  31   BCUT_PEOE_1     float64
#  32   BCUT_PEOE_2     float64
#  33   BCUT_PEOE_3     float64
#  34   BCUT_SLOGP_0    float64
#  35   BCUT_SLOGP_1    float64
#  36   BCUT_SLOGP_2    float64
#  37   BCUT_SLOGP_3    float64
#  38   BCUT_SMR_0      float64
#  39   BCUT_SMR_1      float64
#  40   BCUT_SMR_2      float64
#  41   BCUT_SMR_3      float64
#  42   bpol            float64
#  43   b_1rotN         int64
#  44   b_1rotR         float64
#  45   b_ar            int64
#  46   b_count         int64
#  47   b_double        int64
#  48   b_heavy         int64
#  49   b_max1len       int64
#  50   b_rotN          int64
#  51   b_rotR          float64
#  52   b_single        int64
#  53   b_triple        int64
#  54   CASA+           float64
#  55   CASA-           float64
#  56   chi0            float64
#  57   chi0v           float64
#  58   chi0v_C         float64
#  59   chi0_C          float64
#  60   chi1            float64
#  61   chi1v           float64
#  62   chi1v_C         float64
#  63   chi1_C          float64
#  64   chiral          int64
#  65   chiral_u        int64
#  66   DASA            float64
#  67   DCASA           float64
#  68   density         float64
#  69   diameter        int64
#  70   dipole          float64
#  71   E               float64
#  72   E_ang           float64
#  73   E_ele           float64
#  74   E_nb            float64
#  75   E_oop           float64
#  76   E_sol           float64
#  77   E_stb           int64
#  78   E_str           float64
#  79   E_strain        float64
#  80   E_tor           float64
#  81   E_vdw           float64
#  82   FASA+           float64
#  83   FASA-           float64
#  84   FASA_H          float64
#  85   FASA_P          float64
#  86   FCASA+          float64
#  87   FCASA-          float64
#  88   FCharge         int64
#  89   GCUT_PEOE_0     float64
#  90   GCUT_PEOE_1     float64
#  91   GCUT_PEOE_2     float64
#  92   GCUT_PEOE_3     float64
#  93   GCUT_SLOGP_0    float64
#  94   GCUT_SLOGP_1    float64
#  95   GCUT_SLOGP_2    float64
#  96   GCUT_SLOGP_3    float64
#  97   GCUT_SMR_0      float64
#  98   GCUT_SMR_1      float64
#  99   GCUT_SMR_2      float64
#  100  GCUT_SMR_3      float64
#  101  glob            float64
#  102  h_ema           float64
#  103  h_emd           float64
#  104  h_emd_C         float64
#  105  h_logD          float64
#  106  h_logP          float64
#  107  h_logS          float64
#  108  h_log_dbo       float64
#  109  h_log_pbo       float64
#  110  h_mr            float64
#  111  h_pavgQ         float64
#  112  h_pKa           float64
#  113  h_pKb           float64
#  114  h_pstates       float64
#  115  h_pstrain       float64
#  116  Kier1           float64
#  117  Kier2           float64
#  118  Kier3           float64
#  119  KierA1          float64
#  120  KierA2          float64
#  121  KierA3          float64
#  122  KierFlex        float64
#  123  logP(o/w)       float64
#  124  logS            float64
#  125  MACCS(--1)      int64
#  126  MACCS(--2)      int64
#  127  MACCS(--3)      int64
#  128  MACCS(--4)      int64
#  129  MACCS(--5)      int64
#  130  MACCS(--6)      int64
#  131  MACCS(--7)      int64
#  132  MACCS(--8)      int64
#  133  MACCS(--9)      int64
#  134  MACCS(-10)      int64
#  135  MACCS(-11)      int64
#  136  MACCS(-12)      int64
#  137  MACCS(-13)      int64
#  138  MACCS(-14)      int64
#  139  MACCS(-15)      int64
#  140  MACCS(-16)      int64
#  141  MACCS(-17)      int64
#  142  MACCS(-18)      int64
#  143  MACCS(-19)      int64
#  144  MACCS(-20)      int64
#  145  MACCS(-21)      int64
#  146  MACCS(-22)      int64
#  147  MACCS(-23)      int64
#  148  MACCS(-24)      int64
#  149  MACCS(-25)      int64
#  150  MACCS(-26)      int64
#  151  MACCS(-27)      int64
#  152  MACCS(-28)      int64
#  153  MACCS(-29)      int64
#  154  MACCS(-30)      int64
#  155  MACCS(-31)      int64
#  156  MACCS(-32)      int64
#  157  MACCS(-33)      int64
#  158  MACCS(-34)      int64
#  159  MACCS(-35)      int64
#  160  MACCS(-36)      int64
#  161  MACCS(-37)      int64
#  162  MACCS(-38)      int64
#  163  MACCS(-39)      int64
#  164  MACCS(-40)      int64
#  165  MACCS(-41)      int64
#  166  MACCS(-42)      int64
#  167  MACCS(-43)      int64
#  168  MACCS(-44)      int64
#  169  MACCS(-45)      int64
#  170  MACCS(-46)      int64
#  171  MACCS(-47)      int64
#  172  MACCS(-48)      int64
#  173  MACCS(-49)      int64
#  174  MACCS(-50)      int64
#  175  MACCS(-51)      int64
#  176  MACCS(-52)      int64
#  177  MACCS(-53)      int64
#  178  MACCS(-54)      int64
#  179  MACCS(-55)      int64
#  180  MACCS(-56)      int64
#  181  MACCS(-57)      int64
#  182  MACCS(-58)      int64
#  183  MACCS(-59)      int64
#  184  MACCS(-60)      int64
#  185  MACCS(-61)      int64
#  186  MACCS(-62)      int64
#  187  MACCS(-63)      int64
#  188  MACCS(-64)      int64
#  189  MACCS(-65)      int64
#  190  MACCS(-66)      int64
#  191  MACCS(-67)      int64
#  192  MACCS(-68)      int64
#  193  MACCS(-69)      int64
#  194  MACCS(-70)      int64
#  195  MACCS(-71)      int64
#  196  MACCS(-72)      int64
#  197  MACCS(-73)      int64
#  198  MACCS(-74)      int64
#  199  MACCS(-75)      int64
#  200  MACCS(-76)      int64
#  201  MACCS(-77)      int64
#  202  MACCS(-78)      int64
#  203  MACCS(-79)      int64
#  204  MACCS(-80)      int64
#  205  MACCS(-81)      int64
#  206  MACCS(-82)      int64
#  207  MACCS(-83)      int64
#  208  MACCS(-84)      int64
#  209  MACCS(-85)      int64
#  210  MACCS(-86)      int64
#  211  MACCS(-87)      int64
#  212  MACCS(-88)      int64
#  213  MACCS(-89)      int64
#  214  MACCS(-90)      int64
#  215  MACCS(-91)      int64
#  216  MACCS(-92)      int64
#  217  MACCS(-93)      int64
#  218  MACCS(-94)      int64
#  219  MACCS(-95)      int64
#  220  MACCS(-96)      int64
#  221  MACCS(-97)      int64
#  222  MACCS(-98)      int64
#  223  MACCS(-99)      int64
#  224  MACCS(100)      int64
#  225  MACCS(101)      int64
#  226  MACCS(102)      int64
#  227  MACCS(103)      int64
#  228  MACCS(104)      int64
#  229  MACCS(105)      int64
#  230  MACCS(106)      int64
#  231  MACCS(107)      int64
#  232  MACCS(108)      int64
#  233  MACCS(109)      int64
#  234  MACCS(110)      int64
#  235  MACCS(111)      int64
#  236  MACCS(112)      int64
#  237  MACCS(113)      int64
#  238  MACCS(114)      int64
#  239  MACCS(115)      int64
#  240  MACCS(116)      int64
#  241  MACCS(117)      int64
#  242  MACCS(118)      int64
#  243  MACCS(119)      int64
#  244  MACCS(120)      int64
#  245  MACCS(121)      int64
#  246  MACCS(122)      int64
#  247  MACCS(123)      int64
#  248  MACCS(124)      int64
#  249  MACCS(125)      int64
#  250  MACCS(126)      int64
#  251  MACCS(127)      int64
#  252  MACCS(128)      int64
#  253  MACCS(129)      int64
#  254  MACCS(130)      int64
#  255  MACCS(131)      int64
#  256  MACCS(132)      int64
#  257  MACCS(133)      int64
#  258  MACCS(134)      int64
#  259  MACCS(135)      int64
#  260  MACCS(136)      int64
#  261  MACCS(137)      int64
#  262  MACCS(138)      int64
#  263  MACCS(139)      int64
#  264  MACCS(140)      int64
#  265  MACCS(141)      int64
#  266  MACCS(142)      int64
#  267  MACCS(143)      int64
#  268  MACCS(144)      int64
#  269  MACCS(145)      int64
#  270  MACCS(146)      int64
#  271  MACCS(147)      int64
#  272  MACCS(148)      int64
#  273  MACCS(149)      int64
#  274  MACCS(150)      int64
#  275  MACCS(151)      int64
#  276  MACCS(152)      int64
#  277  MACCS(153)      int64
#  278  MACCS(154)      int64
#  279  MACCS(155)      int64
#  280  MACCS(156)      int64
#  281  MACCS(157)      int64
#  282  MACCS(158)      int64
#  283  MACCS(159)      int64
#  284  MACCS(160)      int64
#  285  MACCS(161)      int64
#  286  MACCS(162)      int64
#  287  MACCS(163)      int64
#  288  MACCS(164)      int64
#  289  MACCS(165)      int64
#  290  MACCS(166)      int64
#  291  mr              float64
#  292  mutagenic       int64
#  293  nmol            int64
#  294  npr1            float64
#  295  npr2            float64
#  296  opr_brigid      int64
#  297  opr_leadlike    int64
#  298  opr_nring       int64
#  299  opr_nrot        int64
#  300  opr_violation   int64
#  301  PC+             float64
#  302  PC-             float64
#  303  PEOE_PC+        float64
#  304  PEOE_PC-        float64
#  305  PEOE_RPC+       float64
#  306  PEOE_RPC-       float64
#  307  PEOE_VSA+0      float64
#  308  PEOE_VSA+1      float64
#  309  PEOE_VSA+2      float64
#  310  PEOE_VSA+3      float64
#  311  PEOE_VSA+4      float64
#  312  PEOE_VSA+5      float64
#  313  PEOE_VSA+6      float64
#  314  PEOE_VSA-0      float64
#  315  PEOE_VSA-1      float64
#  316  PEOE_VSA-2      float64
#  317  PEOE_VSA-3      float64
#  318  PEOE_VSA-4      float64
#  319  PEOE_VSA-5      float64
#  320  PEOE_VSA-6      float64
#  321  PEOE_VSA_FHYD   float64
#  322  PEOE_VSA_FNEG   float64
#  323  PEOE_VSA_FPNEG  float64
#  324  PEOE_VSA_FPOL   float64
#  325  PEOE_VSA_FPOS   float64
#  326  PEOE_VSA_FPPOS  float64
#  327  PEOE_VSA_HYD    float64
#  328  PEOE_VSA_NEG    float64
#  329  PEOE_VSA_PNEG   float64
#  330  PEOE_VSA_POL    float64
#  331  PEOE_VSA_POS    float64
#  332  PEOE_VSA_PPOS   float64
#  333  petitjean       float64
#  334  petitjeanSC     float64
#  335  pmi             float64
#  336  pmi1            float64
#  337  pmi2            float64
#  338  pmi3            float64
#  339  Q_PC+           float64
#  340  Q_PC-           float64
#  341  Q_RPC+          float64
#  342  Q_RPC-          float64
#  343  Q_VSA_FHYD      float64
#  344  Q_VSA_FNEG      float64
#  345  Q_VSA_FPNEG     float64
#  346  Q_VSA_FPOL      float64
#  347  Q_VSA_FPOS      float64
#  348  Q_VSA_FPPOS     float64
#  349  Q_VSA_HYD       float64
#  350  Q_VSA_NEG       float64
#  351  Q_VSA_PNEG      float64
#  352  Q_VSA_POL       float64
#  353  Q_VSA_POS       float64
#  354  Q_VSA_PPOS      float64
#  355  radius          int64
#  356  reactive        int64
#  357  rgyr            float64
#  358  rings           int64
#  359  RPC+            float64
#  360  RPC-            float64
#  361  rsynth          float64
#  362  SlogP           float64
#  363  SlogP_VSA0      float64
#  364  SlogP_VSA1      float64
#  365  SlogP_VSA2      float64
#  366  SlogP_VSA3      float64
#  367  SlogP_VSA4      float64
#  368  SlogP_VSA5      float64
#  369  SlogP_VSA6      float64
#  370  SlogP_VSA7      float64
#  371  SlogP_VSA8      float64
#  372  SlogP_VSA9      float64
#  373  SMR             float64
#  374  SMR_VSA0        float64
#  375  SMR_VSA1        float64
#  376  SMR_VSA2        float64
#  377  SMR_VSA3        float64
#  378  SMR_VSA4        float64
#  379  SMR_VSA5        float64
#  380  SMR_VSA6        float64
#  381  SMR_VSA7        float64
#  382  std_dim1        float64
#  383  std_dim2        float64
#  384  std_dim3        float64
#  385  TPSA            float64
#  386  VAdjEq          float64
#  387  VAdjMa          float64
#  388  VDistEq         float64
#  389  VDistMa         float64
#  390  vdw_area        float64
#  391  vdw_vol         float64
#  392  vol             float64
#  393  VSA             float64
#  394  vsa_acc         float64
#  395  vsa_acid        float64
#  396  vsa_base        float64
#  397  vsa_don         float64
#  398  vsa_hyd         float64
#  399  vsa_other       float64
#  400  vsa_pol         float64
#  401  vsurf_CW1       float64
#  402  vsurf_CW2       float64
#  403  vsurf_CW3       float64
#  404  vsurf_CW4       float64
#  405  vsurf_CW5       float64
#  406  vsurf_CW6       float64
#  407  vsurf_CW7       float64
#  408  vsurf_CW8       float64
#  409  vsurf_D1        float64
#  410  vsurf_D2        float64
#  411  vsurf_D3        float64
#  412  vsurf_D4        float64
#  413  vsurf_D5        float64
#  414  vsurf_D6        float64
#  415  vsurf_D7        float64
#  416  vsurf_D8        float64
#  417  vsurf_DD12      float64
#  418  vsurf_DD13      float64
#  419  vsurf_DD23      float64
#  420  vsurf_DW12      float64
#  421  vsurf_DW13      float64
#  422  vsurf_DW23      float64
#  423  vsurf_EDmin1    float64
#  424  vsurf_EDmin2    float64
#  425  vsurf_EDmin3    float64
#  426  vsurf_EWmin1    float64
#  427  vsurf_EWmin2    float64
#  428  vsurf_EWmin3    float64
#  429  vsurf_G         float64
#  430  vsurf_HB1       float64
#  431  vsurf_HB2       float64
#  432  vsurf_HB3       float64
#  433  vsurf_HB4       float64
#  434  vsurf_HB5       float64
#  435  vsurf_HB6       float64
#  436  vsurf_HB7       float64
#  437  vsurf_HB8       float64
#  438  vsurf_HL1       float64
#  439  vsurf_HL2       float64
#  440  vsurf_ID1       float64
#  441  vsurf_ID2       float64
#  442  vsurf_ID3       float64
#  443  vsurf_ID4       float64
#  444  vsurf_ID5       float64
#  445  vsurf_ID6       float64
#  446  vsurf_ID7       float64
#  447  vsurf_ID8       float64
#  448  vsurf_IW1       float64
#  449  vsurf_IW2       float64
#  450  vsurf_IW3       float64
#  451  vsurf_IW4       float64
#  452  vsurf_IW5       float64
#  453  vsurf_IW6       float64
#  454  vsurf_IW7       float64
#  455  vsurf_IW8       float64
#  456  vsurf_R         float64
#  457  vsurf_S         float64
#  458  vsurf_V         float64
#  459  vsurf_W1        float64
#  460  vsurf_W2        float64
#  461  vsurf_W3        float64
#  462  vsurf_W4        float64
#  463  vsurf_W5        float64
#  464  vsurf_W6        float64
#  465  vsurf_W7        float64
#  466  vsurf_W8        float64
#  467  vsurf_Wp1       float64
#  468  vsurf_Wp2       float64
#  469  vsurf_Wp3       float64
#  470  vsurf_Wp4       float64
#  471  vsurf_Wp5       float64
#  472  vsurf_Wp6       float64
#  473  vsurf_Wp7       float64
#  474  vsurf_Wp8       float64
#  475  Weight          float64
#  476  weinerPath      int64
#  477  weinerPol       int64
#  478  zagreb          int64
# dtypes: float64(266), int64(213)
# memory usage: 546.5 KB
# None
# ===== COLS WITH NAN VALUES =====
# Log_MP_RATIO    0
# apol            0
# ASA             0
# ASA+            0
# ASA-            0
#                ..
# vsurf_Wp8       0
# Weight          0
# weinerPath      0
# weinerPol       0
# zagreb          0
# Length: 479, dtype: int64
# ===== BASIC DATA OVERVIEW (TEST) =====
# >>> Description
#        Log_MP_RATIO       apol         ASA        ASA+        ASA-  \
# count     37.000000  37.000000   37.000000   37.000000   37.000000
# mean       0.466767  36.743485  485.230563   99.880510  382.949623
# std        0.308726   4.258958   40.495030   50.856481   76.259088
# min       -0.359296  23.658344  341.985020   34.995163   81.638962
# 25%        0.329167  34.822380  468.081730   75.069984  344.058590
# 50%        0.561432  36.867172  497.625700   90.301811  397.337370
# 75%        0.678482  38.380379  509.825560  104.990330  430.366850
# max        1.041625  50.529068  540.454650  313.179630  500.342440
#
#             ASA_H       ASA_P      a_acc  a_acid      a_aro  ...  vsurf_Wp3  \
# count   37.000000   37.000000  37.000000    37.0  37.000000  ...  37.000000
# mean   470.228960   15.001603   0.108108     0.0  11.594595  ...  48.283784
# std     86.244466   56.494545   0.657596     0.0   2.302890  ...  16.284836
# min     61.816746    0.000000   0.000000     0.0   0.000000  ...  17.750000
# 25%    458.915130    0.000000   0.000000     0.0  12.000000  ...  38.125000
# 50%    493.633610    0.000000   0.000000     0.0  12.000000  ...  50.000000
# 75%    507.888730    0.000000   0.000000     0.0  12.000000  ...  54.250000
# max    540.454650  317.939330   4.000000     0.0  13.000000  ...  91.625000
#
#        vsurf_Wp4  vsurf_Wp5  vsurf_Wp6  vsurf_Wp7  vsurf_Wp8      Weight  \
# count  37.000000  37.000000  37.000000       37.0       37.0   37.000000
# mean    0.827703   0.287162   0.070946        0.0        0.0  358.960994
# std     3.335201   1.217945   0.318062        0.0        0.0   65.175265
# min     0.000000   0.000000   0.000000        0.0        0.0  180.166990
# 25%     0.000000   0.000000   0.000000        0.0        0.0  316.876010
# 50%     0.000000   0.000000   0.000000        0.0        0.0  360.881990
# 75%     0.000000   0.000000   0.000000        0.0        0.0  395.327000
# max    14.750000   5.375000   1.750000        0.0        0.0  498.661990
#
#        weinerPath  weinerPol      zagreb
# count   37.000000  37.000000   37.000000
# mean   580.729730  31.756757   95.513514
# std    169.053681   6.909757   13.795373
# min    174.000000  21.000000   60.000000
# 25%    488.000000  27.000000   88.000000
# 50%    580.000000  31.000000   94.000000
# 75%    650.000000  35.000000  106.000000
# max    915.000000  47.000000  124.000000
#
# [8 rows x 479 columns]
# >>> Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 479 columns):
#  #    Column          Dtype
# ---   ------          -----
#  0    Log_MP_RATIO    float64
#  1    apol            float64
#  2    ASA             float64
#  3    ASA+            float64
#  4    ASA-            float64
#  5    ASA_H           float64
#  6    ASA_P           float64
#  7    a_acc           int64
#  8    a_acid          int64
#  9    a_aro           int64
#  10   a_base          int64
#  11   a_count         int64
#  12   a_don           int64
#  13   a_donacc        int64
#  14   a_heavy         int64
#  15   a_hyd           int64
#  16   a_IC            float64
#  17   a_ICM           float64
#  18   a_nB            int64
#  19   a_nBr           int64
#  20   a_nC            int64
#  21   a_nCl           int64
#  22   a_nF            int64
#  23   a_nH            int64
#  24   a_nI            int64
#  25   a_nN            int64
#  26   a_nO            int64
#  27   a_nP            int64
#  28   a_nS            int64
#  29   balabanJ        float64
#  30   BCUT_PEOE_0     float64
#  31   BCUT_PEOE_1     float64
#  32   BCUT_PEOE_2     float64
#  33   BCUT_PEOE_3     float64
#  34   BCUT_SLOGP_0    float64
#  35   BCUT_SLOGP_1    float64
#  36   BCUT_SLOGP_2    float64
#  37   BCUT_SLOGP_3    float64
#  38   BCUT_SMR_0      float64
#  39   BCUT_SMR_1      float64
#  40   BCUT_SMR_2      float64
#  41   BCUT_SMR_3      float64
#  42   bpol            float64
#  43   b_1rotN         int64
#  44   b_1rotR         float64
#  45   b_ar            int64
#  46   b_count         int64
#  47   b_double        int64
#  48   b_heavy         int64
#  49   b_max1len       int64
#  50   b_rotN          int64
#  51   b_rotR          float64
#  52   b_single        int64
#  53   b_triple        int64
#  54   CASA+           float64
#  55   CASA-           float64
#  56   chi0            float64
#  57   chi0v           float64
#  58   chi0v_C         float64
#  59   chi0_C          float64
#  60   chi1            float64
#  61   chi1v           float64
#  62   chi1v_C         float64
#  63   chi1_C          float64
#  64   chiral          int64
#  65   chiral_u        int64
#  66   DASA            float64
#  67   DCASA           float64
#  68   density         float64
#  69   diameter        int64
#  70   dipole          float64
#  71   E               float64
#  72   E_ang           float64
#  73   E_ele           float64
#  74   E_nb            float64
#  75   E_oop           float64
#  76   E_sol           float64
#  77   E_stb           int64
#  78   E_str           float64
#  79   E_strain        float64
#  80   E_tor           float64
#  81   E_vdw           float64
#  82   FASA+           float64
#  83   FASA-           float64
#  84   FASA_H          float64
#  85   FASA_P          float64
#  86   FCASA+          float64
#  87   FCASA-          float64
#  88   FCharge         int64
#  89   GCUT_PEOE_0     float64
#  90   GCUT_PEOE_1     float64
#  91   GCUT_PEOE_2     float64
#  92   GCUT_PEOE_3     float64
#  93   GCUT_SLOGP_0    float64
#  94   GCUT_SLOGP_1    float64
#  95   GCUT_SLOGP_2    float64
#  96   GCUT_SLOGP_3    float64
#  97   GCUT_SMR_0      float64
#  98   GCUT_SMR_1      float64
#  99   GCUT_SMR_2      float64
#  100  GCUT_SMR_3      float64
#  101  glob            float64
#  102  h_ema           float64
#  103  h_emd           float64
#  104  h_emd_C         float64
#  105  h_logD          float64
#  106  h_logP          float64
#  107  h_logS          float64
#  108  h_log_dbo       int64
#  109  h_log_pbo       float64
#  110  h_mr            float64
#  111  h_pavgQ         float64
#  112  h_pKa           float64
#  113  h_pKb           float64
#  114  h_pstates       float64
#  115  h_pstrain       float64
#  116  Kier1           float64
#  117  Kier2           float64
#  118  Kier3           float64
#  119  KierA1          float64
#  120  KierA2          float64
#  121  KierA3          float64
#  122  KierFlex        float64
#  123  logP(o/w)       float64
#  124  logS            float64
#  125  MACCS(--1)      int64
#  126  MACCS(--2)      int64
#  127  MACCS(--3)      int64
#  128  MACCS(--4)      int64
#  129  MACCS(--5)      int64
#  130  MACCS(--6)      int64
#  131  MACCS(--7)      int64
#  132  MACCS(--8)      int64
#  133  MACCS(--9)      int64
#  134  MACCS(-10)      int64
#  135  MACCS(-11)      int64
#  136  MACCS(-12)      int64
#  137  MACCS(-13)      int64
#  138  MACCS(-14)      int64
#  139  MACCS(-15)      int64
#  140  MACCS(-16)      int64
#  141  MACCS(-17)      int64
#  142  MACCS(-18)      int64
#  143  MACCS(-19)      int64
#  144  MACCS(-20)      int64
#  145  MACCS(-21)      int64
#  146  MACCS(-22)      int64
#  147  MACCS(-23)      int64
#  148  MACCS(-24)      int64
#  149  MACCS(-25)      int64
#  150  MACCS(-26)      int64
#  151  MACCS(-27)      int64
#  152  MACCS(-28)      int64
#  153  MACCS(-29)      int64
#  154  MACCS(-30)      int64
#  155  MACCS(-31)      int64
#  156  MACCS(-32)      int64
#  157  MACCS(-33)      int64
#  158  MACCS(-34)      int64
#  159  MACCS(-35)      int64
#  160  MACCS(-36)      int64
#  161  MACCS(-37)      int64
#  162  MACCS(-38)      int64
#  163  MACCS(-39)      int64
#  164  MACCS(-40)      int64
#  165  MACCS(-41)      int64
#  166  MACCS(-42)      int64
#  167  MACCS(-43)      int64
#  168  MACCS(-44)      int64
#  169  MACCS(-45)      int64
#  170  MACCS(-46)      int64
#  171  MACCS(-47)      int64
#  172  MACCS(-48)      int64
#  173  MACCS(-49)      int64
#  174  MACCS(-50)      int64
#  175  MACCS(-51)      int64
#  176  MACCS(-52)      int64
#  177  MACCS(-53)      int64
#  178  MACCS(-54)      int64
#  179  MACCS(-55)      int64
#  180  MACCS(-56)      int64
#  181  MACCS(-57)      int64
#  182  MACCS(-58)      int64
#  183  MACCS(-59)      int64
#  184  MACCS(-60)      int64
#  185  MACCS(-61)      int64
#  186  MACCS(-62)      int64
#  187  MACCS(-63)      int64
#  188  MACCS(-64)      int64
#  189  MACCS(-65)      int64
#  190  MACCS(-66)      int64
#  191  MACCS(-67)      int64
#  192  MACCS(-68)      int64
#  193  MACCS(-69)      int64
#  194  MACCS(-70)      int64
#  195  MACCS(-71)      int64
#  196  MACCS(-72)      int64
#  197  MACCS(-73)      int64
#  198  MACCS(-74)      int64
#  199  MACCS(-75)      int64
#  200  MACCS(-76)      int64
#  201  MACCS(-77)      int64
#  202  MACCS(-78)      int64
#  203  MACCS(-79)      int64
#  204  MACCS(-80)      int64
#  205  MACCS(-81)      int64
#  206  MACCS(-82)      int64
#  207  MACCS(-83)      int64
#  208  MACCS(-84)      int64
#  209  MACCS(-85)      int64
#  210  MACCS(-86)      int64
#  211  MACCS(-87)      int64
#  212  MACCS(-88)      int64
#  213  MACCS(-89)      int64
#  214  MACCS(-90)      int64
#  215  MACCS(-91)      int64
#  216  MACCS(-92)      int64
#  217  MACCS(-93)      int64
#  218  MACCS(-94)      int64
#  219  MACCS(-95)      int64
#  220  MACCS(-96)      int64
#  221  MACCS(-97)      int64
#  222  MACCS(-98)      int64
#  223  MACCS(-99)      int64
#  224  MACCS(100)      int64
#  225  MACCS(101)      int64
#  226  MACCS(102)      int64
#  227  MACCS(103)      int64
#  228  MACCS(104)      int64
#  229  MACCS(105)      int64
#  230  MACCS(106)      int64
#  231  MACCS(107)      int64
#  232  MACCS(108)      int64
#  233  MACCS(109)      int64
#  234  MACCS(110)      int64
#  235  MACCS(111)      int64
#  236  MACCS(112)      int64
#  237  MACCS(113)      int64
#  238  MACCS(114)      int64
#  239  MACCS(115)      int64
#  240  MACCS(116)      int64
#  241  MACCS(117)      int64
#  242  MACCS(118)      int64
#  243  MACCS(119)      int64
#  244  MACCS(120)      int64
#  245  MACCS(121)      int64
#  246  MACCS(122)      int64
#  247  MACCS(123)      int64
#  248  MACCS(124)      int64
#  249  MACCS(125)      int64
#  250  MACCS(126)      int64
#  251  MACCS(127)      int64
#  252  MACCS(128)      int64
#  253  MACCS(129)      int64
#  254  MACCS(130)      int64
#  255  MACCS(131)      int64
#  256  MACCS(132)      int64
#  257  MACCS(133)      int64
#  258  MACCS(134)      int64
#  259  MACCS(135)      int64
#  260  MACCS(136)      int64
#  261  MACCS(137)      int64
#  262  MACCS(138)      int64
#  263  MACCS(139)      int64
#  264  MACCS(140)      int64
#  265  MACCS(141)      int64
#  266  MACCS(142)      int64
#  267  MACCS(143)      int64
#  268  MACCS(144)      int64
#  269  MACCS(145)      int64
#  270  MACCS(146)      int64
#  271  MACCS(147)      int64
#  272  MACCS(148)      int64
#  273  MACCS(149)      int64
#  274  MACCS(150)      int64
#  275  MACCS(151)      int64
#  276  MACCS(152)      int64
#  277  MACCS(153)      int64
#  278  MACCS(154)      int64
#  279  MACCS(155)      int64
#  280  MACCS(156)      int64
#  281  MACCS(157)      int64
#  282  MACCS(158)      int64
#  283  MACCS(159)      int64
#  284  MACCS(160)      int64
#  285  MACCS(161)      int64
#  286  MACCS(162)      int64
#  287  MACCS(163)      int64
#  288  MACCS(164)      int64
#  289  MACCS(165)      int64
#  290  MACCS(166)      int64
#  291  mr              float64
#  292  mutagenic       int64
#  293  nmol            int64
#  294  npr1            float64
#  295  npr2            float64
#  296  opr_brigid      int64
#  297  opr_leadlike    int64
#  298  opr_nring       int64
#  299  opr_nrot        int64
#  300  opr_violation   int64
#  301  PC+             float64
#  302  PC-             float64
#  303  PEOE_PC+        float64
#  304  PEOE_PC-        float64
#  305  PEOE_RPC+       float64
#  306  PEOE_RPC-       float64
#  307  PEOE_VSA+0      float64
#  308  PEOE_VSA+1      float64
#  309  PEOE_VSA+2      float64
#  310  PEOE_VSA+3      float64
#  311  PEOE_VSA+4      int64
#  312  PEOE_VSA+5      float64
#  313  PEOE_VSA+6      float64
#  314  PEOE_VSA-0      float64
#  315  PEOE_VSA-1      float64
#  316  PEOE_VSA-2      float64
#  317  PEOE_VSA-3      int64
#  318  PEOE_VSA-4      float64
#  319  PEOE_VSA-5      float64
#  320  PEOE_VSA-6      float64
#  321  PEOE_VSA_FHYD   float64
#  322  PEOE_VSA_FNEG   float64
#  323  PEOE_VSA_FPNEG  float64
#  324  PEOE_VSA_FPOL   float64
#  325  PEOE_VSA_FPOS   float64
#  326  PEOE_VSA_FPPOS  float64
#  327  PEOE_VSA_HYD    float64
#  328  PEOE_VSA_NEG    float64
#  329  PEOE_VSA_PNEG   float64
#  330  PEOE_VSA_POL    float64
#  331  PEOE_VSA_POS    float64
#  332  PEOE_VSA_PPOS   float64
#  333  petitjean       float64
#  334  petitjeanSC     float64
#  335  pmi             float64
#  336  pmi1            float64
#  337  pmi2            float64
#  338  pmi3            float64
#  339  Q_PC+           float64
#  340  Q_PC-           float64
#  341  Q_RPC+          float64
#  342  Q_RPC-          float64
#  343  Q_VSA_FHYD      float64
#  344  Q_VSA_FNEG      float64
#  345  Q_VSA_FPNEG     float64
#  346  Q_VSA_FPOL      float64
#  347  Q_VSA_FPOS      float64
#  348  Q_VSA_FPPOS     float64
#  349  Q_VSA_HYD       float64
#  350  Q_VSA_NEG       float64
#  351  Q_VSA_PNEG      float64
#  352  Q_VSA_POL       float64
#  353  Q_VSA_POS       float64
#  354  Q_VSA_PPOS      float64
#  355  radius          int64
#  356  reactive        int64
#  357  rgyr            float64
#  358  rings           int64
#  359  RPC+            float64
#  360  RPC-            float64
#  361  rsynth          float64
#  362  SlogP           float64
#  363  SlogP_VSA0      float64
#  364  SlogP_VSA1      float64
#  365  SlogP_VSA2      float64
#  366  SlogP_VSA3      float64
#  367  SlogP_VSA4      float64
#  368  SlogP_VSA5      float64
#  369  SlogP_VSA6      float64
#  370  SlogP_VSA7      float64
#  371  SlogP_VSA8      float64
#  372  SlogP_VSA9      float64
#  373  SMR             float64
#  374  SMR_VSA0        float64
#  375  SMR_VSA1        float64
#  376  SMR_VSA2        float64
#  377  SMR_VSA3        float64
#  378  SMR_VSA4        float64
#  379  SMR_VSA5        float64
#  380  SMR_VSA6        float64
#  381  SMR_VSA7        float64
#  382  std_dim1        float64
#  383  std_dim2        float64
#  384  std_dim3        float64
#  385  TPSA            float64
#  386  VAdjEq          float64
#  387  VAdjMa          float64
#  388  VDistEq         float64
#  389  VDistMa         float64
#  390  vdw_area        float64
#  391  vdw_vol         float64
#  392  vol             float64
#  393  VSA             float64
#  394  vsa_acc         float64
#  395  vsa_acid        int64
#  396  vsa_base        int64
#  397  vsa_don         int64
#  398  vsa_hyd         float64
#  399  vsa_other       float64
#  400  vsa_pol         float64
#  401  vsurf_CW1       float64
#  402  vsurf_CW2       float64
#  403  vsurf_CW3       float64
#  404  vsurf_CW4       float64
#  405  vsurf_CW5       float64
#  406  vsurf_CW6       float64
#  407  vsurf_CW7       float64
#  408  vsurf_CW8       float64
#  409  vsurf_D1        float64
#  410  vsurf_D2        float64
#  411  vsurf_D3        float64
#  412  vsurf_D4        float64
#  413  vsurf_D5        float64
#  414  vsurf_D6        float64
#  415  vsurf_D7        float64
#  416  vsurf_D8        float64
#  417  vsurf_DD12      float64
#  418  vsurf_DD13      float64
#  419  vsurf_DD23      float64
#  420  vsurf_DW12      float64
#  421  vsurf_DW13      float64
#  422  vsurf_DW23      float64
#  423  vsurf_EDmin1    float64
#  424  vsurf_EDmin2    float64
#  425  vsurf_EDmin3    float64
#  426  vsurf_EWmin1    float64
#  427  vsurf_EWmin2    float64
#  428  vsurf_EWmin3    float64
#  429  vsurf_G         float64
#  430  vsurf_HB1       float64
#  431  vsurf_HB2       float64
#  432  vsurf_HB3       float64
#  433  vsurf_HB4       float64
#  434  vsurf_HB5       float64
#  435  vsurf_HB6       float64
#  436  vsurf_HB7       float64
#  437  vsurf_HB8       float64
#  438  vsurf_HL1       float64
#  439  vsurf_HL2       float64
#  440  vsurf_ID1       float64
#  441  vsurf_ID2       float64
#  442  vsurf_ID3       float64
#  443  vsurf_ID4       float64
#  444  vsurf_ID5       float64
#  445  vsurf_ID6       float64
#  446  vsurf_ID7       float64
#  447  vsurf_ID8       float64
#  448  vsurf_IW1       float64
#  449  vsurf_IW2       float64
#  450  vsurf_IW3       float64
#  451  vsurf_IW4       float64
#  452  vsurf_IW5       float64
#  453  vsurf_IW6       float64
#  454  vsurf_IW7       float64
#  455  vsurf_IW8       float64
#  456  vsurf_R         float64
#  457  vsurf_S         float64
#  458  vsurf_V         float64
#  459  vsurf_W1        float64
#  460  vsurf_W2        float64
#  461  vsurf_W3        float64
#  462  vsurf_W4        float64
#  463  vsurf_W5        float64
#  464  vsurf_W6        int64
#  465  vsurf_W7        float64
#  466  vsurf_W8        float64
#  467  vsurf_Wp1       float64
#  468  vsurf_Wp2       float64
#  469  vsurf_Wp3       float64
#  470  vsurf_Wp4       float64
#  471  vsurf_Wp5       float64
#  472  vsurf_Wp6       float64
#  473  vsurf_Wp7       int64
#  474  vsurf_Wp8       int64
#  475  Weight          float64
#  476  weinerPath      int64
#  477  weinerPol       int64
#  478  zagreb          int64
# dtypes: float64(257), int64(222)
# memory usage: 138.6 KB
# None
# ===== COLS WITH NAN VALUES =====
# Log_MP_RATIO    0
# apol            0
# ASA             0
# ASA+            0
# ASA-            0
#                ..
# vsurf_Wp8       0
# Weight          0
# weinerPath      0
# weinerPol       0
# zagreb          0
# Length: 479, dtype: int64

# %% [markdown]
# ## Comparing FULL dataset vs IONIZABLE + NEUTRAL DATASET

# %%
print("===== TRAIN =====")
df_concat_ion_train: pd.DataFrame = pd.concat([df_ionizable_train, df_neutral_train])
df_concat_ion_train = df_concat_ion_train.reset_index(drop=True)
display(df_concat_ion_train.shape)
display(df_full_train.shape)


# https://stackoverflow.com/a/20228113
df_concat_all_train = pd.concat([df_concat_ion_train, df_full_train])
df_concat_all_train = df_concat_all_train.reset_index(drop=True)
df_gpby = df_concat_all_train.groupby(list(df_concat_all_train.columns))
idx = [x[0] for x in df_gpby.groups.values() if len(x) == 1]
df_unique_train = df_concat_all_train.reindex(idx)
print(">>> NUMBER OF DIFFERENT VALUES")
display(df_unique_train.shape)


print(">>> VALEURS UNIQUES DANS FULL TRAIN")
print(len(pd.merge(df_unique_train, df_full_train, how="inner")))

print(">>> VALEURS UNIQUES DANS IONIZABLE + NEUTRAL TRAIN")
print(len(pd.merge(df_unique_train, df_concat_ion_train, how="inner")))


print("===== TEST =====")
df_concat_ion_test: pd.DataFrame = pd.concat([df_ionizable_test, df_neutral_test])
df_concat_ion_test = df_concat_ion_test.reset_index(drop=True)
display(df_concat_ion_test.shape)
display(df_full_test.shape)


df_concat_all_test = pd.concat([df_concat_ion_test, df_full_test])
df_concat_all_test = df_concat_all_test.reset_index(drop=True)
df_gpby = df_concat_all_test.groupby(list(df_concat_all_test.columns))
idx = [x[0] for x in df_gpby.groups.values() if len(x) == 1]
df_unique_test = df_concat_all_test.reindex(idx)
print(">>> NUMBER OF DIFFERENT VALUES")
display(df_unique_test.shape)


print(">>> VALEURS UNIQUES DANS FULL test")
print(len(pd.merge(df_unique_test, df_full_test, how="inner")))

print(">>> VALEURS UNIQUES DANS IONIZABLE + NEUTRAL test")
print(len(pd.merge(df_unique_test, df_concat_ion_test, how="inner")))
# Out:
# ===== TRAIN =====
# (147, 479)
# (146, 479)
# >>> NUMBER OF DIFFERENT VALUES
# (65, 479)
# >>> VALEURS UNIQUES DANS FULL TRAIN
# 32
# >>> VALEURS UNIQUES DANS IONIZABLE + NEUTRAL TRAIN
# 33
# ===== TEST =====
# (36, 479)
# (37, 479)
# >>> NUMBER OF DIFFERENT VALUES
# (29, 479)
# >>> VALEURS UNIQUES DANS FULL test
# 15
# >>> VALEURS UNIQUES DANS IONIZABLE + NEUTRAL test
# /tmp/ipykernel_2531/631907556.py:42: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   print(len(pd.merge(df_unique_test, df_full_test, how="inner")))
# 14

# %% [markdown]
# Some rows in the full dataset and the neutral / ionizable datasets are shared. Others are unique:
# **TRAIN**
# - FULL TRAIN: 32
# - IONIZABLE / NEUTRAL: 33
#
# **TEST**
# - FULL TEST: 15
# - IONIZABLE / NEUTRAL: 14

# %% [markdown]
# # Visualisation
# Here we are taking a quick look at all the numerical data

# %% [markdown]
# ## Data balance

# %% [markdown]
# ### TRAIN

# %%
df_ionizable_train["Type"] = "IONIZABLE"
df_neutral_train["Type"] = "NEUTRAL"

df_concat_all_train_typed: pd.DataFrame = pd.concat([df_ionizable_train, df_neutral_train], ignore_index=True)

sns.countplot(data=df_concat_all_train_typed, x="Type", hue="Type")
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %% [markdown]
# As we can see the training set for neutral and ionizable molecules are not equal in size
# This will be a factor that needs to be taken in account during the training phase when choosing the data
